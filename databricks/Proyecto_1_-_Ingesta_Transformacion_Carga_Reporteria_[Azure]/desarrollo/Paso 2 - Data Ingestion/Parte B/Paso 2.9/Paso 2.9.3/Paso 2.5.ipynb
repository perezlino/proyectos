# %% [markdown]
# ### **Paso 2.5 - Ingesta del archivo "results.json"**

# %% [markdown]
# Nos permite crear e indicar parámetros en tiempo de ejecución
#
# <center><img src="https://i.postimg.cc/W1Y3PV9C/db72.png"></center>

# %%
dbutils.widgets.text("p_data_source", "")
v_data_source = dbutils.widgets.get("p_data_source")

# %%
v_data_source
# Out:
# Out[2]: 'Ergast'

# %%
dbutils.widgets.text("p_file_date", "2021-03-28")
v_file_date = dbutils.widgets.get("p_file_date")

# %%
v_file_date
# Out:
# Out[4]: '2023-06-11'

# %%
# %run "../includes/configuration"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %run "../includes/common_functions"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# #### Paso 1 - Leer el archivo JSON

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, FloatType

# %%
results_schema = StructType(fields=[StructField("resultId", IntegerType(), False),
                                    StructField("raceId", IntegerType(), True),
                                    StructField("driverId", IntegerType(), True),
                                    StructField("constructorId", IntegerType(), True),
                                    StructField("number", IntegerType(), True),
                                    StructField("grid", IntegerType(), True),
                                    StructField("position", IntegerType(), True),
                                    StructField("positionText", StringType(), True),
                                    StructField("positionOrder", IntegerType(), True),
                                    StructField("points", FloatType(), True),
                                    StructField("laps", IntegerType(), True),
                                    StructField("time", StringType(), True),
                                    StructField("milliseconds", IntegerType(), True),
                                    StructField("fastestLap", IntegerType(), True),
                                    StructField("rank", IntegerType(), True),
                                    StructField("fastestLapTime", StringType(), True),
                                    StructField("fastestLapSpeed", FloatType(), True),
                                    StructField("statusId", StringType(), True)])

# %%
# El parámetro "raw_folder_path" se encuentra en el notebook "configuration"
# El parámetro "v_file_date" se encuentra en el notebook e indicamos su valor en tiempo de ejecución
results_df = spark.read \
.schema(results_schema) \
.json(f"{raw_folder_path}/results.json")
#.json(f"{raw_folder_path}/{v_file_date}/results.json")

# %%
results_df.show(truncate=False)
# Out:
# +--------+------+--------+-------------+------+----+--------+------------+-------------+------+----+-----------+------------+----------+----+--------------+---------------+--------+
# |resultId|raceId|driverId|constructorId|number|grid|position|positionText|positionOrder|points|laps|time       |milliseconds|fastestLap|rank|fastestLapTime|fastestLapSpeed|statusId|
# +--------+------+--------+-------------+------+----+--------+------------+-------------+------+----+-----------+------------+----------+----+--------------+---------------+--------+
# |1       |18    |1       |1            |22    |1   |1       |1           |1            |10.0  |58  |1:34:50.616|5690616     |39        |2   |1:27.452      |218.3          |1       |
# |2       |18    |2       |2            |3     |5   |2       |2           |2            |8.0   |58  |+5.478     |5696094     |41        |3   |1:27.739      |217.586        |1       |
# |3       |18    |3       |3            |7     |7   |3       |3           |3            |6.0   |58  |+8.163     |5698779     |41        |5   |1:28.090      |216.719        |1       |
# |4       |18    |4       |4            |5     |11  |4       |4           |4            |5.0   |58  |+17.181    |5707797     |58        |7   |1:28.603      |215.464        |1       |
# |5       |18    |5       |1            |23    |3   |5       |5           |5            |4.0   |58  |+18.014    |5708630     |43        |1   |1:27.418      |218.385        |1       |
# |6       |18    |6       |3            |8     |13  |6       |6           |6            |3.0   |57  |\N         |null        |50        |14  |1:29.639      |212.974        |11      |
# |7       |18    |7       |5            |14    |17  |7       |7           |7            |2.0   |55  |\N         |null        |22        |12  |1:29.534      |213.224        |5       |
# |8       |18    |8       |6            |1     |15  |8       |8           |8            |1.0   |53  |\N         |null        |20        |4   |1:27.903      |217.18         |5       |
# |9       |18    |9       |2            |4     |2   |null    |R           |9            |0.0   |47  |\N         |null        |15        |9   |1:28.753      |215.1          |4       |
# |10      |18    |10      |7            |12    |18  |null    |R           |10           |0.0   |43  |\N         |null        |23        |13  |1:29.558      |213.166        |3       |
# |11      |18    |11      |8            |18    |19  |null    |R           |11           |0.0   |32  |\N         |null        |24        |15  |1:30.892      |210.038        |7       |
# |12      |18    |12      |4            |6     |20  |null    |R           |12           |0.0   |30  |\N         |null        |20        |16  |1:31.384      |208.907        |8       |
# |13      |18    |13      |6            |2     |4   |null    |R           |13           |0.0   |29  |\N         |null        |23        |6   |1:28.175      |216.51         |5       |
# |14      |18    |14      |9            |9     |8   |null    |R           |14           |0.0   |25  |\N         |null        |21        |11  |1:29.502      |213.3          |4       |
# |15      |18    |15      |7            |11    |6   |null    |R           |15           |0.0   |19  |\N         |null        |18        |10  |1:29.310      |213.758        |10      |
# |16      |18    |16      |10           |20    |22  |null    |R           |16           |0.0   |8   |\N         |null        |8         |17  |1:32.021      |207.461        |9       |
# |17      |18    |17      |9            |10    |14  |null    |R           |17           |0.0   |0   |\N         |null        |null      |null|\N            |null           |4       |
# |18      |18    |18      |11           |16    |12  |null    |R           |18           |0.0   |0   |\N         |null        |null      |null|\N            |null           |4       |
# |19      |18    |19      |8            |19    |21  |null    |R           |19           |0.0   |0   |\N         |null        |null      |null|\N            |null           |4       |
# |20      |18    |20      |5            |15    |9   |null    |R           |20           |0.0   |0   |\N         |null        |null      |null|\N            |null           |4       |
# +--------+------+--------+-------------+------+----+--------+------------+-------------+------+----+-----------+------------+----------+----+--------------+---------------+--------+
# only showing top 20 rows

# %% [markdown]
# #### Paso 2 - Renombrar columnas y añadir columnas nuevas

# %%
from pyspark.sql.functions import lit

# %%
results_with_columns_df = results_df.withColumnRenamed("resultId", "result_id") \
                                    .withColumnRenamed("raceId", "race_id") \
                                    .withColumnRenamed("driverId", "driver_id") \
                                    .withColumnRenamed("constructorId", "constructor_id") \
                                    .withColumnRenamed("positionText", "position_text") \
                                    .withColumnRenamed("positionOrder", "position_order") \
                                    .withColumnRenamed("fastestLap", "fastest_lap") \
                                    .withColumnRenamed("fastestLapTime", "fastest_lap_time") \
                                    .withColumnRenamed("fastestLapSpeed", "fastest_lap_speed") \
                                    .withColumn("data_source", lit(v_data_source)) \
                                    .withColumn("file_date", lit(v_file_date))

# %%
results_with_columns_df.show(truncate=False)
# Out:
# +---------+-------+---------+--------------+------+----+--------+-------------+--------------+------+----+-----------+------------+-----------+----+----------------+-----------------+--------+-----------+----------+
# |result_id|race_id|driver_id|constructor_id|number|grid|position|position_text|position_order|points|laps|time       |milliseconds|fastest_lap|rank|fastest_lap_time|fastest_lap_speed|statusId|data_source|file_date |
# +---------+-------+---------+--------------+------+----+--------+-------------+--------------+------+----+-----------+------------+-----------+----+----------------+-----------------+--------+-----------+----------+
# |1        |18     |1        |1             |22    |1   |1       |1            |1             |10.0  |58  |1:34:50.616|5690616     |39         |2   |1:27.452        |218.3            |1       |Ergast     |2023-06-18|
# |2        |18     |2        |2             |3     |5   |2       |2            |2             |8.0   |58  |+5.478     |5696094     |41         |3   |1:27.739        |217.586          |1       |Ergast     |2023-06-18|
# |3        |18     |3        |3             |7     |7   |3       |3            |3             |6.0   |58  |+8.163     |5698779     |41         |5   |1:28.090        |216.719          |1       |Ergast     |2023-06-18|
# |4        |18     |4        |4             |5     |11  |4       |4            |4             |5.0   |58  |+17.181    |5707797     |58         |7   |1:28.603        |215.464          |1       |Ergast     |2023-06-18|
# |5        |18     |5        |1             |23    |3   |5       |5            |5             |4.0   |58  |+18.014    |5708630     |43         |1   |1:27.418        |218.385          |1       |Ergast     |2023-06-18|
# |6        |18     |6        |3             |8     |13  |6       |6            |6             |3.0   |57  |\N         |null        |50         |14  |1:29.639        |212.974          |11      |Ergast     |2023-06-18|
# |7        |18     |7        |5             |14    |17  |7       |7            |7             |2.0   |55  |\N         |null        |22         |12  |1:29.534        |213.224          |5       |Ergast     |2023-06-18|
# |8        |18     |8        |6             |1     |15  |8       |8            |8             |1.0   |53  |\N         |null        |20         |4   |1:27.903        |217.18           |5       |Ergast     |2023-06-18|
# |9        |18     |9        |2             |4     |2   |null    |R            |9             |0.0   |47  |\N         |null        |15         |9   |1:28.753        |215.1            |4       |Ergast     |2023-06-18|
# |10       |18     |10       |7             |12    |18  |null    |R            |10            |0.0   |43  |\N         |null        |23         |13  |1:29.558        |213.166          |3       |Ergast     |2023-06-18|
# |11       |18     |11       |8             |18    |19  |null    |R            |11            |0.0   |32  |\N         |null        |24         |15  |1:30.892        |210.038          |7       |Ergast     |2023-06-18|
# |12       |18     |12       |4             |6     |20  |null    |R            |12            |0.0   |30  |\N         |null        |20         |16  |1:31.384        |208.907          |8       |Ergast     |2023-06-18|
# |13       |18     |13       |6             |2     |4   |null    |R            |13            |0.0   |29  |\N         |null        |23         |6   |1:28.175        |216.51           |5       |Ergast     |2023-06-18|
# |14       |18     |14       |9             |9     |8   |null    |R            |14            |0.0   |25  |\N         |null        |21         |11  |1:29.502        |213.3            |4       |Ergast     |2023-06-18|
# |15       |18     |15       |7             |11    |6   |null    |R            |15            |0.0   |19  |\N         |null        |18         |10  |1:29.310        |213.758          |10      |Ergast     |2023-06-18|
# |16       |18     |16       |10            |20    |22  |null    |R            |16            |0.0   |8   |\N         |null        |8          |17  |1:32.021        |207.461          |9       |Ergast     |2023-06-18|
# |17       |18     |17       |9             |10    |14  |null    |R            |17            |0.0   |0   |\N         |null        |null       |null|\N              |null             |4       |Ergast     |2023-06-18|
# |18       |18     |18       |11            |16    |12  |null    |R            |18            |0.0   |0   |\N         |null        |null       |null|\N              |null             |4       |Ergast     |2023-06-18|
# |19       |18     |19       |8             |19    |21  |null    |R            |19            |0.0   |0   |\N         |null        |null       |null|\N              |null             |4       |Ergast     |2023-06-18|
# |20       |18     |20       |5             |15    |9   |null    |R            |20            |0.0   |0   |\N         |null        |null       |null|\N              |null             |4       |Ergast     |2023-06-18|
# +---------+-------+---------+--------------+------+----+--------+-------------+--------------+------+----+-----------+------------+-----------+----+----------------+-----------------+--------+-----------+----------+
# only showing top 20 rows

# %%
# La función "add_ingestion_date()" se encuentra en el notebook "common_functions"
results_with_ingestion_date_df = add_ingestion_date(results_with_columns_df)

# %%
results_with_ingestion_date_df.show(truncate=False)
# Out:
# +---------+-------+---------+--------------+------+----+--------+-------------+--------------+------+----+-----------+------------+-----------+----+----------------+-----------------+--------+-----------+----------+-----------------------+
# |result_id|race_id|driver_id|constructor_id|number|grid|position|position_text|position_order|points|laps|time       |milliseconds|fastest_lap|rank|fastest_lap_time|fastest_lap_speed|statusId|data_source|file_date |ingestion_date         |
# +---------+-------+---------+--------------+------+----+--------+-------------+--------------+------+----+-----------+------------+-----------+----+----------------+-----------------+--------+-----------+----------+-----------------------+
# |1        |18     |1        |1             |22    |1   |1       |1            |1             |10.0  |58  |1:34:50.616|5690616     |39         |2   |1:27.452        |218.3            |1       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |2        |18     |2        |2             |3     |5   |2       |2            |2             |8.0   |58  |+5.478     |5696094     |41         |3   |1:27.739        |217.586          |1       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |3        |18     |3        |3             |7     |7   |3       |3            |3             |6.0   |58  |+8.163     |5698779     |41         |5   |1:28.090        |216.719          |1       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |4        |18     |4        |4             |5     |11  |4       |4            |4             |5.0   |58  |+17.181    |5707797     |58         |7   |1:28.603        |215.464          |1       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |5        |18     |5        |1             |23    |3   |5       |5            |5             |4.0   |58  |+18.014    |5708630     |43         |1   |1:27.418        |218.385          |1       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |6        |18     |6        |3             |8     |13  |6       |6            |6             |3.0   |57  |\N         |null        |50         |14  |1:29.639        |212.974          |11      |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |7        |18     |7        |5             |14    |17  |7       |7            |7             |2.0   |55  |\N         |null        |22         |12  |1:29.534        |213.224          |5       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |8        |18     |8        |6             |1     |15  |8       |8            |8             |1.0   |53  |\N         |null        |20         |4   |1:27.903        |217.18           |5       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |9        |18     |9        |2             |4     |2   |null    |R            |9             |0.0   |47  |\N         |null        |15         |9   |1:28.753        |215.1            |4       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |10       |18     |10       |7             |12    |18  |null    |R            |10            |0.0   |43  |\N         |null        |23         |13  |1:29.558        |213.166          |3       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |11       |18     |11       |8             |18    |19  |null    |R            |11            |0.0   |32  |\N         |null        |24         |15  |1:30.892        |210.038          |7       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |12       |18     |12       |4             |6     |20  |null    |R            |12            |0.0   |30  |\N         |null        |20         |16  |1:31.384        |208.907          |8       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |13       |18     |13       |6             |2     |4   |null    |R            |13            |0.0   |29  |\N         |null        |23         |6   |1:28.175        |216.51           |5       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |14       |18     |14       |9             |9     |8   |null    |R            |14            |0.0   |25  |\N         |null        |21         |11  |1:29.502        |213.3            |4       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |15       |18     |15       |7             |11    |6   |null    |R            |15            |0.0   |19  |\N         |null        |18         |10  |1:29.310        |213.758          |10      |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |16       |18     |16       |10            |20    |22  |null    |R            |16            |0.0   |8   |\N         |null        |8          |17  |1:32.021        |207.461          |9       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |17       |18     |17       |9             |10    |14  |null    |R            |17            |0.0   |0   |\N         |null        |null       |null|\N              |null             |4       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |18       |18     |18       |11            |16    |12  |null    |R            |18            |0.0   |0   |\N         |null        |null       |null|\N              |null             |4       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |19       |18     |19       |8             |19    |21  |null    |R            |19            |0.0   |0   |\N         |null        |null       |null|\N              |null             |4       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# |20       |18     |20       |5             |15    |9   |null    |R            |20            |0.0   |0   |\N         |null        |null       |null|\N              |null             |4       |Ergast     |2023-06-18|2023-06-11 14:37:08.044|
# +---------+-------+---------+--------------+------+----+--------+-------------+--------------+------+----+-----------+------------+-----------+----+----------------+-----------------+--------+-----------+----------+-----------------------+
# only showing top 20 rows

# %% [markdown]
# #### Paso 3 - Eliminar la columna no deseada

# %%
from pyspark.sql.functions import col

# %%
results_final_df = results_with_ingestion_date_df.drop(col("statusId"))

# %%
results_final_df.show(truncate=False)
# Out:
# +---------+-------+---------+--------------+------+----+--------+-------------+--------------+------+----+-----------+------------+-----------+----+----------------+-----------------+-----------+----------+----------------------+
# |result_id|race_id|driver_id|constructor_id|number|grid|position|position_text|position_order|points|laps|time       |milliseconds|fastest_lap|rank|fastest_lap_time|fastest_lap_speed|data_source|file_date |ingestion_date        |
# +---------+-------+---------+--------------+------+----+--------+-------------+--------------+------+----+-----------+------------+-----------+----+----------------+-----------------+-----------+----------+----------------------+
# |1        |18     |1        |1             |22    |1   |1       |1            |1             |10.0  |58  |1:34:50.616|5690616     |39         |2   |1:27.452        |218.3            |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |2        |18     |2        |2             |3     |5   |2       |2            |2             |8.0   |58  |+5.478     |5696094     |41         |3   |1:27.739        |217.586          |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |3        |18     |3        |3             |7     |7   |3       |3            |3             |6.0   |58  |+8.163     |5698779     |41         |5   |1:28.090        |216.719          |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |4        |18     |4        |4             |5     |11  |4       |4            |4             |5.0   |58  |+17.181    |5707797     |58         |7   |1:28.603        |215.464          |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |5        |18     |5        |1             |23    |3   |5       |5            |5             |4.0   |58  |+18.014    |5708630     |43         |1   |1:27.418        |218.385          |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |6        |18     |6        |3             |8     |13  |6       |6            |6             |3.0   |57  |\N         |null        |50         |14  |1:29.639        |212.974          |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |7        |18     |7        |5             |14    |17  |7       |7            |7             |2.0   |55  |\N         |null        |22         |12  |1:29.534        |213.224          |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |8        |18     |8        |6             |1     |15  |8       |8            |8             |1.0   |53  |\N         |null        |20         |4   |1:27.903        |217.18           |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |9        |18     |9        |2             |4     |2   |null    |R            |9             |0.0   |47  |\N         |null        |15         |9   |1:28.753        |215.1            |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |10       |18     |10       |7             |12    |18  |null    |R            |10            |0.0   |43  |\N         |null        |23         |13  |1:29.558        |213.166          |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |11       |18     |11       |8             |18    |19  |null    |R            |11            |0.0   |32  |\N         |null        |24         |15  |1:30.892        |210.038          |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |12       |18     |12       |4             |6     |20  |null    |R            |12            |0.0   |30  |\N         |null        |20         |16  |1:31.384        |208.907          |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |13       |18     |13       |6             |2     |4   |null    |R            |13            |0.0   |29  |\N         |null        |23         |6   |1:28.175        |216.51           |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |14       |18     |14       |9             |9     |8   |null    |R            |14            |0.0   |25  |\N         |null        |21         |11  |1:29.502        |213.3            |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |15       |18     |15       |7             |11    |6   |null    |R            |15            |0.0   |19  |\N         |null        |18         |10  |1:29.310        |213.758          |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |16       |18     |16       |10            |20    |22  |null    |R            |16            |0.0   |8   |\N         |null        |8          |17  |1:32.021        |207.461          |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |17       |18     |17       |9             |10    |14  |null    |R            |17            |0.0   |0   |\N         |null        |null       |null|\N              |null             |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |18       |18     |18       |11            |16    |12  |null    |R            |18            |0.0   |0   |\N         |null        |null       |null|\N              |null             |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |19       |18     |19       |8             |19    |21  |null    |R            |19            |0.0   |0   |\N         |null        |null       |null|\N              |null             |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# |20       |18     |20       |5             |15    |9   |null    |R            |20            |0.0   |0   |\N         |null        |null       |null|\N              |null             |Ergast     |2023-06-18|2023-06-11 14:37:18.33|
# +---------+-------+---------+--------------+------+----+--------+-------------+--------------+------+----+-----------+------------+-----------+----+----------------+-----------------+-----------+----------+----------------------+
# only showing top 20 rows

# %% [markdown]
# #### Paso 4 - Escribir datos en el contenedor **processed** del ADLS como **parquet**

# %%
# Escribimos el archivo con formato PARQUET en el contenedor "processed" y directorio "results"
# Particionamos el archivo según los valores de la columna "race_id"
# El parámetro "processed_folder_path" se encuentra en el notebook "configuration"
results_final_df.write.mode('overwrite').partitionBy('race_id').parquet(f"{processed_folder_path}/results")

# %%
# Visualizamos los objetos que se encuentran en el directorio "results"
# %fs
ls /mnt/formula1dl/processed/results

# %%
dbutils.notebook.exit("Success")
