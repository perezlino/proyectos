# %% [markdown]
# ## **Despliegue de creación de tabla particionada `HIVE` desde `SPARK`**

# %% [markdown]
# ### **`Paso 1` - Crear directorio que albergara el archivo que utilizaremos para el despliegue del procesamiento SPARK**

# %% [markdown]
# - El directorio "deploy" en la ruta `/usr/local/spark/deploy`

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker exec -it spark-master bash
root@spark-master:/#
root@spark-master:/# cd /usr/local/spark
root@spark-master:/usr/local/spark#
root@spark-master:/usr/local/spark# mkdir deploy
root@spark-master:/usr/local/spark#
root@spark-master:/usr/local/spark# ls -l
total 136
-rw-r--r-- 1 1000 1000 21371 Feb  2  2020 LICENSE
-rw-r--r-- 1 1000 1000 42919 Feb  2  2020 NOTICE
drwxr-xr-x 3 1000 1000  4096 Feb  2  2020 R
-rw-r--r-- 1 1000 1000  3756 Feb  2  2020 README.md
-rw-r--r-- 1 1000 1000   187 Feb  2  2020 RELEASE
drwxr-xr-x 2 1000 1000  4096 Feb  2  2020 bin
drwxr-xr-x 1 1000 1000  4096 Jun 20 23:31 conf
drwxr-xr-x 5 1000 1000  4096 Feb  2  2020 data
drwxr-xr-x 2 root root  4096 Jun 25 02:06 deploy    # <-------
drwxr-xr-x 4 1000 1000  4096 Feb  2  2020 examples
drwxr-xr-x 2 1000 1000 12288 Feb  2  2020 jars
drwxr-xr-x 4 1000 1000  4096 Feb  2  2020 kubernetes
drwxr-xr-x 2 1000 1000  4096 Feb  2  2020 licenses
drwxr-xr-x 1 1000 1000  4096 Feb  2  2020 python
drwxr-xr-x 2 1000 1000  4096 Feb  2  2020 sbin
drwxr-xr-x 2 1000 1000  4096 Feb  2  2020 yarn
root@spark-master:/usr/local/spark#

# %% [markdown]
# ### **`Paso 2` - Subir archivo de despliegue al directorio recién creado**

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_4>docker cp deploy_script_spark.py spark-master:/usr/local/spark/deploy
Successfully copied 5.63kB to spark-master:/usr/local/spark/deploy

C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_4>docker exec -it spark-master bash
root@spark-master:/#
root@spark-master:/# cd /usr/local/spark/deploy
root@spark-master:/usr/local/spark/deploy#
root@spark-master:/usr/local/spark/deploy# ls -l
total 4
-rwxr-xr-x 1 root root 3923 Jun 25 01:59 deploy_script_spark.py
root@spark-master:/usr/local/spark/deploy#

# %% [markdown]
# ### **`Paso 3` - Despliegue de archivo de procesamiento SPARK**

# %%
spark-submit /usr/local/spark/deploy/deploy_script_spark.py

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker exec -it spark-master bash
root@spark-master:/usr/local/spark/deploy# 
root@spark-master:/usr/local/spark/deploy# spark-submit deploy_script_spark.py
2024-07-12 18:44:31,629 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
2024-07-12 18:44:33,186 INFO spark.SparkContext: Running Spark version 2.4.5
2024-07-12 18:44:33,251 INFO spark.SparkContext: Submitted application: Ejemplo Python Spark SQL Hive Integration
2024-07-12 18:44:33,368 INFO spark.SecurityManager: Changing view acls to: root
2024-07-12 18:44:33,368 INFO spark.SecurityManager: Changing modify acls to: root
2024-07-12 18:44:33,368 INFO spark.SecurityManager: Changing view acls groups to:
2024-07-12 18:44:33,369 INFO spark.SecurityManager: Changing modify acls groups to:
2024-07-12 18:44:33,369 INFO spark.SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(root); groups with view permissions: Set(); users  with modify permissions: Set(root); groups with modify permissions: Set()
2024-07-12 18:44:33,926 INFO util.Utils: Successfully started service 'sparkDriver' on port 36455.
2024-07-12 18:44:33,962 INFO spark.SparkEnv: Registering MapOutputTracker
2024-07-12 18:44:33,987 INFO spark.SparkEnv: Registering BlockManagerMaster
2024-07-12 18:44:33,991 INFO storage.BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
2024-07-12 18:44:33,992 INFO storage.BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
2024-07-12 18:44:34,010 INFO storage.DiskBlockManager: Created local directory at /tmp/blockmgr-9207a331-fadf-4cf3-9276-a9781905f58f
2024-07-12 18:44:34,033 INFO memory.MemoryStore: MemoryStore started with capacity 166.8 MB
2024-07-12 18:44:34,053 INFO spark.SparkEnv: Registering OutputCommitCoordinator
2024-07-12 18:44:34,155 INFO util.log: Logging initialized @4408ms
2024-07-12 18:44:34,250 INFO server.Server: jetty-9.3.z-SNAPSHOT, build timestamp: unknown, git hash: unknown
2024-07-12 18:44:34,283 INFO server.Server: Started @4539ms
2024-07-12 18:44:34,316 INFO server.AbstractConnector: Started ServerConnector@a8ba4ff{HTTP/1.1,[http/1.1]}{0.0.0.0:4040}
2024-07-12 18:44:34,317 INFO util.Utils: Successfully started service 'SparkUI' on port 4040.
2024-07-12 18:44:34,380 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@c5dbfbb{/jobs,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,383 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@58a9b8fe{/jobs/json,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,386 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@ac18d73{/jobs/job,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,389 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@6e4b0c8a{/jobs/job/json,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,392 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@7b3037f5{/stages,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,394 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@7d9c97f5{/stages/json,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,396 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@22ea778{/stages/stage,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,401 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@5778d715{/stages/stage/json,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,403 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@201abfe5{/stages/pool,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,406 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@2a003781{/stages/pool/json,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,408 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@720a9abc{/storage,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,412 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@63db2b97{/storage/json,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,418 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@164b559e{/storage/rdd,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,421 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@3d5cd4e9{/storage/rdd/json,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,426 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@1ba56684{/environment,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,430 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@219861f4{/environment/json,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,434 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@6d3327fc{/executors,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,437 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@36934d2f{/executors/json,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,443 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@6b29c3f{/executors/threadDump,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,449 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@64c7dadc{/executors/threadDump/json,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,468 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@103f1d7f{/static,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,472 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@2feadfa4{/,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,476 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@7f9412b4{/api,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,482 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@44fd32e8{/jobs/job/kill,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,486 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@42d354a2{/stages/stage/kill,null,AVAILABLE,@Spark}
2024-07-12 18:44:34,493 INFO ui.SparkUI: Bound SparkUI to 0.0.0.0, and started at http://spark-master:4040
2024-07-12 18:44:34,780 INFO client.StandaloneAppClient$ClientEndpoint: Connecting to master spark://spark-master:7077...
2024-07-12 18:44:34,896 INFO client.TransportClientFactory: Successfully created connection to spark-master/172.18.0.10:7077 after 71 ms (0 ms spent in bootstraps)
2024-07-12 18:44:35,136 INFO cluster.StandaloneSchedulerBackend: Connected to Spark cluster with app ID app-20240712184435-0006
2024-07-12 18:44:35,215 INFO client.StandaloneAppClient$ClientEndpoint: Executor added: app-20240712184435-0006/0 on worker-20240712180629-172.18.0.11-39885 (172.18.0.11:39885) with 4 core(s)
2024-07-12 18:44:35,219 INFO cluster.StandaloneSchedulerBackend: Granted executor ID app-20240712184435-0006/0 on hostPort 172.18.0.11:39885 with 4 core(s), 650.0 MB RAM
2024-07-12 18:44:35,237 INFO util.Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 37865.
2024-07-12 18:44:35,239 INFO netty.NettyBlockTransferService: Server created on spark-master:37865
2024-07-12 18:44:35,244 INFO storage.BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
2024-07-12 18:44:35,317 INFO client.StandaloneAppClient$ClientEndpoint: Executor updated: app-20240712184435-0006/0 is now RUNNING
2024-07-12 18:44:35,372 INFO storage.BlockManagerMaster: Registering BlockManager BlockManagerId(driver, spark-master, 37865, None)
2024-07-12 18:44:35,387 INFO storage.BlockManagerMasterEndpoint: Registering block manager spark-master:37865 with 166.8 MB RAM, BlockManagerId(driver, spark-master, 37865, None)
2024-07-12 18:44:35,397 INFO storage.BlockManagerMaster: Registered BlockManager BlockManagerId(driver, spark-master, 37865, None)
2024-07-12 18:44:35,400 INFO storage.BlockManager: Initialized BlockManager: BlockManagerId(driver, spark-master, 37865, None)
2024-07-12 18:44:36,065 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@1ba0c808{/metrics/json,null,AVAILABLE,@Spark}
2024-07-12 18:44:36,179 INFO cluster.StandaloneSchedulerBackend: SchedulerBackend is ready for scheduling beginning after reached minRegisteredResourcesRatio: 0.0
2024-07-12 18:44:36,682 INFO internal.SharedState: loading hive config file: file:/usr/local/spark/conf/hive-site.xml
2024-07-12 18:44:36,763 INFO internal.SharedState: Setting hive.metastore.warehouse.dir ('null') to the value of spark.sql.warehouse.dir ('file:/spark-warehouse').
2024-07-12 18:44:36,775 INFO internal.SharedState: Warehouse path is 'file:/spark-warehouse'.
2024-07-12 18:44:36,845 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@596e51e4{/SQL,null,AVAILABLE,@Spark}
2024-07-12 18:44:36,856 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@56808c33{/SQL/json,null,AVAILABLE,@Spark}
2024-07-12 18:44:36,860 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@4b607548{/SQL/execution,null,AVAILABLE,@Spark}
2024-07-12 18:44:36,872 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@5932c3a2{/SQL/execution/json,null,AVAILABLE,@Spark}
2024-07-12 18:44:36,881 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@69e2c197{/static/sql,null,AVAILABLE,@Spark}
2024-07-12 18:44:38,926 INFO state.StateStoreCoordinatorRef: Registered StateStoreCoordinator endpoint
2024-07-12 18:44:41,548 INFO datasources.InMemoryFileIndex: It took 408 ms to list leaf files for 1 paths.
2024-07-12 18:44:41,872 INFO datasources.InMemoryFileIndex: It took 50 ms to list leaf files for 2 paths.
2024-07-12 18:44:42,257 INFO cluster.CoarseGrainedSchedulerBackend$DriverEndpoint: Registered executor NettyRpcEndpointRef(spark-client://Executor) (172.18.0.11:39046) with ID 0
2024-07-12 18:44:42,968 INFO storage.BlockManagerMasterEndpoint: Registering block manager 172.18.0.11:34825 with 166.8 MB RAM, BlockManagerId(0, 172.18.0.11, 34825, None)
2024-07-12 18:44:50,435 INFO datasources.FileSourceStrategy: Pruning directories with:
2024-07-12 18:44:50,456 INFO datasources.FileSourceStrategy: Post-Scan Filters: (length(trim(value#0, None)) > 0)
2024-07-12 18:44:50,478 INFO datasources.FileSourceStrategy: Output Data Schema: struct<value: string>
2024-07-12 18:44:50,511 INFO execution.FileSourceScanExec: Pushed Filters:
2024-07-12 18:44:51,613 INFO codegen.CodeGenerator: Code generated in 628.941016 ms
2024-07-12 18:44:52,084 INFO codegen.CodeGenerator: Code generated in 37.217632 ms
2024-07-12 18:44:52,268 INFO memory.MemoryStore: Block broadcast_0 stored as values in memory (estimated size 310.7 KB, free 166.5 MB)
2024-07-12 18:44:52,472 INFO memory.MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 25.3 KB, free 166.5 MB)
2024-07-12 18:44:52,488 INFO storage.BlockManagerInfo: Added broadcast_0_piece0 in memory on spark-master:37865 (size: 25.3 KB, free: 166.8 MB)
2024-07-12 18:44:52,509 INFO spark.SparkContext: Created broadcast 0 from load at NativeMethodAccessorImpl.java:0
2024-07-12 18:44:52,540 INFO execution.FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
2024-07-12 18:44:53,004 INFO spark.SparkContext: Starting job: load at NativeMethodAccessorImpl.java:0
2024-07-12 18:44:53,056 INFO scheduler.DAGScheduler: Got job 0 (load at NativeMethodAccessorImpl.java:0) with 1 output partitions
2024-07-12 18:44:53,057 INFO scheduler.DAGScheduler: Final stage: ResultStage 0 (load at NativeMethodAccessorImpl.java:0)
2024-07-12 18:44:53,059 INFO scheduler.DAGScheduler: Parents of final stage: List()
2024-07-12 18:44:53,065 INFO scheduler.DAGScheduler: Missing parents: List()
2024-07-12 18:44:53,080 INFO scheduler.DAGScheduler: Submitting ResultStage 0 (MapPartitionsRDD[3] at load at NativeMethodAccessorImpl.java:0), which has no missing parents
2024-07-12 18:44:53,201 INFO memory.MemoryStore: Block broadcast_1 stored as values in memory (estimated size 8.9 KB, free 166.5 MB)
2024-07-12 18:44:53,215 INFO memory.MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 4.6 KB, free 166.5 MB)
2024-07-12 18:44:53,219 INFO storage.BlockManagerInfo: Added broadcast_1_piece0 in memory on spark-master:37865 (size: 4.6 KB, free: 166.8 MB)
2024-07-12 18:44:53,223 INFO spark.SparkContext: Created broadcast 1 from broadcast at DAGScheduler.scala:1163
2024-07-12 18:44:53,286 INFO scheduler.DAGScheduler: Submitting 1 missing tasks from ResultStage 0 (MapPartitionsRDD[3] at load at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
2024-07-12 18:44:53,289 INFO scheduler.TaskSchedulerImpl: Adding task set 0.0 with 1 tasks
2024-07-12 18:44:53,379 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0, 172.18.0.11, executor 0, partition 0, ANY, 8253 bytes)
2024-07-12 18:44:54,247 INFO storage.BlockManagerInfo: Added broadcast_1_piece0 in memory on 172.18.0.11:34825 (size: 4.6 KB, free: 166.8 MB)
2024-07-12 18:44:55,962 INFO storage.BlockManagerInfo: Added broadcast_0_piece0 in memory on 172.18.0.11:34825 (size: 25.3 KB, free: 166.8 MB)
2024-07-12 18:45:00,805 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 7446 ms on 172.18.0.11 (executor 0) (1/1)
2024-07-12 18:45:00,830 INFO scheduler.TaskSchedulerImpl: Removed TaskSet 0.0, whose tasks have all completed, from pool
2024-07-12 18:45:00,987 INFO scheduler.DAGScheduler: ResultStage 0 (load at NativeMethodAccessorImpl.java:0) finished in 7.799 s
2024-07-12 18:45:01,573 INFO scheduler.DAGScheduler: Job 0 finished: load at NativeMethodAccessorImpl.java:0, took 8.567498 s
2024-07-12 18:45:02,302 INFO storage.BlockManagerInfo: Removed broadcast_1_piece0 on spark-master:37865 in memory (size: 4.6 KB, free: 166.8 MB)
2024-07-12 18:45:02,337 INFO storage.BlockManagerInfo: Removed broadcast_1_piece0 on 172.18.0.11:34825 in memory (size: 4.6 KB, free: 166.8 MB)
2024-07-12 18:45:02,778 INFO datasources.FileSourceStrategy: Pruning directories with:
2024-07-12 18:45:02,784 INFO datasources.FileSourceStrategy: Post-Scan Filters:
2024-07-12 18:45:02,793 INFO datasources.FileSourceStrategy: Output Data Schema: struct<value: string>
2024-07-12 18:45:02,796 INFO execution.FileSourceScanExec: Pushed Filters:
2024-07-12 18:45:02,926 INFO codegen.CodeGenerator: Code generated in 74.346925 ms
2024-07-12 18:45:03,349 INFO memory.MemoryStore: Block broadcast_2 stored as values in memory (estimated size 310.7 KB, free 166.2 MB)
2024-07-12 18:45:03,767 INFO memory.MemoryStore: Block broadcast_2_piece0 stored as bytes in memory (estimated size 25.3 KB, free 166.1 MB)
2024-07-12 18:45:03,784 INFO storage.BlockManagerInfo: Added broadcast_2_piece0 in memory on spark-master:37865 (size: 25.3 KB, free: 166.8 MB)
2024-07-12 18:45:03,802 INFO spark.SparkContext: Created broadcast 2 from load at NativeMethodAccessorImpl.java:0
2024-07-12 18:45:03,804 INFO execution.FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
2024-07-12 18:45:04,654 INFO spark.SparkContext: Starting job: load at NativeMethodAccessorImpl.java:0
2024-07-12 18:45:04,680 INFO scheduler.DAGScheduler: Got job 1 (load at NativeMethodAccessorImpl.java:0) with 2 output partitions
2024-07-12 18:45:04,680 INFO scheduler.DAGScheduler: Final stage: ResultStage 1 (load at NativeMethodAccessorImpl.java:0)
2024-07-12 18:45:04,681 INFO scheduler.DAGScheduler: Parents of final stage: List()
2024-07-12 18:45:04,684 INFO scheduler.DAGScheduler: Missing parents: List()
2024-07-12 18:45:04,700 INFO scheduler.DAGScheduler: Submitting ResultStage 1 (MapPartitionsRDD[9] at load at NativeMethodAccessorImpl.java:0), which has no missing parents
2024-07-12 18:45:04,760 INFO memory.MemoryStore: Block broadcast_3 stored as values in memory (estimated size 14.1 KB, free 166.1 MB)
2024-07-12 18:45:04,780 INFO memory.MemoryStore: Block broadcast_3_piece0 stored as bytes in memory (estimated size 7.6 KB, free 166.1 MB)
2024-07-12 18:45:04,786 INFO storage.BlockManagerInfo: Added broadcast_3_piece0 in memory on spark-master:37865 (size: 7.6 KB, free: 166.7 MB)
2024-07-12 18:45:04,796 INFO spark.SparkContext: Created broadcast 3 from broadcast at DAGScheduler.scala:1163
2024-07-12 18:45:04,819 INFO scheduler.DAGScheduler: Submitting 2 missing tasks from ResultStage 1 (MapPartitionsRDD[9] at load at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0, 1))
2024-07-12 18:45:04,837 INFO scheduler.TaskSchedulerImpl: Adding task set 1.0 with 2 tasks
2024-07-12 18:45:04,874 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 1.0 (TID 1, 172.18.0.11, executor 0, partition 0, ANY, 8253 bytes)
2024-07-12 18:45:04,878 INFO scheduler.TaskSetManager: Starting task 1.0 in stage 1.0 (TID 2, 172.18.0.11, executor 0, partition 1, ANY, 8253 bytes)
2024-07-12 18:45:05,690 INFO storage.BlockManagerInfo: Added broadcast_3_piece0 in memory on 172.18.0.11:34825 (size: 7.6 KB, free: 166.8 MB)
2024-07-12 18:45:31,087 INFO storage.BlockManagerInfo: Added broadcast_2_piece0 in memory on 172.18.0.11:34825 (size: 25.3 KB, free: 166.7 MB)
2024-07-12 18:45:34,057 INFO scheduler.TaskSetManager: Finished task 1.0 in stage 1.0 (TID 2) in 29163 ms on 172.18.0.11 (executor 0) (1/2)
2024-07-12 18:45:34,493 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 1.0 (TID 1) in 29620 ms on 172.18.0.11 (executor 0) (2/2)
2024-07-12 18:45:34,494 INFO scheduler.TaskSchedulerImpl: Removed TaskSet 1.0, whose tasks have all completed, from pool
2024-07-12 18:45:34,513 INFO scheduler.DAGScheduler: ResultStage 1 (load at NativeMethodAccessorImpl.java:0) finished in 29.791 s
2024-07-12 18:45:34,517 INFO scheduler.DAGScheduler: Job 1 finished: load at NativeMethodAccessorImpl.java:0, took 29.867065 s
root
 |-- id: integer (nullable = true)
 |-- nombre: string (nullable = true)
 |-- salario: integer (nullable = true)
 |-- departamento: string (nullable = true)

2024-07-12 18:45:39,776 INFO hive.HiveUtils: Initializing HiveMetastoreConnection version 1.2.1 using Spark classes.
2024-07-12 18:45:43,427 WARN conf.HiveConf: HiveConf of name hive.metastore.event.db.notification.api.auth does not exist
2024-07-12 18:45:43,918 INFO spark.ContextCleaner: Cleaned accumulator 9
2024-07-12 18:45:43,921 INFO spark.ContextCleaner: Cleaned accumulator 22
2024-07-12 18:45:44,031 INFO storage.BlockManagerInfo: Removed broadcast_2_piece0 on 172.18.0.11:34825 in memory (size: 25.3 KB, free: 166.8 MB)
2024-07-12 18:45:44,055 INFO storage.BlockManagerInfo: Removed broadcast_2_piece0 on spark-master:37865 in memory (size: 25.3 KB, free: 166.8 MB)
2024-07-12 18:45:44,283 INFO spark.ContextCleaner: Cleaned accumulator 40
2024-07-12 18:45:44,375 INFO spark.ContextCleaner: Cleaned accumulator 51
2024-07-12 18:45:44,390 INFO spark.ContextCleaner: Cleaned accumulator 30
2024-07-12 18:45:44,444 INFO spark.ContextCleaner: Cleaned accumulator 24
2024-07-12 18:45:44,603 INFO storage.BlockManagerInfo: Removed broadcast_3_piece0 on spark-master:37865 in memory (size: 7.6 KB, free: 166.8 MB)
2024-07-12 18:45:44,718 INFO storage.BlockManagerInfo: Removed broadcast_3_piece0 on 172.18.0.11:34825 in memory (size: 7.6 KB, free: 166.8 MB)
2024-07-12 18:45:45,079 INFO spark.ContextCleaner: Cleaned accumulator 36
2024-07-12 18:45:45,080 INFO spark.ContextCleaner: Cleaned accumulator 27
2024-07-12 18:45:45,080 INFO spark.ContextCleaner: Cleaned accumulator 16
2024-07-12 18:45:45,080 INFO spark.ContextCleaner: Cleaned accumulator 11
2024-07-12 18:45:45,081 INFO spark.ContextCleaner: Cleaned accumulator 13
2024-07-12 18:45:45,081 INFO spark.ContextCleaner: Cleaned accumulator 52
2024-07-12 18:45:45,081 INFO spark.ContextCleaner: Cleaned accumulator 46
2024-07-12 18:45:45,082 INFO spark.ContextCleaner: Cleaned accumulator 7
2024-07-12 18:45:45,082 INFO spark.ContextCleaner: Cleaned accumulator 37
2024-07-12 18:45:45,084 INFO spark.ContextCleaner: Cleaned accumulator 59
2024-07-12 18:45:45,087 INFO spark.ContextCleaner: Cleaned accumulator 31
2024-07-12 18:45:45,092 INFO spark.ContextCleaner: Cleaned accumulator 47
2024-07-12 18:45:45,094 INFO spark.ContextCleaner: Cleaned accumulator 12
2024-07-12 18:45:45,101 INFO spark.ContextCleaner: Cleaned accumulator 15
2024-07-12 18:45:45,101 INFO spark.ContextCleaner: Cleaned accumulator 32
2024-07-12 18:45:45,101 INFO spark.ContextCleaner: Cleaned accumulator 28
2024-07-12 18:45:45,103 INFO spark.ContextCleaner: Cleaned accumulator 50
2024-07-12 18:45:45,148 INFO spark.ContextCleaner: Cleaned accumulator 49
2024-07-12 18:45:45,149 INFO spark.ContextCleaner: Cleaned accumulator 42
2024-07-12 18:45:45,216 INFO spark.ContextCleaner: Cleaned accumulator 57
2024-07-12 18:45:45,218 INFO spark.ContextCleaner: Cleaned accumulator 10
2024-07-12 18:45:45,219 INFO spark.ContextCleaner: Cleaned accumulator 43
2024-07-12 18:45:45,235 INFO spark.ContextCleaner: Cleaned accumulator 23
2024-07-12 18:45:45,250 INFO spark.ContextCleaner: Cleaned accumulator 38
2024-07-12 18:45:45,252 INFO spark.ContextCleaner: Cleaned accumulator 33
2024-07-12 18:45:45,253 INFO spark.ContextCleaner: Cleaned accumulator 8
2024-07-12 18:45:45,255 INFO spark.ContextCleaner: Cleaned accumulator 25
2024-07-12 18:45:45,259 INFO spark.ContextCleaner: Cleaned accumulator 35
2024-07-12 18:45:45,286 INFO spark.ContextCleaner: Cleaned accumulator 55
2024-07-12 18:45:45,296 INFO spark.ContextCleaner: Cleaned accumulator 34
2024-07-12 18:45:45,297 INFO spark.ContextCleaner: Cleaned accumulator 44
2024-07-12 18:45:45,297 INFO spark.ContextCleaner: Cleaned accumulator 20
2024-07-12 18:45:45,297 INFO spark.ContextCleaner: Cleaned accumulator 41
2024-07-12 18:45:45,297 INFO spark.ContextCleaner: Cleaned accumulator 45
2024-07-12 18:45:45,297 INFO spark.ContextCleaner: Cleaned accumulator 58
2024-07-12 18:45:45,297 INFO spark.ContextCleaner: Cleaned accumulator 14
2024-07-12 18:45:45,297 INFO spark.ContextCleaner: Cleaned accumulator 19
2024-07-12 18:45:45,298 INFO spark.ContextCleaner: Cleaned accumulator 39
2024-07-12 18:45:45,298 INFO spark.ContextCleaner: Cleaned accumulator 48
2024-07-12 18:45:45,298 INFO spark.ContextCleaner: Cleaned accumulator 54
2024-07-12 18:45:45,299 INFO spark.ContextCleaner: Cleaned accumulator 26
2024-07-12 18:45:45,302 INFO spark.ContextCleaner: Cleaned accumulator 29
2024-07-12 18:45:45,303 INFO spark.ContextCleaner: Cleaned accumulator 21
2024-07-12 18:45:45,304 INFO spark.ContextCleaner: Cleaned accumulator 17
2024-07-12 18:45:45,305 INFO spark.ContextCleaner: Cleaned accumulator 60
2024-07-12 18:45:45,601 INFO storage.BlockManagerInfo: Removed broadcast_0_piece0 on 172.18.0.11:34825 in memory (size: 25.3 KB, free: 166.8 MB)
2024-07-12 18:45:45,782 INFO storage.BlockManagerInfo: Removed broadcast_0_piece0 on spark-master:37865 in memory (size: 25.3 KB, free: 166.8 MB)
2024-07-12 18:45:45,911 INFO spark.ContextCleaner: Cleaned accumulator 18
2024-07-12 18:45:45,912 INFO spark.ContextCleaner: Cleaned accumulator 61
2024-07-12 18:45:45,912 INFO spark.ContextCleaner: Cleaned accumulator 53
2024-07-12 18:45:45,925 INFO spark.ContextCleaner: Cleaned accumulator 56
2024-07-12 18:45:46,942 INFO hive.metastore: Trying to connect to metastore with URI thrift://hive-metastore:9083
2024-07-12 18:45:47,360 INFO hive.metastore: Connected to metastore.
2024-07-12 18:45:48,099 INFO session.SessionState: Created local directory: /tmp/e977fd25-4ccd-40cf-857a-44462214d966_resources
2024-07-12 18:45:48,143 INFO session.SessionState: Created HDFS directory: /tmp/hive/root/e977fd25-4ccd-40cf-857a-44462214d966
2024-07-12 18:45:48,167 INFO session.SessionState: Created local directory: /tmp/root/e977fd25-4ccd-40cf-857a-44462214d966
2024-07-12 18:45:48,182 INFO session.SessionState: Created HDFS directory: /tmp/hive/root/e977fd25-4ccd-40cf-857a-44462214d966/_tmp_space.db
2024-07-12 18:45:48,196 INFO client.HiveClientImpl: Warehouse location for Hive client (version 1.2.2) is file:/spark-warehouse
2024-07-12 18:45:50,604 INFO datasources.FileSourceStrategy: Pruning directories with:
2024-07-12 18:45:50,605 INFO datasources.FileSourceStrategy: Post-Scan Filters:
2024-07-12 18:45:50,607 INFO datasources.FileSourceStrategy: Output Data Schema: struct<id: int, departamento: string, nombre: string, salario: int ... 2 more fields>
2024-07-12 18:45:50,608 INFO execution.FileSourceScanExec: Pushed Filters:
2024-07-12 18:45:50,787 INFO common.FileUtils: Creating directory if it doesn't exist: hdfs://namenode:9000/user/databases/db1/dept_partition/.hive-staging_hive_2024-07-12_18-45-50_782_5067594969183362602-1
2024-07-12 18:45:51,773 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
2024-07-12 18:45:51,777 INFO datasources.SQLHadoopMapReduceCommitProtocol: Using output committer class org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter
2024-07-12 18:45:51,887 INFO codegen.CodeGenerator: Code generated in 46.173333 ms
2024-07-12 18:45:51,911 INFO memory.MemoryStore: Block broadcast_4 stored as values in memory (estimated size 306.6 KB, free 166.5 MB)
2024-07-12 18:45:51,939 INFO memory.MemoryStore: Block broadcast_4_piece0 stored as bytes in memory (estimated size 25.3 KB, free 166.5 MB)
2024-07-12 18:45:51,943 INFO storage.BlockManagerInfo: Added broadcast_4_piece0 in memory on spark-master:37865 (size: 25.3 KB, free: 166.8 MB)
2024-07-12 18:45:51,946 INFO spark.SparkContext: Created broadcast 4 from insertInto at NativeMethodAccessorImpl.java:0
2024-07-12 18:45:51,954 INFO execution.FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
2024-07-12 18:45:52,204 INFO spark.SparkContext: Starting job: insertInto at NativeMethodAccessorImpl.java:0
2024-07-12 18:45:52,216 INFO scheduler.DAGScheduler: Got job 2 (insertInto at NativeMethodAccessorImpl.java:0) with 1 output partitions
2024-07-12 18:45:52,216 INFO scheduler.DAGScheduler: Final stage: ResultStage 2 (insertInto at NativeMethodAccessorImpl.java:0)
2024-07-12 18:45:52,216 INFO scheduler.DAGScheduler: Parents of final stage: List()
2024-07-12 18:45:52,217 INFO scheduler.DAGScheduler: Missing parents: List()
2024-07-12 18:45:52,220 INFO scheduler.DAGScheduler: Submitting ResultStage 2 (MapPartitionsRDD[12] at insertInto at NativeMethodAccessorImpl.java:0), which has no missing parents
2024-07-12 18:45:52,533 INFO memory.MemoryStore: Block broadcast_5 stored as values in memory (estimated size 236.3 KB, free 166.2 MB)
2024-07-12 18:45:52,551 INFO memory.MemoryStore: Block broadcast_5_piece0 stored as bytes in memory (estimated size 86.9 KB, free 166.2 MB)
2024-07-12 18:45:52,570 INFO storage.BlockManagerInfo: Added broadcast_5_piece0 in memory on spark-master:37865 (size: 86.9 KB, free: 166.7 MB)
2024-07-12 18:45:52,578 INFO spark.SparkContext: Created broadcast 5 from broadcast at DAGScheduler.scala:1163
2024-07-12 18:45:52,586 INFO scheduler.DAGScheduler: Submitting 1 missing tasks from ResultStage 2 (MapPartitionsRDD[12] at insertInto at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
2024-07-12 18:45:52,586 INFO scheduler.TaskSchedulerImpl: Adding task set 2.0 with 1 tasks
2024-07-12 18:45:52,595 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 2.0 (TID 3, 172.18.0.11, executor 0, partition 0, ANY, 8253 bytes)
2024-07-12 18:45:52,820 INFO storage.BlockManagerInfo: Added broadcast_5_piece0 in memory on 172.18.0.11:34825 (size: 86.9 KB, free: 166.7 MB)
2024-07-12 18:45:53,975 INFO storage.BlockManagerInfo: Added broadcast_4_piece0 in memory on 172.18.0.11:34825 (size: 25.3 KB, free: 166.7 MB)
2024-07-12 18:45:58,048 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 2.0 (TID 3) in 5456 ms on 172.18.0.11 (executor 0) (1/1)
2024-07-12 18:45:58,049 INFO scheduler.TaskSchedulerImpl: Removed TaskSet 2.0, whose tasks have all completed, from pool
2024-07-12 18:45:58,052 INFO scheduler.DAGScheduler: ResultStage 2 (insertInto at NativeMethodAccessorImpl.java:0) finished in 5.821 s
2024-07-12 18:45:58,055 INFO scheduler.DAGScheduler: Job 2 finished: insertInto at NativeMethodAccessorImpl.java:0, took 5.849769 s
2024-07-12 18:45:58,232 INFO datasources.FileFormatWriter: Write Job ba87801b-3b75-460f-a93a-7c3b9ed4f655 committed.
2024-07-12 18:45:58,252 INFO datasources.FileFormatWriter: Finished processing stats for write job ba87801b-3b75-460f-a93a-7c3b9ed4f655.
2024-07-12 18:45:58,811 INFO common.FileUtils: Creating directory if it doesn't exist: hdfs://namenode:9000/user/databases/db1/dept_partition/departamento=Sales
2024-07-12 18:45:58,953 ERROR hdfs.KeyProviderCache: Could not find uri with key [dfs.encryption.key.provider.uri] to create a keyProvider !!
2024-07-12 18:45:59,013 INFO metadata.Hive: Renaming src: hdfs://namenode:9000/user/databases/db1/dept_partition/.hive-staging_hive_2024-07-12_18-45-50_782_5067594969183362602-1/-ext-10000/departamento=Sales/part-00000-f27024e8-9916-48a1-bddd-f499eee489a8.c000, dest: hdfs://namenode:9000/user/databases/db1/dept_partition/departamento=Sales/part-00000-f27024e8-9916-48a1-bddd-f499eee489a8.c000, Status:true
2024-07-12 18:45:59,587 INFO metadata.Hive: New loading path = hdfs://namenode:9000/user/databases/db1/dept_partition/.hive-staging_hive_2024-07-12_18-45-50_782_5067594969183362602-1/-ext-10000/departamento=Sales with partSpec {departamento=Sales}
2024-07-12 18:45:59,653 INFO common.FileUtils: Creating directory if it doesn't exist: hdfs://namenode:9000/user/databases/db1/dept_partition/departamento=Accounts
2024-07-12 18:45:59,761 INFO metadata.Hive: Renaming src: hdfs://namenode:9000/user/databases/db1/dept_partition/.hive-staging_hive_2024-07-12_18-45-50_782_5067594969183362602-1/-ext-10000/departamento=Accounts/part-00000-f27024e8-9916-48a1-bddd-f499eee489a8.c000, dest: hdfs://namenode:9000/user/databases/db1/dept_partition/departamento=Accounts/part-00000-f27024e8-9916-48a1-bddd-f499eee489a8.c000, Status:true
2024-07-12 18:45:59,899 INFO metadata.Hive: New loading path = hdfs://namenode:9000/user/databases/db1/dept_partition/.hive-staging_hive_2024-07-12_18-45-50_782_5067594969183362602-1/-ext-10000/departamento=Accounts with partSpec {departamento=Accounts}
2024-07-12 18:45:59,943 INFO common.FileUtils: Creating directory if it doesn't exist: hdfs://namenode:9000/user/databases/db1/dept_partition/departamento=Marketing
2024-07-12 18:46:00,063 INFO metadata.Hive: Renaming src: hdfs://namenode:9000/user/databases/db1/dept_partition/.hive-staging_hive_2024-07-12_18-45-50_782_5067594969183362602-1/-ext-10000/departamento=Marketing/part-00000-f27024e8-9916-48a1-bddd-f499eee489a8.c000, dest: hdfs://namenode:9000/user/databases/db1/dept_partition/departamento=Marketing/part-00000-f27024e8-9916-48a1-bddd-f499eee489a8.c000, Status:true
2024-07-12 18:46:00,213 INFO metadata.Hive: New loading path = hdfs://namenode:9000/user/databases/db1/dept_partition/.hive-staging_hive_2024-07-12_18-45-50_782_5067594969183362602-1/-ext-10000/departamento=Marketing with partSpec {departamento=Marketing}
2024-07-12 18:46:00,263 INFO common.FileUtils: Creating directory if it doesn't exist: hdfs://namenode:9000/user/databases/db1/dept_partition/departamento=HR
2024-07-12 18:46:00,329 INFO metadata.Hive: Renaming src: hdfs://namenode:9000/user/databases/db1/dept_partition/.hive-staging_hive_2024-07-12_18-45-50_782_5067594969183362602-1/-ext-10000/departamento=HR/part-00000-f27024e8-9916-48a1-bddd-f499eee489a8.c000, dest: hdfs://namenode:9000/user/databases/db1/dept_partition/departamento=HR/part-00000-f27024e8-9916-48a1-bddd-f499eee489a8.c000, Status:true
2024-07-12 18:46:00,512 INFO metadata.Hive: New loading path = hdfs://namenode:9000/user/databases/db1/dept_partition/.hive-staging_hive_2024-07-12_18-45-50_782_5067594969183362602-1/-ext-10000/departamento=HR with partSpec {departamento=HR}
2024-07-12 18:46:01,212 INFO datasources.FileSourceStrategy: Pruning directories with:
2024-07-12 18:46:01,220 INFO datasources.FileSourceStrategy: Post-Scan Filters:
2024-07-12 18:46:01,221 INFO datasources.FileSourceStrategy: Output Data Schema: struct<deptid: int, nombre: string, salario: int ... 1 more fields>
2024-07-12 18:46:01,222 INFO execution.FileSourceScanExec: Pushed Filters:
2024-07-12 18:46:02,230 INFO datasources.PrunedInMemoryFileIndex: It took 88 ms to list leaf files for 4 paths.
2024-07-12 18:46:02,575 INFO codegen.CodeGenerator: Code generated in 132.301953 ms
2024-07-12 18:46:02,700 INFO codegen.CodeGenerator: Code generated in 61.490463 ms
2024-07-12 18:46:02,836 INFO codegen.CodeGenerator: Code generated in 98.786739 ms
2024-07-12 18:46:02,878 INFO memory.MemoryStore: Block broadcast_6 stored as values in memory (estimated size 306.5 KB, free 165.9 MB)
2024-07-12 18:46:02,923 INFO memory.MemoryStore: Block broadcast_6_piece0 stored as bytes in memory (estimated size 25.4 KB, free 165.8 MB)
2024-07-12 18:46:02,929 INFO storage.BlockManagerInfo: Added broadcast_6_piece0 in memory on spark-master:37865 (size: 25.4 KB, free: 166.7 MB)
2024-07-12 18:46:02,937 INFO spark.SparkContext: Created broadcast 6 from showString at NativeMethodAccessorImpl.java:0
2024-07-12 18:46:02,955 INFO execution.FileSourceScanExec: Planning scan with bin packing, max size: 4195229 bytes, open cost is considered as scanning 4194304 bytes.
2024-07-12 18:46:03,070 INFO spark.SparkContext: Starting job: showString at NativeMethodAccessorImpl.java:0
2024-07-12 18:46:03,098 INFO scheduler.DAGScheduler: Registering RDD 17 (showString at NativeMethodAccessorImpl.java:0) as input to shuffle 0
2024-07-12 18:46:03,118 INFO scheduler.DAGScheduler: Got job 3 (showString at NativeMethodAccessorImpl.java:0) with 1 output partitions
2024-07-12 18:46:03,124 INFO scheduler.DAGScheduler: Final stage: ResultStage 4 (showString at NativeMethodAccessorImpl.java:0)
2024-07-12 18:46:03,129 INFO scheduler.DAGScheduler: Parents of final stage: List(ShuffleMapStage 3)
2024-07-12 18:46:03,139 INFO scheduler.DAGScheduler: Missing parents: List(ShuffleMapStage 3)
2024-07-12 18:46:03,158 INFO scheduler.DAGScheduler: Submitting ShuffleMapStage 3 (MapPartitionsRDD[17] at showString at NativeMethodAccessorImpl.java:0), which has no missing parents
2024-07-12 18:46:03,318 INFO memory.MemoryStore: Block broadcast_7 stored as values in memory (estimated size 12.0 KB, free 165.8 MB)
2024-07-12 18:46:03,342 INFO memory.MemoryStore: Block broadcast_7_piece0 stored as bytes in memory (estimated size 5.7 KB, free 165.8 MB)
2024-07-12 18:46:03,351 INFO storage.BlockManagerInfo: Added broadcast_7_piece0 in memory on spark-master:37865 (size: 5.7 KB, free: 166.7 MB)
2024-07-12 18:46:03,362 INFO spark.SparkContext: Created broadcast 7 from broadcast at DAGScheduler.scala:1163
2024-07-12 18:46:03,389 INFO scheduler.DAGScheduler: Submitting 4 missing tasks from ShuffleMapStage 3 (MapPartitionsRDD[17] at showString at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0, 1, 2, 3))
2024-07-12 18:46:03,392 INFO scheduler.TaskSchedulerImpl: Adding task set 3.0 with 4 tasks
2024-07-12 18:46:03,423 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 3.0 (TID 4, 172.18.0.11, executor 0, partition 0, ANY, 8398 bytes)
2024-07-12 18:46:03,438 INFO scheduler.TaskSetManager: Starting task 1.0 in stage 3.0 (TID 5, 172.18.0.11, executor 0, partition 1, ANY, 8412 bytes)
2024-07-12 18:46:03,457 INFO scheduler.TaskSetManager: Starting task 2.0 in stage 3.0 (TID 6, 172.18.0.11, executor 0, partition 2, ANY, 8410 bytes)
2024-07-12 18:46:03,459 INFO scheduler.TaskSetManager: Starting task 3.0 in stage 3.0 (TID 7, 172.18.0.11, executor 0, partition 3, ANY, 8404 bytes)
2024-07-12 18:46:03,846 INFO storage.BlockManagerInfo: Added broadcast_7_piece0 in memory on 172.18.0.11:34825 (size: 5.7 KB, free: 166.7 MB)
2024-07-12 18:46:04,648 INFO storage.BlockManagerInfo: Added broadcast_6_piece0 in memory on 172.18.0.11:34825 (size: 25.4 KB, free: 166.7 MB)
2024-07-12 18:46:06,475 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 3.0 (TID 4) in 3068 ms on 172.18.0.11 (executor 0) (1/4)
2024-07-12 18:46:06,489 INFO scheduler.TaskSetManager: Finished task 3.0 in stage 3.0 (TID 7) in 3032 ms on 172.18.0.11 (executor 0) (2/4)
2024-07-12 18:46:06,509 INFO scheduler.TaskSetManager: Finished task 1.0 in stage 3.0 (TID 5) in 3072 ms on 172.18.0.11 (executor 0) (3/4)
2024-07-12 18:46:06,523 INFO scheduler.TaskSetManager: Finished task 2.0 in stage 3.0 (TID 6) in 3071 ms on 172.18.0.11 (executor 0) (4/4)
2024-07-12 18:46:06,528 INFO scheduler.TaskSchedulerImpl: Removed TaskSet 3.0, whose tasks have all completed, from pool
2024-07-12 18:46:06,533 INFO scheduler.DAGScheduler: ShuffleMapStage 3 (showString at NativeMethodAccessorImpl.java:0) finished in 3.350 s
2024-07-12 18:46:06,543 INFO scheduler.DAGScheduler: looking for newly runnable stages
2024-07-12 18:46:06,549 INFO scheduler.DAGScheduler: running: Set()
2024-07-12 18:46:06,553 INFO scheduler.DAGScheduler: waiting: Set(ResultStage 4)
2024-07-12 18:46:06,556 INFO scheduler.DAGScheduler: failed: Set()
2024-07-12 18:46:06,577 INFO scheduler.DAGScheduler: Submitting ResultStage 4 (MapPartitionsRDD[21] at showString at NativeMethodAccessorImpl.java:0), which has no missing parents
2024-07-12 18:46:06,645 INFO memory.MemoryStore: Block broadcast_8 stored as values in memory (estimated size 8.1 KB, free 165.8 MB)
2024-07-12 18:46:06,681 INFO memory.MemoryStore: Block broadcast_8_piece0 stored as bytes in memory (estimated size 3.9 KB, free 165.8 MB)
2024-07-12 18:46:06,697 INFO storage.BlockManagerInfo: Added broadcast_8_piece0 in memory on spark-master:37865 (size: 3.9 KB, free: 166.7 MB)
2024-07-12 18:46:06,701 INFO spark.SparkContext: Created broadcast 8 from broadcast at DAGScheduler.scala:1163
2024-07-12 18:46:06,716 INFO scheduler.DAGScheduler: Submitting 1 missing tasks from ResultStage 4 (MapPartitionsRDD[21] at showString at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
2024-07-12 18:46:06,716 INFO scheduler.TaskSchedulerImpl: Adding task set 4.0 with 1 tasks
2024-07-12 18:46:06,764 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 4.0 (TID 8, 172.18.0.11, executor 0, partition 0, NODE_LOCAL, 7771 bytes)
2024-07-12 18:46:07,192 INFO storage.BlockManagerInfo: Added broadcast_8_piece0 in memory on 172.18.0.11:34825 (size: 3.9 KB, free: 166.7 MB)
2024-07-12 18:46:07,533 INFO spark.MapOutputTrackerMasterEndpoint: Asked to send map output locations for shuffle 0 to 172.18.0.11:39046
2024-07-12 18:46:08,440 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 4.0 (TID 8) in 1706 ms on 172.18.0.11 (executor 0) (1/1)
2024-07-12 18:46:08,450 INFO scheduler.TaskSchedulerImpl: Removed TaskSet 4.0, whose tasks have all completed, from pool
2024-07-12 18:46:08,459 INFO scheduler.DAGScheduler: ResultStage 4 (showString at NativeMethodAccessorImpl.java:0) finished in 1.860 s
2024-07-12 18:46:08,491 INFO scheduler.DAGScheduler: Job 3 finished: showString at NativeMethodAccessorImpl.java:0, took 5.402179 s
+------+--------+-------+------------+
|deptid|  nombre|salario|departamento|
+------+--------+-------+------------+
|    40|   Teddy|   3747|          HR|
|    40|     Ana|   3603|          HR|
|    40|   Naoko|   2698|          HR|
|    40|Danielle|   3613|          HR|
|    40|   Hanna|   2916|          HR|
|    40|   Barry|   2564|          HR|
|    40|    Kirk|   2304|          HR|
|    40|    Lili|   3233|          HR|
|    40|   Pablo|   2909|          HR|
|    40|  Miyako|   3705|          HR|
+------+--------+-------+------------+

2024-07-12 18:46:09,911 INFO codegen.CodeGenerator: Code generated in 82.912447 ms
2024-07-12 18:46:10,198 INFO codegen.CodeGenerator: Code generated in 208.140934 ms
+--------------------+
|           partition|
+--------------------+
|departamento=Acco...|
|     departamento=HR|
|departamento=Mark...|
|  departamento=Sales|
+--------------------+

2024-07-12 18:46:10,641 INFO spark.SparkContext: Invoking stop() from shutdown hook
2024-07-12 18:46:10,692 INFO server.AbstractConnector: Stopped Spark@a8ba4ff{HTTP/1.1,[http/1.1]}{0.0.0.0:4040}
2024-07-12 18:46:10,722 INFO ui.SparkUI: Stopped Spark web UI at http://spark-master:4040
2024-07-12 18:46:10,776 INFO cluster.StandaloneSchedulerBackend: Shutting down all executors
2024-07-12 18:46:10,783 INFO cluster.CoarseGrainedSchedulerBackend$DriverEndpoint: Asking each executor to shut down
2024-07-12 18:46:10,972 INFO spark.MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
2024-07-12 18:46:11,159 INFO memory.MemoryStore: MemoryStore cleared
2024-07-12 18:46:11,165 INFO storage.BlockManager: BlockManager stopped
2024-07-12 18:46:11,205 INFO storage.BlockManagerMaster: BlockManagerMaster stopped
2024-07-12 18:46:11,256 INFO scheduler.OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
2024-07-12 18:46:11,420 INFO spark.SparkContext: Successfully stopped SparkContext
2024-07-12 18:46:11,436 INFO util.ShutdownHookManager: Shutdown hook called
2024-07-12 18:46:11,496 INFO util.ShutdownHookManager: Deleting directory /tmp/spark-3665aebe-c582-4250-a49c-33c5810cb165
2024-07-12 18:46:11,538 INFO util.ShutdownHookManager: Deleting directory /tmp/spark-1410aba2-663d-4f26-94b3-8747231ddaf0/pyspark-e051a6df-282d-4a0d-a7c2-68793c231ef0
2024-07-12 18:46:11,711 INFO util.ShutdownHookManager: Deleting directory /tmp/spark-1410aba2-663d-4f26-94b3-8747231ddaf0
root@spark-master:/#

# %%
# Revisamos HDFS
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker exec -it spark-master bash
root@spark-master:/#
root@spark-master:/# hdfs dfs -ls /user/databases/db1/dept_partition
Found 4 items
drwxr-xr-x   - root supergroup          0 2024-07-12 18:45 /user/databases/db1/dept_partition/departamento=Accounts
drwxr-xr-x   - root supergroup          0 2024-07-12 18:46 /user/databases/db1/dept_partition/departamento=HR
drwxr-xr-x   - root supergroup          0 2024-07-12 18:46 /user/databases/db1/dept_partition/departamento=Marketing
drwxr-xr-x   - root supergroup          0 2024-07-12 18:45 /user/databases/db1/dept_partition/departamento=Sales
root@spark-master:/#
root@spark-master:/# hdfs dfs -ls /user/databases/db1/dept_partition/departamento=Accounts
Found 1 items
-rwxr-xr-x   3 root supergroup        888 2024-07-12 18:45 /user/databases/db1/dept_partition/departamento=Accounts/part-00000-f27024e8-9916-48a1-bddd-f499eee489a8.c000
root@spark-master:/#
root@spark-master:/# hdfs dfs -ls /user/databases/db1/dept_partition/departamento=HR
Found 1 items
-rwxr-xr-x   3 root supergroup        973 2024-07-12 18:45 /user/databases/db1/dept_partition/departamento=HR/part-00000-f27024e8-9916-48a1-bddd-f499eee489a8.c000
root@spark-master:/#
root@spark-master:/# hdfs dfs -ls /user/databases/db1/dept_partition/departamento=Marketing
Found 1 items
-rwxr-xr-x   3 root supergroup        954 2024-07-12 18:45 /user/databases/db1/dept_partition/departamento=Marketing/part-00000-f27024e8-9916-48a1-bddd-f499eee489a8.c000
root@spark-master:/#
root@spark-master:/# hdfs dfs -ls /user/databases/db1/dept_partition/departamento=Sales
Found 1 items
-rwxr-xr-x   3 root supergroup        888 2024-07-12 18:45 /user/databases/db1/dept_partition/departamento=Sales/part-00000-f27024e8-9916-48a1-bddd-f499eee489a8.c000
root@spark-master:/#
