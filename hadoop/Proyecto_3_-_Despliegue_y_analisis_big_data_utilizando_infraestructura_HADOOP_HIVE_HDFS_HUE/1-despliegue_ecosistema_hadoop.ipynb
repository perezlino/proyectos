# %% [markdown]
# ## **Despliegue de infraestructura de ecosistema `Hadoop` + `HDFS` + `Hive` + `Hue`**

# %% [markdown]
# ### **Introducción**

# %% [markdown]
# Este ecosistema esta conformado con los siguientes servicios:
#
# - `Hadoop`
# - `HDFS`
# - `Hive`
# - `Hue`

# %% [markdown]
# <center><img src="https://i.postimg.cc/Y9n644fm/p26.png"></center>

# %% [markdown]
# Para montar este ecosistema fue utilizado el material compartido por **https://github.com/juliopez/Hadoop**

# %% [markdown]
# ### **Despliegue de ecosistema `Hadoop` y `servicios` en Docker**

# %% [markdown]
# Desde el directorio donde tengo el archivo **`docker-compose.yml`** ejecuto el siguiente comando:

# %%
C:\Users\Alfonso> 

C:\Users\Alfonso>cd Documents

C:\Users\Alfonso\Documents>cd ecosistema-hadoop

C:\Users\Alfonso\Documents\ecosistema-hadoop-cluster>docker compose up

# %% [markdown]
# ### **Detener e Inicializar contenedores Docker con `servicios`**

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker compose stop
[+] Stopping 8/8
 ✔ Container hive-server                Stopped                                                                                                                   10.5s
 ✔ Container hue                        Stopped                                                                                                                    0.0s
 ✔ Container zeppelin                   Stopped                                                                                                                    0.0s
 ✔ Container database                   Stopped                                                                                                                    0.0s
 ✔ Container hive-metastore             Stopped                                                                                                                    0.9s
 ✔ Container hive-metastore-postgresql  Stopped                                                                                                                    0.4s
 ✔ Container datanode                   Stopped                                                                                                                   10.4s
 ✔ Container namenode                   Stopped                                                                                                                   10.5s

C:\Users\Alfonso\Documents\ecosistema-hadoop>docker ps
CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

C:\Users\Alfonso\Documents\ecosistema-hadoop>docker compose start
[+] Running 8/8
 ✔ Container namenode                   Started                                                                                                                    0.5s
 ✔ Container database                   Started                                                                                                                    0.6s
 ✔ Container zeppelin                   Started                                                                                                                    0.7s
 ✔ Container datanode                   Started                                                                                                                    0.7s
 ✔ Container hue                        Started                                                                                                                    0.7s
 ✔ Container hive-metastore-postgresql  Started                                                                                                                    0.5s
 ✔ Container hive-metastore             Started                                                                                                                    0.5s
 ✔ Container hive-server                Started                                                                                                                    0.5s

C:\Users\Alfonso\Documents\ecosistema-hadoop>docker ps -a
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker ps -ase start
CONTAINER ID   IMAGE                                             COMMAND                  CREATED        STATUS                     PORTS                                          NAMES
49df5e47f76a   bde2020/hive:2.3.2-postgresql-metastore           "entrypoint.sh /bin/…"   22 hours ago   Up 54 seconds              0.0.0.0:10000->10000/tcp, 10002/tcp            hive-server
9003155d6084   bde2020/hive:2.3.2-postgresql-metastore           "entrypoint.sh /opt/…"   22 hours ago   Up 54 seconds              10000/tcp, 0.0.0.0:9083->9083/tcp, 10002/tcp   hive-metastore
94719ea76fca   gethue/hue:20191107-135001                        "./startup.sh"           22 hours ago   Up 55 seconds              0.0.0.0:8888->8888/tcp                         hue
4b441ce9d355   bde2020/hive-metastore-postgresql:2.3.0           "/docker-entrypoint.…"   22 hours ago   Up 55 seconds              5432/tcp                                       hive-metastore-postgresql
50c838050046   bde2020/hadoop-datanode:2.0.0-hadoop2.7.4-java8   "/entrypoint.sh /run…"   22 hours ago   Up 55 seconds (healthy)    0.0.0.0:50075->50075/tcp                       datanode
d7c55458c7c0   mysql:5.7                                         "docker-entrypoint.s…"   22 hours ago   Up 56 seconds              33060/tcp, 0.0.0.0:33061->3306/tcp             database
f2648434bf70   apache/zeppelin:0.8.0                             "/usr/bin/tini -- bi…"   22 hours ago   Up 56 seconds              0.0.0.0:19090->8080/tcp                        zeppelin
52d0320b5821   bde2020/hadoop-namenode:2.0.0-hadoop2.7.4-java8   "/entrypoint.sh /run…"   22 hours ago   Up 56 seconds (healthy)    0.0.0.0:50070->50070/tcp                       namenode

C:\Users\Alfonso\Documents\ecosistema-hadoop>

# %% [markdown]
# ### **Revisión de interfaces de los servicios**

# %% [markdown]
# - **localhost:50070** (visualiza Hadoop y sus namenode)
# - **localhost:8888** (Hue solicitará la creación de una cuenta. Ingresamos `admin` como usuario y `admin` como password)

# %% [markdown]
# #### Namenode

# %% [markdown]
# <center><img src="https://i.postimg.cc/ZKsXDNDC/p27.png"></center>
# <center><img src="https://i.postimg.cc/4xKjC3rw/p28.png"></center>
# <center><img src="https://i.postimg.cc/qRrFCxgZ/p29.png"></center>

# %% [markdown]
# #### Hue

# %% [markdown]
# <center><img src="https://i.postimg.cc/cLV2dSWW/p30.png"></center>
# <center><img src="https://i.postimg.cc/rm9PGRry/p31.png"></center>

# %% [markdown]
# ### **Analizar el contenedor que alberga el namenode de Hadoop `namenode`**

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker exec -it namenode bash
root@52d0320b5821:/#
root@52d0320b5821:/# hdfs dfs -ls /
Found 2 items
drwx-wx-wx   - root supergroup          0 2024-05-23 17:18 /tmp
drwxr-xr-x   - root supergroup          0 2024-05-23 17:23 /user
root@52d0320b5821:/#
root@52d0320b5821:/# hdfs dfs -ls /user
Found 1 items
drwxr-xr-x   - root supergroup          0 2024-05-23 17:23 /user/hive
root@52d0320b5821:/#
root@52d0320b5821:/# hdfs dfs -ls /user/hive
Found 1 items
drwxrwxr-x   - root supergroup          0 2024-05-23 17:23 /user/hive/warehouse  # <------ Aqui es donde HIVE guarda los archivos de datos en HDFS
root@52d0320b5821:/#
root@52d0320b5821:/# hdfs dfs -ls /user/hive/warehouse
root@52d0320b5821:/#
root@52d0320b5821:/# exit
exit

What's next?
  Try Docker Debug for seamless, persistent debugging tools in any container or image → docker debug 52d0320b5821
  Learn more at https://docs.docker.com/go/debug-cli/

C:\Users\Alfonso\Documents\ecosistema-hadoop>

# %% [markdown]
# ### **Analizar el contenedor que alberga el metastoreDB de Hive `hive-metastore-postgresql`**

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker exec -it hive-metastore-postgresql bash
root@4b441ce9d355:/#
root@4b441ce9d355:/# psql -U postgres
psql (9.5.3)
Type "help" for help.

postgres=# \l
                                 List of databases
   Name    |  Owner   | Encoding |  Collate   |   Ctype    |   Access privileges
-----------+----------+----------+------------+------------+-----------------------
 metastore | postgres | UTF8     | en_US.utf8 | en_US.utf8 | =Tc/postgres         +
           |          |          |            |            | postgres=CTc/postgres+
           |          |          |            |            | hive=CTc/postgres
 postgres  | postgres | UTF8     | en_US.utf8 | en_US.utf8 |
 template0 | postgres | UTF8     | en_US.utf8 | en_US.utf8 | =c/postgres          +
           |          |          |            |            | postgres=CTc/postgres
 template1 | postgres | UTF8     | en_US.utf8 | en_US.utf8 | =c/postgres          +
           |          |          |            |            | postgres=CTc/postgres
(4 rows)

postgres=# \c metastore                                             # <------ En esta base de datos se almacenan los metadatos
You are now connected to database "metastore" as user "postgres".
metastore=# \dt
                   List of relations
 Schema |           Name            | Type  |  Owner
--------+---------------------------+-------+----------
 public | BUCKETING_COLS            | table | postgres
 public | CDS                       | table | postgres
 public | COLUMNS_V2                | table | postgres
 public | DATABASE_PARAMS           | table | postgres
 public | DBS                       | table | postgres
 public | DB_PRIVS                  | table | postgres
 public | DELEGATION_TOKENS         | table | postgres
 public | FUNCS                     | table | postgres
 public | FUNC_RU                   | table | postgres
 public | GLOBAL_PRIVS              | table | postgres
 public | IDXS                      | table | postgres
 public | INDEX_PARAMS              | table | postgres
 public | KEY_CONSTRAINTS           | table | postgres
 public | MASTER_KEYS               | table | postgres
 public | NOTIFICATION_LOG          | table | postgres
 public | NOTIFICATION_SEQUENCE     | table | postgres
 public | NUCLEUS_TABLES            | table | postgres
 public | PARTITIONS                | table | postgres
 public | PARTITION_EVENTS          | table | postgres
 public | PARTITION_KEYS            | table | postgres
 public | PARTITION_KEY_VALS        | table | postgres
 public | PARTITION_PARAMS          | table | postgres
 public | PART_COL_PRIVS            | table | postgres
 public | PART_COL_STATS            | table | postgres
 public | PART_PRIVS                | table | postgres
 public | ROLES                     | table | postgres
 public | ROLE_MAP                  | table | postgres
 public | SDS                       | table | postgres
 public | SD_PARAMS                 | table | postgres
 public | SEQUENCE_TABLE            | table | postgres
 public | SERDES                    | table | postgres
 public | SERDE_PARAMS              | table | postgres
 public | SKEWED_COL_NAMES          | table | postgres
 public | SKEWED_COL_VALUE_LOC_MAP  | table | postgres
 public | SKEWED_STRING_LIST        | table | postgres
 public | SKEWED_STRING_LIST_VALUES | table | postgres
 public | SKEWED_VALUES             | table | postgres
 public | SORT_COLS                 | table | postgres
 public | TABLE_PARAMS              | table | postgres
 public | TAB_COL_STATS             | table | postgres
metastore=#
metastore-# \q
root@4b441ce9d355:/# 
root@4b441ce9d355:/# exit
exit

What's next?
  Try Docker Debug for seamless, persistent debugging tools in any container or image → docker debug hive-metastore-postgresql
  Learn more at https://docs.docker.com/go/debug-cli/

C:\Users\Alfonso\Documents\ecosistema-hadoop>docker ps

# %% [markdown]
# ### **Analizar el contenedor que alberga el HiveServer `hive-server`**

# %% [markdown]
# Aqui es de donde accederemos a la consola de Hive:

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker exec -it 49df5e47f76a  bash
root@49df5e47f76a:/opt#
root@49df5e47f76a:/opt# cd /opt/hive/bin
root@49df5e47f76a:/opt/hive/bin#
root@49df5e47f76a:/opt/hive/bin# ls -l
total 40
-rwxr-xr-x 1 root staff  881 Nov  9  2017 beeline
drwxr-xr-x 3 root root  4096 Feb  5  2018 ext
-rwxr-xr-x 1 root staff 9838 Nov  9  2017 hive
-rwxr-xr-x 1 root staff 1900 Nov  9  2017 hive-config.sh
-rwxr-xr-x 1 root staff  885 Nov  9  2017 hiveserver2
-rwxr-xr-x 1 root staff  880 Nov  9  2017 hplsql
-rwxr-xr-x 1 root staff  832 Nov  9  2017 metatool
-rwxr-xr-x 1 root staff  884 Nov  9  2017 schematool
root@49df5e47f76a:/opt/hive/bin#
root@49df5e47f76a:/opt/hive/bin# ./beeline                  # <------ Accedemos a la consola "Beeline"
SLF4J: Class path contains multiple SLF4J bindings.
SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.6.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
SLF4J: Found binding in [jar:file:/opt/hadoop-2.7.4/share/hadoop/common/lib/slf4j-log4j12-1.7.10.jar!/org/slf4j/impl/StaticLoggerBinder.class]
SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
Beeline version 2.3.2 by Apache Hive
beeline>
beeline> !quit
root@49df5e47f76a:/opt/hive/bin#
root@49df5e47f76a:/opt/hive/bin# ./hive                  # <------ Accedemos a la consola "Hive"
SLF4J: Class path contains multiple SLF4J bindings.
SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.6.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
SLF4J: Found binding in [jar:file:/opt/hadoop-2.7.4/share/hadoop/common/lib/slf4j-log4j12-1.7.10.jar!/org/slf4j/impl/StaticLoggerBinder.class]
SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]

Logging initialized using configuration in file:/opt/hive/conf/hive-log4j2.properties Async: true
Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
hive>
hive> quit;
root@49df5e47f76a:/opt/hive/bin#
root@49df5e47f76a:/opt/hive/bin# exit
exit

What's next?
  Try Docker Debug for seamless, persistent debugging tools in any container or image → docker debug 49df5e47f76a
  Learn more at https://docs.docker.com/go/debug-cli/

C:\Users\Alfonso\Documents\ecosistema-hadoop>
