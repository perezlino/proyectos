# %% [markdown]
# ## **Movimiento de datos desde `Github` hacia `HDFS`**

# %% [markdown]
# <center><img src="https://i.postimg.cc/yNdy3RJS/p94.png"></center>

# %% [markdown]
# ### **`Paso 0`** - Instalación de **git** y **unzip**

# %%
# Instalación GIT
apt update
apt install git
git --version

# %%
C:\Users\Alfonso>docker exec -it namenode bash
root@namenode:/#
root@namenode:/# apt update
Hit:1 http://deb.debian.org/debian buster InRelease
Get:2 http://deb.debian.org/debian-security buster/updates InRelease [34.8 kB]
Hit:3 http://deb.debian.org/debian buster-updates InRelease
Get:4 http://deb.debian.org/debian-security buster/updates/main amd64 Packages [610 kB]
Fetched 645 kB in 2s (425 kB/s)
Reading package lists... Done
Building dependency tree
Reading state information... Done
2 packages can be upgraded. Run 'apt list --upgradable' to see them.
root@namenode:/#
root@namenode:/# apt install git
Reading package lists... Done
Building dependency tree
Reading state information... Done
The following additional packages will be installed:
  git-man less libbsd0 libcurl3-gnutls libedit2 liberror-perl libexpat1 libgdbm-compat4 libgdbm6 libperl5.28 libx11-6 libx11-data libxau6 libxcb1 libxdmcp6 libxext6
  libxmuu1 netbase openssh-client patch perl perl-modules-5.28 xauth
Suggested packages:
  gettext-base git-daemon-run | git-daemon-sysvinit git-doc git-el git-email git-gui gitk gitweb git-cvs git-mediawiki git-svn gdbm-l10n sensible-utils keychain
  libpam-ssh monkeysphere ssh-askpass ed diffutils-doc perl-doc libterm-readline-gnu-perl | libterm-readline-perl-perl make libb-debug-perl liblocale-codes-perl
The following NEW packages will be installed:
  git git-man less libbsd0 libcurl3-gnutls libedit2 liberror-perl libexpat1 libgdbm-compat4 libgdbm6 libperl5.28 libx11-6 libx11-data libxau6 libxcb1 libxdmcp6
  libxext6 libxmuu1 netbase openssh-client patch perl perl-modules-5.28 xauth
0 upgraded, 24 newly installed, 0 to remove and 2 not upgraded.
Need to get 17.5 MB of archives.
After this operation, 95.2 MB of additional disk space will be used.
Do you want to continue? [Y/n] y
Get:1 http://deb.debian.org/debian buster/main amd64 perl-modules-5.28 all 5.28.1-6+deb10u1 [2873 kB]
Get:2 http://deb.debian.org/debian buster/main amd64 libgdbm6 amd64 1.18.1-4 [64.7 kB]
Get:3 http://deb.debian.org/debian buster/main amd64 libgdbm-compat4 amd64 1.18.1-4 [44.1 kB]
Get:4 http://deb.debian.org/debian buster/main amd64 libperl5.28 amd64 5.28.1-6+deb10u1 [3894 kB]
Get:5 http://deb.debian.org/debian buster/main amd64 perl amd64 5.28.1-6+deb10u1 [204 kB]
Get:6 http://deb.debian.org/debian buster/main amd64 netbase all 5.6 [19.4 kB]
Get:7 http://deb.debian.org/debian-security buster/updates/main amd64 less amd64 487-0.1+deb10u1 [129 kB]
Get:8 http://deb.debian.org/debian buster/main amd64 libbsd0 amd64 0.9.1-2+deb10u1 [99.5 kB]
Get:9 http://deb.debian.org/debian buster/main amd64 libedit2 amd64 3.1-20181209-1 [94.0 kB]
Get:10 http://deb.debian.org/debian-security buster/updates/main amd64 openssh-client amd64 1:7.9p1-10+deb10u4 [785 kB]
Get:11 http://deb.debian.org/debian-security buster/updates/main amd64 libcurl3-gnutls amd64 7.64.0-4+deb10u9 [333 kB]
Get:12 http://deb.debian.org/debian-security buster/updates/main amd64 libexpat1 amd64 2.2.6-2+deb10u7 [108 kB]
Get:13 http://deb.debian.org/debian buster/main amd64 liberror-perl all 0.17027-2 [30.9 kB]
Get:14 http://deb.debian.org/debian-security buster/updates/main amd64 git-man all 1:2.20.1-2+deb10u9 [1624 kB]
Get:15 http://deb.debian.org/debian-security buster/updates/main amd64 git amd64 1:2.20.1-2+deb10u9 [5667 kB]
Get:16 http://deb.debian.org/debian buster/main amd64 libxau6 amd64 1:1.0.8-1+b2 [19.9 kB]
Get:17 http://deb.debian.org/debian buster/main amd64 libxdmcp6 amd64 1:1.1.2-3 [26.3 kB]
Get:18 http://deb.debian.org/debian buster/main amd64 libxcb1 amd64 1.13.1-2 [137 kB]
Get:19 http://deb.debian.org/debian-security buster/updates/main amd64 libx11-data all 2:1.6.7-1+deb10u4 [299 kB]
Get:20 http://deb.debian.org/debian-security buster/updates/main amd64 libx11-6 amd64 2:1.6.7-1+deb10u4 [758 kB]
Get:21 http://deb.debian.org/debian buster/main amd64 libxext6 amd64 2:1.3.3-1+b2 [52.5 kB]
Get:22 http://deb.debian.org/debian buster/main amd64 libxmuu1 amd64 2:1.1.2-2+b3 [23.9 kB]
Get:23 http://deb.debian.org/debian buster/main amd64 patch amd64 2.7.6-3+deb10u1 [126 kB]
Get:24 http://deb.debian.org/debian buster/main amd64 xauth amd64 1:1.0.10-1 [40.3 kB]
Fetched 17.5 MB in 9s (1911 kB/s)
debconf: unable to initialize frontend: Dialog
debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 24.)
debconf: falling back to frontend: Readline
debconf: unable to initialize frontend: Readline
debconf: (Cant locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC contains: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.28.1 /usr/local/share/perl/5.28.1 /usr/lib/x86_64-linux-gnu/perl5/5.28 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl/5.28 /usr/share/perl/5.28 /usr/local/lib/site_perl /usr/lib/x86_64-linux-gnu/perl-base) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 7, <> line 24.)
debconf: falling back to frontend: Teletype
Selecting previously unselected package perl-modules-5.28.
(Reading database ... 7214 files and directories currently installed.)
Preparing to unpack .../00-perl-modules-5.28_5.28.1-6+deb10u1_all.deb ...
Unpacking perl-modules-5.28 (5.28.1-6+deb10u1) ...
Selecting previously unselected package libgdbm6:amd64.
Preparing to unpack .../01-libgdbm6_1.18.1-4_amd64.deb ...
Unpacking libgdbm6:amd64 (1.18.1-4) ...
Selecting previously unselected package libgdbm-compat4:amd64.
Preparing to unpack .../02-libgdbm-compat4_1.18.1-4_amd64.deb ...
Unpacking libgdbm-compat4:amd64 (1.18.1-4) ...
Selecting previously unselected package libperl5.28:amd64.
Preparing to unpack .../03-libperl5.28_5.28.1-6+deb10u1_amd64.deb ...
Unpacking libperl5.28:amd64 (5.28.1-6+deb10u1) ...
Selecting previously unselected package perl.
Preparing to unpack .../04-perl_5.28.1-6+deb10u1_amd64.deb ...
Unpacking perl (5.28.1-6+deb10u1) ...
Selecting previously unselected package netbase.
Preparing to unpack .../05-netbase_5.6_all.deb ...
Unpacking netbase (5.6) ...
Selecting previously unselected package less.
Preparing to unpack .../06-less_487-0.1+deb10u1_amd64.deb ...
Unpacking less (487-0.1+deb10u1) ...
Selecting previously unselected package libbsd0:amd64.
Preparing to unpack .../07-libbsd0_0.9.1-2+deb10u1_amd64.deb ...
Unpacking libbsd0:amd64 (0.9.1-2+deb10u1) ...
Selecting previously unselected package libedit2:amd64.
Preparing to unpack .../08-libedit2_3.1-20181209-1_amd64.deb ...
Unpacking libedit2:amd64 (3.1-20181209-1) ...
Selecting previously unselected package openssh-client.
Preparing to unpack .../09-openssh-client_1%3a7.9p1-10+deb10u4_amd64.deb ...
Unpacking openssh-client (1:7.9p1-10+deb10u4) ...
Selecting previously unselected package libcurl3-gnutls:amd64.
Preparing to unpack .../10-libcurl3-gnutls_7.64.0-4+deb10u9_amd64.deb ...
Unpacking libcurl3-gnutls:amd64 (7.64.0-4+deb10u9) ...
Selecting previously unselected package libexpat1:amd64.
Preparing to unpack .../11-libexpat1_2.2.6-2+deb10u7_amd64.deb ...
Unpacking libexpat1:amd64 (2.2.6-2+deb10u7) ...
Selecting previously unselected package liberror-perl.
Preparing to unpack .../12-liberror-perl_0.17027-2_all.deb ...
Unpacking liberror-perl (0.17027-2) ...
Selecting previously unselected package git-man.
Preparing to unpack .../13-git-man_1%3a2.20.1-2+deb10u9_all.deb ...
Unpacking git-man (1:2.20.1-2+deb10u9) ...
Selecting previously unselected package git.
Preparing to unpack .../14-git_1%3a2.20.1-2+deb10u9_amd64.deb ...
Unpacking git (1:2.20.1-2+deb10u9) ...
Selecting previously unselected package libxau6:amd64.
Preparing to unpack .../15-libxau6_1%3a1.0.8-1+b2_amd64.deb ...
Unpacking libxau6:amd64 (1:1.0.8-1+b2) ...
Selecting previously unselected package libxdmcp6:amd64.
Preparing to unpack .../16-libxdmcp6_1%3a1.1.2-3_amd64.deb ...
Unpacking libxdmcp6:amd64 (1:1.1.2-3) ...
Selecting previously unselected package libxcb1:amd64.
Preparing to unpack .../17-libxcb1_1.13.1-2_amd64.deb ...
Unpacking libxcb1:amd64 (1.13.1-2) ...
Selecting previously unselected package libx11-data.
Preparing to unpack .../18-libx11-data_2%3a1.6.7-1+deb10u4_all.deb ...
Unpacking libx11-data (2:1.6.7-1+deb10u4) ...
Selecting previously unselected package libx11-6:amd64.
Preparing to unpack .../19-libx11-6_2%3a1.6.7-1+deb10u4_amd64.deb ...
Unpacking libx11-6:amd64 (2:1.6.7-1+deb10u4) ...
Selecting previously unselected package libxext6:amd64.
Preparing to unpack .../20-libxext6_2%3a1.3.3-1+b2_amd64.deb ...
Unpacking libxext6:amd64 (2:1.3.3-1+b2) ...
Selecting previously unselected package libxmuu1:amd64.
Preparing to unpack .../21-libxmuu1_2%3a1.1.2-2+b3_amd64.deb ...
Unpacking libxmuu1:amd64 (2:1.1.2-2+b3) ...
Selecting previously unselected package patch.
Preparing to unpack .../22-patch_2.7.6-3+deb10u1_amd64.deb ...
Unpacking patch (2.7.6-3+deb10u1) ...
Selecting previously unselected package xauth.
Preparing to unpack .../23-xauth_1%3a1.0.10-1_amd64.deb ...
Unpacking xauth (1:1.0.10-1) ...
Setting up perl-modules-5.28 (5.28.1-6+deb10u1) ...
Setting up libexpat1:amd64 (2.2.6-2+deb10u7) ...
Setting up libxau6:amd64 (1:1.0.8-1+b2) ...
Setting up less (487-0.1+deb10u1) ...
debconf: unable to initialize frontend: Dialog
debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
debconf: falling back to frontend: Readline
Setting up libcurl3-gnutls:amd64 (7.64.0-4+deb10u9) ...
Setting up libx11-data (2:1.6.7-1+deb10u4) ...
Setting up patch (2.7.6-3+deb10u1) ...
Setting up git-man (1:2.20.1-2+deb10u9) ...
Setting up netbase (5.6) ...
Setting up libbsd0:amd64 (0.9.1-2+deb10u1) ...
Setting up libgdbm6:amd64 (1.18.1-4) ...
Setting up libxdmcp6:amd64 (1:1.1.2-3) ...
Setting up libxcb1:amd64 (1.13.1-2) ...
Setting up libedit2:amd64 (3.1-20181209-1) ...
Setting up libgdbm-compat4:amd64 (1.18.1-4) ...
Setting up libperl5.28:amd64 (5.28.1-6+deb10u1) ...
Setting up libx11-6:amd64 (2:1.6.7-1+deb10u4) ...
Setting up libxmuu1:amd64 (2:1.1.2-2+b3) ...
Setting up openssh-client (1:7.9p1-10+deb10u4) ...
Setting up libxext6:amd64 (2:1.3.3-1+b2) ...
Setting up perl (5.28.1-6+deb10u1) ...
Setting up xauth (1:1.0.10-1) ...
Setting up liberror-perl (0.17027-2) ...
Setting up git (1:2.20.1-2+deb10u9) ...
Processing triggers for libc-bin (2.28-10+deb10u3) ...
root@namenode:/#
root@namenode:/# git --version
git version 2.20.1
root@namenode:/#

# %%
# Instalación UNZIP
apt update
apt install unzip
unzip -v

# %%
root@namenode:/# apt install unzip
Reading package lists... Done
Building dependency tree
Reading state information... Done
Suggested packages:
  zip
The following NEW packages will be installed:
  unzip
0 upgraded, 1 newly installed, 0 to remove and 2 not upgraded.
Need to get 172 kB of archives.
After this operation, 581 kB of additional disk space will be used.
Get:1 http://deb.debian.org/debian-security buster/updates/main amd64 unzip amd64 6.0-23+deb10u3 [172 kB]
Fetched 172 kB in 3s (59.8 kB/s)
debconf: unable to initialize frontend: Dialog
debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
debconf: falling back to frontend: Readline
Selecting previously unselected package unzip.
(Reading database ... 10528 files and directories currently installed.)
Preparing to unpack .../unzip_6.0-23+deb10u3_amd64.deb ...
Unpacking unzip (6.0-23+deb10u3) ...
Setting up unzip (6.0-23+deb10u3) ...
root@namenode:/#
root@namenode:/# unzip -v
UnZip 6.00 of 20 April 2009, by Debian. Original by Info-ZIP.

Latest sources and executables are at ftp://ftp.info-zip.org/pub/infozip/ ;
see ftp://ftp.info-zip.org/pub/infozip/UnZip.html for other sites.

Compiled with gcc 8.3.0 for Unix (Linux ELF).

UnZip special compilation options:
        ACORN_FTYPE_NFS
        COPYRIGHT_CLEAN (PKZIP 0.9x unreducing method not supported)
        SET_DIR_ATTRIB
        SYMLINKS (symbolic links supported, if RTL and file system permit)
        TIMESTAMP
        UNIXBACKUP
        USE_EF_UT_TIME
        USE_UNSHRINK (PKZIP/Zip 1.x unshrinking method supported)
        USE_DEFLATE64 (PKZIP 4.x Deflate64(tm) supported)
        UNICODE_SUPPORT [wide-chars, char coding: UTF-8] (handle UTF-8 paths)
        LARGE_FILE_SUPPORT (large files over 2 GiB supported)
        ZIP64_SUPPORT (archives using Zip64 for large files supported)
        USE_BZIP2 (PKZIP 4.6+, using bzip2 lib version 1.0.6, 6-Sept-2010)
        VMS_TEXT_CONV
        WILD_STOP_AT_DIR
        [decryption, version 2.11 of 05 Jan 2007]

UnZip and ZipInfo environment options:
           UNZIP:  [none]
        UNZIPOPT:  [none]
         ZIPINFO:  [none]
      ZIPINFOOPT:  [none]
root@namenode:/#

# %% [markdown]
# ### **`Paso 1`** - Obtener archivos de datos de Github a nuestro sistema Unix

# %%
git clone https://github.com/sibaramKumar/dataFiles

# %%
C:\Users\Alfonso>docker exec -it namenode bash
root@namenode:/#
root@namenode:/#
root@namenode:/# ls -l
total 108
drwxr-xr-x   1 root root 4096 Jul  3 15:49 bin
drwxr-xr-x   2 root root 4096 Mar 19  2022 boot
drwxr-xr-x   5 root root  340 Jul  3 15:46 dev
-rwxr-xr-x   1 root root  947 Jan 25  2023 entrypoint.sh
drwxr-xr-x   1 root root 4096 Jul  3 15:50 etc
drwxr-xr-x   1 root root 4096 Jul  3 15:46 hadoop
drwxr-xr-x   2 root root 4096 Jun 20 22:48 hadoop-data
drwxr-xr-x   2 root root 4096 Mar 19  2022 home
drwxr-xr-x   1 root root 4096 Jun 20 22:47 lib
drwxr-xr-x   1 root root 4096 Jun 20 22:46 lib64
drwxr-xr-x   2 root root 4096 Aug  1  2022 media
drwxr-xr-x   2 root root 4096 Aug  1  2022 mnt
drwxr-xr-x   1 root root 4096 Jun 20 22:47 opt
dr-xr-xr-x 230 root root    0 Jul  3 15:46 proc
drwx------   1 root root 4096 Aug  2  2022 root
drwxr-xr-x   3 root root 4096 Aug  1  2022 run
drwxr-xr-x   1 root root 4096 Jun 20 22:47 sbin
drwxr-xr-x   2 root root 4096 Aug  1  2022 srv
-rwxr-xr-x   1 root root  506 Jan 25  2023 start-namenode.sh
dr-xr-xr-x  11 root root    0 Jul  3 15:46 sys
drwxrwxrwt   1 root root 4096 Jul  3 15:50 tmp
drwxr-xr-x   1 root root 4096 Aug  1  2022 usr
drwxr-xr-x   1 root root 4096 Aug  1  2022 var
root@namenode:/#
root@namenode:/# cd hadoop-data
root@namenode:/hadoop-data#
root@namenode:/hadoop-data# git clone https://github.com/sibaramKumar/dataFiles
Cloning into 'dataFiles'...
remote: Enumerating objects: 19, done.
remote: Counting objects: 100% (19/19), done.
remote: Compressing objects: 100% (16/16), done.
remote: Total 19 (delta 1), reused 0 (delta 0), pack-reused 0
Unpacking objects: 100% (19/19), done.
root@namenode:/hadoop-data#
root@namenode:/hadoop-data# ls -l
total 4
drwxr-xr-x 3 root root 4096 Jul  3 15:51 dataFiles
root@namenode:/hadoop-data#
root@namenode:/hadoop-data# cd dataFiles
root@namenode:/hadoop-data/dataFiles#
root@namenode:/hadoop-data/dataFiles# ls -lrt
total 1452
-rw-r--r-- 1 root root 1484826 Jul  3 15:51 SalesData.zip
root@namenode:/hadoop-data/dataFiles#

# %% [markdown]
# ### **`Paso 2`** - Descomprimir los archivos

# %%
root@namenode:/hadoop-data/dataFiles# unzip SalesData.zip
Archive:  SalesData.zip
   creating: categories/
  inflating: categories/part-00000
   creating: customers/
  inflating: customers/part-00000
   creating: departments/
 extracting: departments/part-00000
   creating: orders/
  inflating: orders/part-00000
   creating: order_items/
  inflating: order_items/part-00000
   creating: products/
  inflating: products/part-00000
root@namenode:/hadoop-data/dataFiles#
root@namenode:/hadoop-data/dataFiles# ls -lrt
total 1476
drwxr-xr-x 2 root root    4096 Feb  4  2021 products
drwxr-xr-x 2 root root    4096 Feb  4  2021 orders
drwxr-xr-x 2 root root    4096 Feb  4  2021 order_items
drwxr-xr-x 2 root root    4096 Feb  4  2021 departments
drwxr-xr-x 2 root root    4096 Feb  4  2021 customers
drwxr-xr-x 2 root root    4096 Feb  4  2021 categories
-rw-r--r-- 1 root root 1484826 Jul  3 15:51 SalesData.zip
root@namenode:/hadoop-data/dataFiles#
root@namenode:/hadoop-data/dataFiles# rm SalesData.zip
root@namenode:/hadoop-data/dataFiles#
root@namenode:/hadoop-data/dataFiles# ls -lrt
total 24
drwxr-xr-x 2 root root 4096 Feb  4  2021 products
drwxr-xr-x 2 root root 4096 Feb  4  2021 orders
drwxr-xr-x 2 root root 4096 Feb  4  2021 order_items
drwxr-xr-x 2 root root 4096 Feb  4  2021 departments
drwxr-xr-x 2 root root 4096 Feb  4  2021 customers
drwxr-xr-x 2 root root 4096 Feb  4  2021 categories
root@namenode:/hadoop-data/dataFiles#

# %% [markdown]
# ### **`Paso 3`** - Crear una carpeta en HDFS

# %%
root@namenode:/hadoop-data/dataFiles# hdfs dfs -mkdir -p /practica/retail_db/
root@namenode:/hadoop-data/dataFiles#
root@namenode:/hadoop-data/dataFiles# hdfs dfs -ls /
Found 3 items
drwxr-xr-x   - root supergroup          0 2024-07-03 15:59 /practica
drwxr-xr-x   - root supergroup          0 2024-07-03 15:46 /tmp
drwxr-xr-x   - root supergroup          0 2024-07-03 15:56 /user
root@namenode:/hadoop-data/dataFiles#

# %% [markdown]
# ### **`Paso 4`** - Copiar los archivos de local a HDFS

# %%
root@namenode:/hadoop-data/dataFiles# hdfs dfs -put ./* /practica/retail_db/
root@namenode:/hadoop-data/dataFiles#
root@namenode:/hadoop-data/dataFiles# hdfs dfs -ls /practica/retail_db/
Found 6 items
drwxr-xr-x   - root supergroup          0 2024-07-03 15:59 /practica/retail_db/categories
drwxr-xr-x   - root supergroup          0 2024-07-03 15:59 /practica/retail_db/customers
drwxr-xr-x   - root supergroup          0 2024-07-03 15:59 /practica/retail_db/departments
drwxr-xr-x   - root supergroup          0 2024-07-03 15:59 /practica/retail_db/order_items
drwxr-xr-x   - root supergroup          0 2024-07-03 15:59 /practica/retail_db/orders
drwxr-xr-x   - root supergroup          0 2024-07-03 15:59 /practica/retail_db/products
root@namenode:/hadoop-data/dataFiles#
root@namenode:/hadoop-data/dataFiles# hdfs dfs -ls -R /practica/retail_db/
drwxr-xr-x   - root supergroup          0 2024-07-03 15:59 /practica/retail_db/categories
-rw-r--r--   3 root supergroup       1029 2024-07-03 15:59 /practica/retail_db/categories/part-00000
drwxr-xr-x   - root supergroup          0 2024-07-03 15:59 /practica/retail_db/customers
-rw-r--r--   3 root supergroup     953719 2024-07-03 15:59 /practica/retail_db/customers/part-00000
drwxr-xr-x   - root supergroup          0 2024-07-03 15:59 /practica/retail_db/departments
-rw-r--r--   3 root supergroup         60 2024-07-03 15:59 /practica/retail_db/departments/part-00000
drwxr-xr-x   - root supergroup          0 2024-07-03 15:59 /practica/retail_db/order_items
-rw-r--r--   3 root supergroup    5408880 2024-07-03 15:59 /practica/retail_db/order_items/part-00000
drwxr-xr-x   - root supergroup          0 2024-07-03 15:59 /practica/retail_db/orders
-rw-r--r--   3 root supergroup    2999944 2024-07-03 15:59 /practica/retail_db/orders/part-00000
drwxr-xr-x   - root supergroup          0 2024-07-03 15:59 /practica/retail_db/products
-rw-r--r--   3 root supergroup     174155 2024-07-03 15:59 /practica/retail_db/products/part-00000
root@namenode:/hadoop-data/dataFiles#

# %% [markdown]
# ### **`Extra`** - Descargar un archivo desde Github en el sistema local

# %% [markdown]
# Debemos visualizar el archivo en **RAW** y luego copiar su **URL**:

# %%
wget https://raw.githubusercontent.com/futurexskill/bigdata/master/retailstore.csv
