# %% [markdown]
# ## **Despliegue del proyecto**

# %% [markdown]
# Todo este despliegue se debe realizar en el **`spark-master`**

# %% [markdown]
# ### **`Paso 0`**: Instalación de **unzip**

# %%
apt update
apt install unzip

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker exec -it spark-master bash
root@spark-master:/#
root@spark-master:/# apt update          # <===================== Lanzamos el UPDATE
Hit:1 http://deb.debian.org/debian buster InRelease
Get:2 http://deb.debian.org/debian-security buster/updates InRelease [34.8 kB]
Hit:3 http://deb.debian.org/debian buster-updates InRelease
Get:4 http://deb.debian.org/debian-security buster/updates/main amd64 Packages [610 kB]
Fetched 645 kB in 1s (624 kB/s)
Reading package lists... Done
Building dependency tree
Reading state information... Done
2 packages can be upgraded. Run 'apt list --upgradable' to see them.
root@spark-master:/# 
root@spark-master:/# apt install unzip          # <===================== Instalacion de UNZIP
Reading package lists... Done
Building dependency tree
Reading state information... Done
Suggested packages:
  zip
The following NEW packages will be installed:
  unzip
0 upgraded, 1 newly installed, 0 to remove and 2 not upgraded.
Need to get 172 kB of archives.
After this operation, 581 kB of additional disk space will be used.
Get:1 http://deb.debian.org/debian-security buster/updates/main amd64 unzip amd64 6.0-23+deb10u3 [172 kB]
Fetched 172 kB in 0s (729 kB/s)
debconf: unable to initialize frontend: Dialog
debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
debconf: falling back to frontend: Readline
debconf: unable to initialize frontend: Readline
debconf: (Cant locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC contains: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.28.1 /usr/local/share/perl/5.28.1 /usr/lib/x86_64-linux-gnu/perl5/5.28 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl/5.28 /usr/share/perl/5.28 /usr/local/lib/site_perl /usr/lib/x86_64-linux-gnu/perl-base) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 7, <> line 1.)
debconf: falling back to frontend: Teletype
Selecting previously unselected package unzip.
(Reading database ... 7214 files and directories currently installed.)
Preparing to unpack .../unzip_6.0-23+deb10u3_amd64.deb ...
Unpacking unzip (6.0-23+deb10u3) ...
Setting up unzip (6.0-23+deb10u3) ...
root@spark-master:/#

# %% [markdown]
# ### **`Paso 1`**: Descomprimir archivos y otorgar permisos de ejecución

# %%
docker cp proyectos.zip spark-master:/ 
unzip proyectos.zip
chmod -R +x /proyectos/PrescPipeline/src/main/python/bin

# %%
# Subimos el proyecto comprimido en un archivo ZIP
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker cp proyectos.zip spark-master:/ 
Successfully copied 52.7MB to spark-master:/

C:\Users\Alfonso\Documents\ecosistema-hadoop>docker exec -it spark-master bash
root@spark-master:/#
root@spark-master:/# unzip proyectos.zip
Archive:  proyectos.zip
   creating: proyectos/
   creating: proyectos/PrescPipeline/
   creating: proyectos/PrescPipeline/src/
   creating: proyectos/PrescPipeline/src/main/
   creating: proyectos/PrescPipeline/src/main/python/
   creating: proyectos/PrescPipeline/src/main/python/bin/
  inflating: proyectos/PrescPipeline/src/main/python/bin/copiar_archivos_en_hdfs_a_local.ksh
  inflating: proyectos/PrescPipeline/src/main/python/bin/copiar_archivos_locales_a_azure.ksh
  inflating: proyectos/PrescPipeline/src/main/python/bin/copiar_archivos_locales_a_hdfs.ksh
  inflating: proyectos/PrescPipeline/src/main/python/bin/copiar_archivos_locales_a_s3.ksh
  inflating: proyectos/PrescPipeline/src/main/python/bin/create_database.py
  inflating: proyectos/PrescPipeline/src/main/python/bin/create_objects.py
  inflating: proyectos/PrescPipeline/src/main/python/bin/deploy_directorios.ksh
  inflating: proyectos/PrescPipeline/src/main/python/bin/deploy_proyecto_prescPipeline.ksh
  inflating: proyectos/PrescPipeline/src/main/python/bin/eliminar_rutas_output_hdfs.ksh
  inflating: proyectos/PrescPipeline/src/main/python/bin/get_all_variables.py
  inflating: proyectos/PrescPipeline/src/main/python/bin/presc_run_data_extraction.py
  inflating: proyectos/PrescPipeline/src/main/python/bin/presc_run_data_ingest.py
  inflating: proyectos/PrescPipeline/src/main/python/bin/presc_run_data_persist.py
  inflating: proyectos/PrescPipeline/src/main/python/bin/presc_run_data_preprocessing.py
  inflating: proyectos/PrescPipeline/src/main/python/bin/presc_run_data_transform.py
  inflating: proyectos/PrescPipeline/src/main/python/bin/run_presc_pipeline.py
  inflating: proyectos/PrescPipeline/src/main/python/bin/udfs.py
  inflating: proyectos/PrescPipeline/src/main/python/bin/validations.py
   creating: proyectos/PrescPipeline/src/main/python/lib/
   creating: proyectos/PrescPipeline/src/main/python/logs/
   creating: proyectos/PrescPipeline/src/main/python/sql/
   creating: proyectos/PrescPipeline/src/main/python/staging/
   creating: proyectos/PrescPipeline/src/main/python/staging/dimension_city/
  inflating: proyectos/PrescPipeline/src/main/python/staging/dimension_city/us_cities_dimension.parquet
   creating: proyectos/PrescPipeline/src/main/python/staging/fact/
  inflating: proyectos/PrescPipeline/src/main/python/staging/fact/USA_Presc_Medicare_Data_2021.csv
   creating: proyectos/PrescPipeline/src/main/python/unit_test/
  inflating: proyectos/PrescPipeline/src/main/python/unit_test/6.1 city_data_riverside.csv
  inflating: proyectos/PrescPipeline/src/main/python/unit_test/6.3 USA_Presc_Medicare_Data_2021.csv
  inflating: proyectos/PrescPipeline/src/main/python/unit_test/test_transformation_function.py
   creating: proyectos/PrescPipeline/src/main/python/util/
  inflating: proyectos/PrescPipeline/src/main/python/util/logging_to_file.conf
root@spark-master:/#
root@spark-master:/# cd /proyectos/PrescPipeline/src/main/python/bin
root@spark-master:/proyectos/PrescPipeline/src/main/python/bin#
root@spark-master:/proyectos/PrescPipeline/src/main/python/bin# ls -l
total 80
-rw-r--r-- 1 root root 1699 Jul 15 19:07 copiar_archivos_en_hdfs_a_local.ksh
-rw-r--r-- 1 root root 1857 Jul 15 13:01 copiar_archivos_locales_a_azure.ksh
-rw-r--r-- 1 root root 1579 Jul 17 20:09 copiar_archivos_locales_a_hdfs.ksh
-rw-r--r-- 1 root root 2085 Jul 15 12:10 copiar_archivos_locales_a_s3.ksh
-rw-r--r-- 1 root root 1314 Jul 17 21:14 create_database.py
-rw-r--r-- 1 root root 1601 Jul 11 13:45 create_objects.py
-rw-r--r-- 1 root root 1801 Jul 17 20:05 deploy_directorios.ksh
-rw-r--r-- 1 root root 4045 Jul 17 21:10 deploy_proyecto_prescPipeline.ksh
-rw-r--r-- 1 root root 2582 Jul 17 21:31 eliminar_rutas_output_hdfs.ksh
-rw-r--r-- 1 root root 2340 Jul 15 17:22 get_all_variables.py
-rw-r--r-- 1 root root  803 Jul 17 21:03 presc_run_data_extraction.py
-rw-r--r-- 1 root root 1683 Jul 17 20:02 presc_run_data_ingest.py
-rw-r--r-- 1 root root 2121 Jul 17 21:23 presc_run_data_persist.py
-rw-r--r-- 1 root root 4727 Jul 17 20:42 presc_run_data_preprocessing.py
-rw-r--r-- 1 root root 3836 Jul 17 20:57 presc_run_data_transform.py
-rw-r--r-- 1 root root 5283 Jul 17 21:21 run_presc_pipeline.py
-rw-r--r-- 1 root root  180 Feb 20  2022 udfs.py
-rw-r--r-- 1 root root 3721 Jul 17 20:24 validations.py
root@spark-master:/proyectos/PrescPipeline/src/main/python/bin# cd
root@spark-master:~# cd ..
root@spark-master:/#
root@spark-master:/# chmod -R +x /proyectos/PrescPipeline/src/main/python/bin
root@spark-master:/#
root@spark-master:/# cd /proyectos/PrescPipeline/src/main/python/bin
root@spark-master:/proyectos/PrescPipeline/src/main/python/bin#
root@spark-master:/proyectos/PrescPipeline/src/main/python/bin# ls -l
total 80
-rwxr-xr-x 1 root root 1699 Jul 15 19:07 copiar_archivos_en_hdfs_a_local.ksh
-rwxr-xr-x 1 root root 1857 Jul 15 13:01 copiar_archivos_locales_a_azure.ksh
-rwxr-xr-x 1 root root 1579 Jul 17 20:09 copiar_archivos_locales_a_hdfs.ksh
-rwxr-xr-x 1 root root 2085 Jul 15 12:10 copiar_archivos_locales_a_s3.ksh
-rwxr-xr-x 1 root root 1314 Jul 17 21:14 create_database.py
-rwxr-xr-x 1 root root 1601 Jul 11 13:45 create_objects.py
-rwxr-xr-x 1 root root 1801 Jul 17 20:05 deploy_directorios.ksh
-rwxr-xr-x 1 root root 4045 Jul 17 21:10 deploy_proyecto_prescPipeline.ksh
-rwxr-xr-x 1 root root 2582 Jul 17 21:31 eliminar_rutas_output_hdfs.ksh
-rwxr-xr-x 1 root root 2340 Jul 15 17:22 get_all_variables.py
-rwxr-xr-x 1 root root  803 Jul 17 21:03 presc_run_data_extraction.py
-rwxr-xr-x 1 root root 1683 Jul 17 20:02 presc_run_data_ingest.py
-rwxr-xr-x 1 root root 2121 Jul 17 21:23 presc_run_data_persist.py
-rwxr-xr-x 1 root root 4727 Jul 17 20:42 presc_run_data_preprocessing.py
-rwxr-xr-x 1 root root 3836 Jul 17 20:57 presc_run_data_transform.py
-rwxr-xr-x 1 root root 5283 Jul 17 21:21 run_presc_pipeline.py
-rwxr-xr-x 1 root root  180 Feb 20  2022 udfs.py
-rwxr-xr-x 1 root root 3721 Jul 17 20:24 validations.py
root@spark-master:/proyectos/PrescPipeline/src/main/python/bin#

# %% [markdown]
# ### **`Paso 2`**: Crear directorios locales output

# %% [markdown]
# Directorios que albergaran los archivos resultantes desde HDFS obtenidos del procesamiento de datos

# %%
mkdir -p /proyectos/PrescPipeline/src/main/python/output/dimension_city
mkdir -p /proyectos/PrescPipeline/src/main/python/output/presc

# %% [markdown]
# ### **`Paso 3`**: Descargar el jar `postgresql-42.2.23.jar`

# %% [markdown]
# Descargarlo en la ruta `/proyectos/PrescPipeline/src/main/python/lib/postgresql-42.2.23.jar`

# %%
cd /proyectos/PrescPipeline/src/main/python/lib
wget https://jdbc.postgresql.org/download/postgresql-42.2.23.jar
chmod -R +x /proyectos/PrescPipeline/src/main/python/lib

# %%
root@spark-master:/# cd /proyectos/PrescPipeline/src/main/python/lib
root@spark-master:/proyectos/PrescPipeline/src/main/python/lib#
root@spark-master:/proyectos/PrescPipeline/src/main/python/lib# wget https://jdbc.postgresql.org/download/postgresql-42.2.23.jar
--2024-07-18 01:50:21--  https://jdbc.postgresql.org/download/postgresql-42.2.23.jar
Resolving jdbc.postgresql.org (jdbc.postgresql.org)... 72.32.157.228, 2001:4800:3e1:1::228
Connecting to jdbc.postgresql.org (jdbc.postgresql.org)|72.32.157.228|:443... connected.
HTTP request sent, awaiting response... 200 OK
Length: 1005522 (982K) [application/java-archive]
Saving to: ‘postgresql-42.2.23.jar’

postgresql-42.2.23.jar         100%[==================================================>] 981.96K   276KB/s    in 3.6s

2024-07-18 01:50:27 (276 KB/s) - ‘postgresql-42.2.23.jar’ saved [1005522/1005522]

root@spark-master:/proyectos/PrescPipeline/src/main/python/lib# ls -l
total 984
-rw-r--r-- 1 root root 1005522 Sep  7  2022 postgresql-42.2.23.jar
root@spark-master:/proyectos/PrescPipeline/src/main/python/lib#
root@spark-master:/proyectos/PrescPipeline/src/main/python/lib# chmod -R +x /proyectos/PrescPipeline/src/main/python/lib
root@spark-master:/proyectos/PrescPipeline/src/main/python/lib# 
root@spark-master:/proyectos/PrescPipeline/src/main/python/lib# ls -l
total 984
-rwxr-xr-x 1 root root 1005522 Sep  7  2022 postgresql-42.2.23.jar
root@spark-master:/proyectos/PrescPipeline/src/main/python/lib#

# %% [markdown]
# ### **`Paso 4`**: Crear base de datos `prescpipeline` en Postgres

# %%
psql -U airflow --db postgres
CREATE DATABASE prescpipeline;
\c prescpipeline

# %%
C:\Users\Alfonso>docker exec -it postgres bash
bash-5.0#
bash-5.0# psql -U airflow --db postgres
psql (11.4)
Type "help" for help.

postgres=# CREATE DATABASE prescpipeline;
CREATE DATABASE
postgres=#
postgres=# \l
                                 List of databases
     Name      |  Owner  | Encoding |  Collate   |   Ctype    |  Access privileges
---------------+---------+----------+------------+------------+---------------------
 airflow_db    | airflow | UTF8     | en_US.utf8 | en_US.utf8 |
 metastore     | airflow | UTF8     | en_US.utf8 | en_US.utf8 | =Tc/airflow        +
               |         |          |            |            | airflow=CTc/airflow+
               |         |          |            |            | hive=CTc/airflow
 postgres      | airflow | UTF8     | en_US.utf8 | en_US.utf8 |
 prescpipeline | airflow | UTF8     | en_US.utf8 | en_US.utf8 |
 template0     | airflow | UTF8     | en_US.utf8 | en_US.utf8 | =c/airflow         +
               |         |          |            |            | airflow=CTc/airflow
 template1     | airflow | UTF8     | en_US.utf8 | en_US.utf8 | =c/airflow         +
               |         |          |            |            | airflow=CTc/airflow
(6 rows)

postgres=# \c prescpipeline
You are now connected to database "prescpipeline" as user "airflow".
prescpipeline=#
prescpipeline=#

# %% [markdown]
# ### **`Paso 5`**: Despliegue proyecto

# %%
# Indicando la ruta del archivo puedo ejecutar el script .ksh
root@spark-master:/proyectos/PrescPipeline/src/main/python/bin# ./deploy_proyecto_prescPipeline.ksh
root@spark-master:/#

# %% [markdown]
# ### **`Paso 6A`**: Copiar archivos a **AWS S3**

# %% [markdown]
# 1. Crear una cuenta gratis en AWS
# 2. Crear un Bucket S3 (Supongamos que viene dado por el cliente)
# 3. Instalar AWS CLI Clienten nuestro servidor local
# 4. Empujar los archivos a S3 utilizando comandos AWS CLI

# %% [markdown]
# Pasos para crear una cuenta gratuita en AWS:

# %% [markdown]
# <center><img src="https://i.postimg.cc/52ZDkVVT/p137.png"></center>
# <center><img src="https://i.postimg.cc/HxtKx8y1/p138.png"></center>

# %% [markdown]
# Pasos para crear un S3 Bucket:

# %% [markdown]
# <center><img src="https://i.postimg.cc/mk80d1Ly/p130.png"></center>
# <center><img src="https://i.postimg.cc/jd3pPfks/p131.png"></center>
# <center><img src="https://i.postimg.cc/VsgQspq0/p132.png"></center>
# <center><img src="https://i.postimg.cc/W1DQn4Q0/p133.png"></center>
# <center><img src="https://i.postimg.cc/LsLwcb4X/p135.png"></center>
# <center><img src="https://i.postimg.cc/tCg0skkS/p134.png"></center>
# <center><img src="https://i.postimg.cc/hjn6c1h0/p136.png"></center>

# %% [markdown]
# Pasos para instalar AWS CLI en Linux:

# %%
## Paso 1
### Descargar el archivo de instalación mediante el comando curl.
curl "https://awscli.amazonaws.com/awscli-exe-linux-x86_64.zip" -o "awscliv2.zip"

## Paso 2
### Descomprimir el instalador.
unzip awscliv2.zip

## Paso 3
### Ejecutar el programa de instalación
sudo ./aws/install

## Paso 4
### Confirmar la instalación
aws --version

# %% [markdown]
# Dijmos que el S3 Bucket ya venia dado por el cliente, por tanto ahora debemos acceder a él:

# %%
aws s3 ls s3://prescpipeline

# Unable to locate credentials. You can configure credentials by running  "aws configure"

# %% [markdown]
# Esto es porque necesitamos una "access key" y la "secret access key" para acceder al S3 Bucket. Una vez que tengamos las claves de acceso, podemos crear un perfil utilizando el comando "aws configure". Y entonces podremos acceder al bucket s3. Así que vayamos a la consola de aws y generemos las claves de acceso. Para generar las claves de acceso, necesitamos un servicio llamado IAM (Identity and access management)

# %% [markdown]
# <center><img src="https://i.postimg.cc/mkjyCQLB/p122.png"></center>
# <center><img src="https://i.postimg.cc/vZctxgpw/p123.png"></center>
# <center><img src="https://i.postimg.cc/dQjBbK8p/p124.png"></center>
# <center><img src="https://i.postimg.cc/pXVZx1CT/p125.png"></center>
# <center><img src="https://i.postimg.cc/jd8hjQ3h/p126.png"></center>
# <center><img src="https://i.postimg.cc/4xqb64g7/p127.png"></center>
# <center><img src="https://i.postimg.cc/nLmK08Fd/p128.png"></center>
# <center><img src="https://i.postimg.cc/cHNRzD6d/p129.png"></center>

# %% [markdown]
# Vamos a crear el perfil:

# %%
aws configure --profile myprofile

# Nos preguntará la AWS Access Key ID
# Nos preguntará la AWS Secret Access Key
# Nos preguntará la Default Region name (pulsamos ENTER y dejamos el que está por defecto)
# Nos preguntará el Output formar (pulsamos ENTER y dejamos el que está por defecto)

# %% [markdown]
# Ahora, usando el perfil, vamos a acceder al bucket S3. Como no obtenemos ningún error, significa que podemos acceder al bucket. Con esto, hemos instalado correctamente el cliente CLI en nuestro servidor local y también somos capaces de acceder al S3 bucket.

# %%
aws s3 --profile myprofile ls s3://prescpipeline

# %% [markdown]
# Ahora, vamos a utilizar el CLI client y empujar los archivos a S3 utilizando el script **`copiar_archivos_locales_a_s3.ksh`**

# %% [markdown]
# ### **`Paso 6B`**: Copiar archivos a **AZURE Blob Storage**

# %% [markdown]
# 1. Crear una cuenta gratis en Azure
# 2. Crear una cuetna de almacenamiento (Storage account) (Supongamos que viene dado por el cliente)
# 3. Instalar la linea de comandos de Azure **azycopy** en nuestro servidor local
# 4. Empujar los archivos a la Storage account utilizando **azcopy**

# %% [markdown]
# Pasos para crear una cuenta gratuita en AWS:

# %% [markdown]
# <center><img src="https://i.postimg.cc/DwvtM5sq/p139.png"></center>
# <center><img src="https://i.postimg.cc/gjb7qKmL/p140.png"></center>

# %% [markdown]
# Pasos para crear una Cuenta de almacenamiento (Storage account) y dos contenedores que albergaran los directorios con los archivos:

# %% [markdown]
# <center><img src="https://i.postimg.cc/Jzp9VJcS/p141.png"></center>
# <center><img src="https://i.postimg.cc/fbFpkNPK/p142.png"></center>
# <center><img src="https://i.postimg.cc/50CGCrdM/p143.png"></center>
# <center><img src="https://i.postimg.cc/PJbR6853/p144.png"></center>
# <center><img src="https://i.postimg.cc/c1f21PBR/p145.png"></center>
# <center><img src="https://i.postimg.cc/kXcHK8ZD/p146.png"></center>
# <center><img src="https://i.postimg.cc/0yXHHv9s/p147.png"></center>
# <center><img src="https://i.postimg.cc/SR4ZzNfW/p148.png"></center>
# <center><img src="https://i.postimg.cc/4NB8mG79/p149.png"></center>
# <center><img src="https://i.postimg.cc/QxX48CtD/p150.png"></center>

# %% [markdown]
# Pasos para instalar **azcopy** en Linux:

# %%
## Paso 1
### Verificamos si tenemos instalado azcopy
azcopy

## Paso 2
### Descargamos AzCopy
wget https://aka.ms/downloadazcopy-v10-linux

## Paso 3 
### Descomprimimos el archivo 
tar -xvf downloadazcopy-v10-linux

## Paso 4  
### Movemos AzCopy (ruta: ./azcopy_linux_amd64_10.14.1/azcopy) al destino donde queremos guardarlo
sudo cp ./azcopy_linux_amd64_*/azcopy /usr/bin/

## Paso 5
### Dar permiso para que podamos ejecutarlo sin sudo
sudo chmod 777 -R /usr/bin/azcopy   # (Si no estamos dentro de la ruta especifica)
sudo chmod 777 -R azcopy  # (Si estamos dentro de la ruta especifica)

# %% [markdown]
# Configuramos el **Access Policy** y las **SAS keys** para ambos contenedores:

# %% [markdown]
# Generamos ambas configuraciones apra el contenedor `dimension_city` y se repiten las mismas configuraciones para el contenedor `presc`. Finalizamos copiando ambos `Blob SAS URL`:
#
# <center><img src="https://i.postimg.cc/0yT2Vwjs/p151.png"></center>
# <center><img src="https://i.postimg.cc/Bv2ZknP1/p152.png"></center>
# <center><img src="https://i.postimg.cc/50349K34/p153.png"></center>
# <center><img src="https://i.postimg.cc/9MVXhHyg/p154.png"></center>
# <center><img src="https://i.postimg.cc/MHpWn0Py/p155.png"></center>
# <center><img src="https://i.postimg.cc/PfSXBcJK/p156.png"></center>
# <center><img src="https://i.postimg.cc/3J6Kwvgv/p157.png"></center>
# <center><img src="https://i.postimg.cc/NFCQmySZ/p158.png"></center>
# <center><img src="https://i.postimg.cc/sD1jycZz/p159.png"></center>

# %% [markdown]
# Ahora, vamos a utilizar el Azure CLI y empujar los archivos a los contenedores utilizando el script **`copiar_archivos_locales_a_azure.ksh`**
