# %% [markdown]
# ## **Despliegue solo en `HIVE`**

# %% [markdown]
# ### **`Paso 1` - Crear directorios que albergaran los archivos que utilizaremos para el despliegue de directorios en HDFS**

# %% [markdown]
# - El directorio "archivos" en la ruta `/hadoop-data/archivos`
# - El directorio "deploy" en la ruta `/hadoop-data/deploy`

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker exec -it namenode bash
root@namenode:/#
root@namenode:/# ls -l
total 108
drwxr-xr-x   1 root root 4096 Jun 20 22:47 bin
drwxr-xr-x   2 root root 4096 Mar 19  2022 boot
drwxr-xr-x   5 root root  340 Jun 24 17:17 dev
-rwxr-xr-x   1 root root  947 Jan 25  2023 entrypoint.sh
drwxr-xr-x   1 root root 4096 Jun 24 17:17 etc
drwxr-xr-x   1 root root 4096 Jun 24 17:17 hadoop
drwxr-xr-x   2 root root 4096 Jun 20 22:48 hadoop-data
drwxr-xr-x   2 root root 4096 Mar 19  2022 home
drwxr-xr-x   1 root root 4096 Jun 20 22:47 lib
drwxr-xr-x   1 root root 4096 Jun 20 22:46 lib64
drwxr-xr-x   2 root root 4096 Aug  1  2022 media
drwxr-xr-x   2 root root 4096 Aug  1  2022 mnt
drwxr-xr-x   1 root root 4096 Jun 20 22:47 opt
dr-xr-xr-x 251 root root    0 Jun 24 17:17 proc
drwx------   1 root root 4096 Aug  2  2022 root
drwxr-xr-x   3 root root 4096 Aug  1  2022 run
drwxr-xr-x   1 root root 4096 Jun 20 22:47 sbin
drwxr-xr-x   2 root root 4096 Aug  1  2022 srv
-rwxr-xr-x   1 root root  506 Jan 25  2023 start-namenode.sh
dr-xr-xr-x  11 root root    0 Jun 24 17:17 sys
drwxrwxrwt   1 root root 4096 Jun 24 17:18 tmp
drwxr-xr-x   1 root root 4096 Aug  1  2022 usr
drwxr-xr-x   1 root root 4096 Aug  1  2022 var
root@namenode:/# cd hadoop
root@namenode:/hadoop# ls -l
total 8
drwxr-xr-x 3 root root 4096 Jun 20 23:02 dfs
drwxr-xr-x 3 root root 4096 Jun 24 17:17 hdfs
root@namenode:/hadoop# cd ..
root@namenode:/# cd hadoop-data
root@namenode:/hadoop-data# ls -l
total 0
root@namenode:/hadoop-data# mkdir archivos  # <---------
root@namenode:/hadoop-data# ls -l
total 4
drwxr-xr-x 2 root root 4096 Jun 24 17:19 archivos
root@namenode:/hadoop-data# mkdir deploy  # <---------
root@namenode:/hadoop-data# ls -l
total 8
drwxr-xr-x 2 root root 4096 Jun 24 17:19 archivos
drwxr-xr-x 2 root root 4096 Jun 24 17:24 deploy
root@namenode:/hadoop-data# exit
exit

What's next?
  Try Docker Debug for seamless, persistent debugging tools in any container or image → docker debug namenode
  Learn more at https://docs.docker.com/go/debug-cli/

C:\Users\Alfonso\Documents\ecosistema-hadoop>

# %% [markdown]
# ### **`Paso 2` - Subir shemas al contenedor "namenode"**

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop>cd proyecto_1

C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>docker cp persona.avsc namenode:/hadoop-data/archivos
Successfully copied 2.05kB to namenode:/hadoop-data/archivos

C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>docker cp empresa.avsc namenode:/hadoop-data/archivos
Successfully copied 2.05kB to namenode:/hadoop-data/archivos

C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>docker cp transaccion.avsc namenode:/hadoop-data/archivos
Successfully copied 2.05kB to namenode:/hadoop-data/archivos

C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>docker cp deploy_directorios.sh namenode:/hadoop-data/deploy
Successfully copied 5.12kB to namenode:/hadoop-data/deploy

C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>docker exec -it namenode bash
root@namenode:/#
root@namenode:/# cd hadoop-data
root@namenode:/hadoop-data# ls -l
total 8
drwxr-xr-x 2 root root 4096 Jun 24 17:28 archivos
drwxr-xr-x 2 root root 4096 Jun 24 17:29 deploy
root@namenode:/hadoop-data# ls -l archivos
total 12
-rwxr-xr-x 1 root root 160 Feb 24  2020 empresa.avsc
-rwxr-xr-x 1 root root 498 Feb 24  2020 persona.avsc
-rwxr-xr-x 1 root root 226 Feb 24  2020 transaccion.avsc
root@namenode:/hadoop-data# ls -l deploy
total 4
-rwxr-xr-x 1 root root 3342 Jun 24 17:24 deploy_directorios.sh
root@namenode:/hadoop-data# cd deploy

# %% [markdown]
# ### **`Paso 3` - Subir archivos de datos al contenedor "namenode"**

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop>cd proyecto_1

C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>docker cp persona.data namenode:/hadoop-data/archivos
Successfully copied 9.22kB to namenode:/hadoop-data/archivos

C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>docker cp empresa.data namenode:/hadoop-data/archivos
Successfully copied 2.05kB to namenode:/hadoop-data/archivos

C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>docker cp transacciones.data namenode:/hadoop-data/archivos
Successfully copied 5.13MB to namenode:/hadoop-data/archivos

C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>docker exec -it namenode bash
root@namenode:/#
root@namenode:/# cd hadoop-data
root@namenode:/hadoop-data#
root@namenode:/hadoop-data# ls -l archivos
total 5036
-rwxr-xr-x 1 root root     160 Feb 24  2020 empresa.avsc
-rwxr-xr-x 1 root root     105 Jun 23  2018 empresa.data
-rwxr-xr-x 1 root root     498 Feb 24  2020 persona.avsc
-rwxr-xr-x 1 root root    7282 Jun 23  2018 persona.data
-rwxr-xr-x 1 root root     226 Feb 24  2020 transaccion.avsc
-rwxr-xr-x 1 root root 5129134 Dec 15  2018 transacciones.data
root@namenode:/hadoop-data#

# %% [markdown]
# ### **`Paso 4` - Despliegue de directorios en HDFS**

# %%
sh deploy_directorios.sh proyectos proyecto_1

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker exec -it namenode bash
root@namenode:/#
root@namenode:/# cd hadoop-data
root@namenode:/hadoop-data#
root@namenode:/hadoop-data# cd deploy
root@namenode:/hadoop-data/deploy#
root@namenode:/hadoop-data/deploy# sh deploy_directorios.sh proyectos proyecto_1
Eliminando carpeta raiz...
Deleted /user/proyectos/proyecto_1
Creando la estructura de carpetas para landing_tmp...
Creando la estructura de carpetas para landing...
Creando la estructura de carpetas para universal...
Creando la estructura de carpetas para smart...
Subiendo archivos de datos...
Subiendo archivos de schema...
root@namenode:/hadoop-data/deploy#
root@namenode:/hadoop-data/deploy# hdfs dfs -ls /
Found 2 items
drwxrwxr-x   - root supergroup          0 2024-06-24 17:20 /tmp
drwxr-xr-x   - root supergroup          0 2024-06-24 17:31 /user
root@namenode:/hadoop-data/deploy#
root@namenode:/hadoop-data/deploy# hdfs dfs -ls /user/proyectos/proyecto_1
Found 3 items
drwxr-xr-x   - root supergroup          0 2024-06-24 18:32 /user/proyectos/proyecto_1/archivos
drwxr-xr-x   - root supergroup          0 2024-06-24 18:32 /user/proyectos/proyecto_1/database
drwxr-xr-x   - root supergroup          0 2024-06-24 18:32 /user/proyectos/proyecto_1/schema
root@namenode:/hadoop-data/deploy#
root@namenode:/hadoop-data/deploy# hdfs dfs -ls /user/proyectos/proyecto_1/database
Found 4 items
drwxr-xr-x   - root supergroup          0 2024-06-24 18:31 /user/proyectos/proyecto_1/database/landing
drwxr-xr-x   - root supergroup          0 2024-06-24 18:31 /user/proyectos/proyecto_1/database/landing_tmp
drwxr-xr-x   - root supergroup          0 2024-06-24 18:32 /user/proyectos/proyecto_1/database/smart
drwxr-xr-x   - root supergroup          0 2024-06-24 18:32 /user/proyectos/proyecto_1/database/universal
root@namenode:/hadoop-data/deploy#
root@namenode:/hadoop-data/deploy# exit
exit

What's next?
  Try Docker Debug for seamless, persistent debugging tools in any container or image → docker debug namenode
  Learn more at https://docs.docker.com/go/debug-cli/

C:\Users\Alfonso\Documents\ecosistema-hadoop>

# %% [markdown]
# ### **`Paso 5` - Crear directorio que albergará archivos despliegue de bases de datos y tablas en el contenedor "hive-server"**

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>docker exec -it hive-server bash
root@hive-server:/opt#
root@hive-server:/opt# cd hive
root@hive-server:/opt/hive# 
root@hive-server:/opt/hive# mkdir deploy
root@hive-server:/opt/hive#
root@hive-server:/opt/hive# ls -l
total 76
-rw-r--r-- 1 root staff 20798 Aug 22  2019 LICENSE
-rw-r--r-- 1 root staff   230 Aug 22  2019 NOTICE
-rw-r--r-- 1 root staff  2469 Aug 22  2019 RELEASE_NOTES.txt
drwxr-xr-x 3 root root   4096 Jun 20 22:50 bin
drwxr-xr-x 2 root root   4096 Jun 20 22:50 binary-package-licenses
drwxr-xr-x 1 root root   4096 Jun 20 22:50 conf
drwxr-xr-x 2 root root   4096 Jun 24 18:00 deploy  # <--------
drwxr-xr-x 4 root root   4096 Jun 20 22:50 examples
drwxr-xr-x 7 root root   4096 Jun 20 22:50 hcatalog
drwxr-xr-x 2 root root   4096 Jun 20 22:50 jdbc
drwxr-xr-x 4 root root  12288 Jun 20 22:50 lib
drwxr-xr-x 4 root root   4096 Jun 20 22:50 scripts
root@hive-server:/opt/hive#
root@hive-server:/opt/hive# exit
exit

What's next?
  Try Docker Debug for seamless, persistent debugging tools in any container or image → docker debug hive-server
  Learn more at https://docs.docker.com/go/debug-cli/

C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>

# %% [markdown]
# ### **`Paso 6` - Subir archivos de despliegue de bases de datos y tablas al contenedor "hive-server"**

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>docker cp deploy_esquema_landing_tmp.sql hive-server:/opt/hive/deploy
Successfully copied 5.63kB to hive-server:/opt/hive/deploy

C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>docker cp deploy_esquema_landing.sql hive-server:/opt/hive/deploy
Successfully copied 4.61kB to hive-server:/opt/hive/deploy

C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>docker cp deploy_esquema_universal.sql hive-server:/opt/hive/deploy
Successfully copied 9.22kB to hive-server:/opt/hive/deploy

C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>docker cp deploy_esquema_smart.sql hive-server:/opt/hive/deploy
Successfully copied 5.12kB to hive-server:/opt/hive/deploy

C:\Users\Alfonso\Documents\ecosistema-hadoop\proyecto_1>docker exec -it hive-server bash
root@hive-server:/opt#
root@hive-server:/opt# cd /opt/hive/deploy
root@hive-server:/opt/hive/deploy#
root@hive-server:/opt/hive/deploy# ls -l
total 20
-rwxr-xr-x 1 root root 2878 Apr 24  2023 deploy_esquema_landing.sql
-rwxr-xr-x 1 root root 4044 Jun 24 17:57 deploy_esquema_landing_tmp.sql
-rwxr-xr-x 1 root root 3206 Apr 24  2023 deploy_esquema_smart.sql
-rwxr-xr-x 1 root root 7556 Jun 11 01:35 deploy_esquema_universal.sql
root@hive-server:/opt/hive/deploy#
root@hive-server:/opt/hive/deploy#

# %% [markdown]
# ### **`Paso 7` - Despliegue de esquemas de bases de datos y tablas**

# %% [markdown]
# #### Esquema `LANDING_TMP`

# %%
beeline -u jdbc:hive2://localhost:10000 -f /opt/hive/deploy/deploy_esquema_landing_tmp.sql --hiveconf "PARAM_RAIZ=proyectos" --hiveconf "PARAM_PROYECTO=proyecto_1"

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker exec -it hive-server bash
root@hive-server:/opt#
root@hive-server:/opt# cd hive
root@hive-server:/opt/hive#
root@hive-server:/opt/hive# cd bin
root@hive-server:/opt/hive/bin#
root@hive-server:/opt/hive/bin# beeline -u jdbc:hive2://localhost:10000 -f /opt/hive/deploy/deploy_esquema_landing_tmp.sql --hiveconf "PARAM_RAIZ=proyectos" --hiveconf "PARAM_PROYECTO=proyecto_1"
SLF4J: Class path contains multiple SLF4J bindings.
SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
Connecting to jdbc:hive2://localhost:10000
Connected to: Apache Hive (version 3.1.2)
Driver: Hive JDBC (version 3.1.2)
Transaction isolation: TRANSACTION_REPEATABLE_READ
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @author Alfonso Perez
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @email perezlino@gmail.com
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @copyright Alfonso Perez
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Despliegue del esquema "LANDING"
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @section Tuning
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET hive.execution.engine=mr;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.job.maps=8;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.input.fileinputformat.split.maxsize=128000000;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.input.fileinputformat.split.minsize=128000000;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.map.cpu.vcores=2;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.map.memory.mb=128;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.job.reduces=8;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.reduce.cpu.vcores=2;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.reduce.memory.mb=128;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET hive.exec.dynamic.partition=true;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET hive.exec.dynamic.partition.mode=nonstrict;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET hive.exec.max.dynamic.partitions=9999;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET hive.exec.max.dynamic.partitions.pernode=9999;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET hive.exec.compress.output=true;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET parquet.compression=SNAPPY;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET orc.compression=SNAPPY;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET avro.output.codec=SNAPPY;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapred.job.queue.name=q_user_main;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET spark.job.queue.name=q_user_main;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET tez.job.queue.name=q_user_main;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @section Programa
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Borrado de la base de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> DROP DATABASE IF EXISTS LANDING_TMP CASCADE;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624190130_b52abcd9-e8c8-41ae-a491-a57f7bb93392): DROP DATABASE IF EXISTS LANDING_TMP CASCADE
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624190130_b52abcd9-e8c8-41ae-a491-a57f7bb93392); Time taken: 0.141 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624190130_b52abcd9-e8c8-41ae-a491-a57f7bb93392): DROP DATABASE IF EXISTS LANDING_TMP CASCADE
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624190130_b52abcd9-e8c8-41ae-a491-a57f7bb93392); Time taken: 0.541 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query DROP DATABASE IF EXISTS LANDING_TMP CASCADE
No rows affected (0.798 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de la base de datos:
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE DATABASE IF NOT EXISTS LANDING_TMP
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION 'hdfs:///user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/database/landing_tmp';
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624190131_170afcc8-881b-4c6c-894f-67942b9216a7): CREATE DATABASE IF NOT EXISTS LANDING_TMP
LOCATION 'hdfs:///user/proyectos/proyecto_1/database/landing_tmp'
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624190131_170afcc8-881b-4c6c-894f-67942b9216a7); Time taken: 0.012 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624190131_170afcc8-881b-4c6c-894f-67942b9216a7): CREATE DATABASE IF NOT EXISTS LANDING_TMP
LOCATION 'hdfs:///user/proyectos/proyecto_1/database/landing_tmp'
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624190131_170afcc8-881b-4c6c-894f-67942b9216a7); Time taken: 0.03 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE DATABASE IF NOT EXISTS LANDING_TMP
LOCATION 'hdfs:///user/proyectos/proyecto_1/database/landing_tmp'
No rows affected (0.105 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Persona
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de la tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TABLE LANDING_TMP.PERSONA(
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> NOMBRE STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TELEFONO STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> CORREO STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FECHA_INGRESO STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> EDAD STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SALARIO STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID_EMPRESA STRING
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> )
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ROW FORMAT DELIMITED
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FIELDS TERMINATED BY '|'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LINES TERMINATED BY '\n'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS TEXTFILE
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION 'hdfs:///user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/database/landing_tmp/persona';
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624190131_ecd1aa79-93fa-4de4-8487-f2e7ca9dea79): CREATE TABLE LANDING_TMP.PERSONA(
ID STRING,
NOMBRE STRING,
TELEFONO STRING,
CORREO STRING,
FECHA_INGRESO STRING,
EDAD STRING,
SALARIO STRING,
ID_EMPRESA STRING
)
ROW FORMAT DELIMITED
FIELDS TERMINATED BY '|'
LINES TERMINATED BY '\n'
STORED AS TEXTFILE
LOCATION 'hdfs:///user/proyectos/proyecto_1/database/landing_tmp/persona'
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624190131_ecd1aa79-93fa-4de4-8487-f2e7ca9dea79); Time taken: 0.043 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624190131_ecd1aa79-93fa-4de4-8487-f2e7ca9dea79): CREATE TABLE LANDING_TMP.PERSONA(
ID STRING,
NOMBRE STRING,
TELEFONO STRING,
CORREO STRING,
FECHA_INGRESO STRING,
EDAD STRING,
SALARIO STRING,
ID_EMPRESA STRING
)
ROW FORMAT DELIMITED
FIELDS TERMINATED BY '|'
LINES TERMINATED BY '\n'
STORED AS TEXTFILE
LOCATION 'hdfs:///user/proyectos/proyecto_1/database/landing_tmp/persona'
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624190131_ecd1aa79-93fa-4de4-8487-f2e7ca9dea79); Time taken: 0.134 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TABLE LANDING_TMP.PERSONA(
ID STRING,
NOMBRE STRING,
TELEFONO STRING,
CORREO STRING,
FECHA_INGRESO STRING,
EDAD STRING,
SALARIO STRING,
ID_EMPRESA STRING
)
ROW FORMAT DELIMITED
FIELDS TERMINATED BY '|'
LINES TERMINATED BY '\n'
STORED AS TEXTFILE
LOCATION 'hdfs:///user/proyectos/proyecto_1/database/landing_tmp/persona'
No rows affected (0.24 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Subida de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> LOAD DATA INPATH '/user/proyectos/proyecto_1/archivos/persona.data' INTO TABLE LANDING_TMP.PERSONA;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624190131_bfb9124a-433a-474f-8c8d-c5f043114042): LOAD DATA INPATH '/user/proyectos/proyecto_1/archivos/persona.data' INTO TABLE LANDING_TMP.PERSONA
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624190131_bfb9124a-433a-474f-8c8d-c5f043114042); Time taken: 0.077 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624190131_bfb9124a-433a-474f-8c8d-c5f043114042): LOAD DATA INPATH '/user/proyectos/proyecto_1/archivos/persona.data' INTO TABLE LANDING_TMP.PERSONA
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table landing_tmp.persona from hdfs://namenode:9000/user/proyectos/proyecto_1/archivos/persona.data
INFO  : Starting task [Stage-1:STATS] in serial mode
INFO  : Completed executing command(queryId=root_20240624190131_bfb9124a-433a-474f-8c8d-c5f043114042); Time taken: 0.241 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query LOAD DATA INPATH '/user/proyectos/proyecto_1/archivos/persona.data' INTO TABLE LANDING_TMP.PERSONA
No rows affected (0.359 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM LANDING_TMP.PERSONA LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624190132_51129f24-2def-4b6b-a27e-29485355f135): SELECT * FROM LANDING_TMP.PERSONA LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:persona.id, type:string, comment:null), FieldSchema(name:persona.nombre, type:string, comment:null), FieldSchema(name:persona.telefono, type:string, comment:null), FieldSchema(name:persona.correo, type:string, comment:null), FieldSchema(name:persona.fecha_ingreso, type:string, comment:null), FieldSchema(name:persona.edad, type:string, comment:null), FieldSchema(name:persona.salario, type:string, comment:null), FieldSchema(name:persona.id_empresa, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624190132_51129f24-2def-4b6b-a27e-29485355f135); Time taken: 0.252 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624190132_51129f24-2def-4b6b-a27e-29485355f135): SELECT * FROM LANDING_TMP.PERSONA LIMIT 10
INFO  : Completed executing command(queryId=root_20240624190132_51129f24-2def-4b6b-a27e-29485355f135); Time taken: 0.001 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM LANDING_TMP.PERSONA LIMIT 10
+-------------+-----------------+-------------------+-----------------------------------------+------------------------+---------------+------------------+---------------------+
| persona.id  | persona.nombre  | persona.telefono  |             persona.correo              | persona.fecha_ingreso  | persona.edad  | persona.salario  | persona.id_empresa  |
+-------------+-----------------+-------------------+-----------------------------------------+------------------------+---------------+------------------+---------------------+
| ID          | NOMBRE          | TELEFONO          | CORREO                                  | FECHA_INGRESO          | EDAD          | SALARIO          | ID_EMPRESA          |
| 1           | Carl            | 1-745-633-9145    | arcu.Sed.et@ante.co.uk                  | 2004-04-23             | 32            | 20095            | 5                   |
| 2           | Priscilla       | 155-2498          | Donec.egestas.Aliquam@volutpatnunc.edu  | 2019-02-17             | 34            | 9298             | 2                   |
| 3           | Jocelyn         | 1-204-956-8594    | amet.diam@lobortis.co.uk                | 2002-08-01             | 27            | 10853            | 3                   |
| 4           | Aidan           | 1-719-862-9385    | euismod.et.commodo@nibhlaciniaorci.edu  | 2018-11-06             | 29            | 3387             | 10                  |
| 5           | Leandra         | 839-8044          | at@pretiumetrutrum.com                  | 2002-10-10             | 41            | 22102            | 1                   |
| 6           | Bert            | 797-4453          | a.felis.ullamcorper@arcu.org            | 2017-04-25             | 70            | 7800             | 7                   |
| 7           | Mark            | 1-680-102-6792    | Quisque.ac@placerat.ca                  | 2006-04-21             | 52            | 8112             | 5                   |
| 8           | Jonah           | 214-2975          | eu.ultrices.sit@vitae.ca                | 2017-10-07             | 23            | 17040            | 5                   |
| 9           | Hanae           | 935-2277          | eu@Nunc.ca                              | 2003-05-25             | 69            | 6834             | 3                   |
+-------------+-----------------+-------------------+-----------------------------------------+------------------------+---------------+------------------+---------------------+
10 rows selected (0.385 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Empresa
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TABLE LANDING_TMP.EMPRESA(
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> NOMBRE STRING
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> )
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ROW FORMAT DELIMITED
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FIELDS TERMINATED BY '|'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LINES TERMINATED BY '\n'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS TEXTFILE
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION 'hdfs:///user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/database/landing_tmp/empresa';
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624190132_7b974416-8cd6-46ed-9eae-a0024b731d84): CREATE TABLE LANDING_TMP.EMPRESA(
ID STRING,
NOMBRE STRING
)
ROW FORMAT DELIMITED
FIELDS TERMINATED BY '|'
LINES TERMINATED BY '\n'
STORED AS TEXTFILE
LOCATION 'hdfs:///user/proyectos/proyecto_1/database/landing_tmp/empresa'
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624190132_7b974416-8cd6-46ed-9eae-a0024b731d84); Time taken: 0.014 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624190132_7b974416-8cd6-46ed-9eae-a0024b731d84): CREATE TABLE LANDING_TMP.EMPRESA(
ID STRING,
NOMBRE STRING
)
ROW FORMAT DELIMITED
FIELDS TERMINATED BY '|'
LINES TERMINATED BY '\n'
STORED AS TEXTFILE
LOCATION 'hdfs:///user/proyectos/proyecto_1/database/landing_tmp/empresa'
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624190132_7b974416-8cd6-46ed-9eae-a0024b731d84); Time taken: 0.082 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TABLE LANDING_TMP.EMPRESA(
ID STRING,
NOMBRE STRING
)
ROW FORMAT DELIMITED
FIELDS TERMINATED BY '|'
LINES TERMINATED BY '\n'
STORED AS TEXTFILE
LOCATION 'hdfs:///user/proyectos/proyecto_1/database/landing_tmp/empresa'
No rows affected (0.144 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Subida de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> LOAD DATA INPATH '/user/proyectos/proyecto_1/archivos/empresa.data' INTO TABLE LANDING_TMP.EMPRESA;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624190132_90378712-375d-472c-972d-85ce67dade8b): LOAD DATA INPATH '/user/proyectos/proyecto_1/archivos/empresa.data' INTO TABLE LANDING_TMP.EMPRESA
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624190132_90378712-375d-472c-972d-85ce67dade8b); Time taken: 0.057 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624190132_90378712-375d-472c-972d-85ce67dade8b): LOAD DATA INPATH '/user/proyectos/proyecto_1/archivos/empresa.data' INTO TABLE LANDING_TMP.EMPRESA
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table landing_tmp.empresa from hdfs://namenode:9000/user/proyectos/proyecto_1/archivos/empresa.data
INFO  : Starting task [Stage-1:STATS] in serial mode
INFO  : Completed executing command(queryId=root_20240624190132_90378712-375d-472c-972d-85ce67dade8b); Time taken: 0.321 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query LOAD DATA INPATH '/user/proyectos/proyecto_1/archivos/empresa.data' INTO TABLE LANDING_TMP.EMPRESA
No rows affected (0.411 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM LANDING_TMP.EMPRESA LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624190133_43a81302-924e-4866-87c6-d294852916b9): SELECT * FROM LANDING_TMP.EMPRESA LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:empresa.id, type:string, comment:null), FieldSchema(name:empresa.nombre, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624190133_43a81302-924e-4866-87c6-d294852916b9); Time taken: 0.386 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624190133_43a81302-924e-4866-87c6-d294852916b9): SELECT * FROM LANDING_TMP.EMPRESA LIMIT 10
INFO  : Completed executing command(queryId=root_20240624190133_43a81302-924e-4866-87c6-d294852916b9); Time taken: 0.001 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM LANDING_TMP.EMPRESA LIMIT 10
+-------------+-----------------+
| empresa.id  | empresa.nombre  |
+-------------+-----------------+
| ID          | NOMBRE          |
| 1           | Walmart         |
| 2           | Microsoft       |
| 3           | Apple           |
| 4           | Toyota          |
| 5           | Amazon          |
| 6           | Google          |
| 7           | Samsung         |
| 8           | HP              |
| 9           | IBM             |
+-------------+-----------------+
10 rows selected (0.501 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Transaccion
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TABLE LANDING_TMP.TRANSACCION(
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID_PERSONA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID_EMPRESA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> MONTO STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FECHA STRING
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> )
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ROW FORMAT DELIMITED
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FIELDS TERMINATED BY '|'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LINES TERMINATED BY '\n'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS TEXTFILE
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION 'hdfs:///user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/database/landing_tmp/transaccion';
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624190134_e2f3734a-fb9d-43b0-ae93-4b3bd1d4cfe5): CREATE TABLE LANDING_TMP.TRANSACCION(
ID_PERSONA STRING,
ID_EMPRESA STRING,
MONTO STRING,
FECHA STRING
)
ROW FORMAT DELIMITED
FIELDS TERMINATED BY '|'
LINES TERMINATED BY '\n'
STORED AS TEXTFILE
LOCATION 'hdfs:///user/proyectos/proyecto_1/database/landing_tmp/transaccion'
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624190134_e2f3734a-fb9d-43b0-ae93-4b3bd1d4cfe5); Time taken: 0.03 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624190134_e2f3734a-fb9d-43b0-ae93-4b3bd1d4cfe5): CREATE TABLE LANDING_TMP.TRANSACCION(
ID_PERSONA STRING,
ID_EMPRESA STRING,
MONTO STRING,
FECHA STRING
)
ROW FORMAT DELIMITED
FIELDS TERMINATED BY '|'
LINES TERMINATED BY '\n'
STORED AS TEXTFILE
LOCATION 'hdfs:///user/proyectos/proyecto_1/database/landing_tmp/transaccion'
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624190134_e2f3734a-fb9d-43b0-ae93-4b3bd1d4cfe5); Time taken: 0.158 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TABLE LANDING_TMP.TRANSACCION(
ID_PERSONA STRING,
ID_EMPRESA STRING,
MONTO STRING,
FECHA STRING
)
ROW FORMAT DELIMITED
FIELDS TERMINATED BY '|'
LINES TERMINATED BY '\n'
STORED AS TEXTFILE
LOCATION 'hdfs:///user/proyectos/proyecto_1/database/landing_tmp/transaccion'
No rows affected (0.346 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Subida de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> LOAD DATA INPATH '/user/proyectos/proyecto_1/archivos/transacciones.data' INTO TABLE LANDING_TMP.TRANSACCION;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624190134_398868c4-e800-4ab9-9dee-b7b73f8400ab): LOAD DATA INPATH '/user/proyectos/proyecto_1/archivos/transacciones.data' INTO TABLE LANDING_TMP.TRANSACCION
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624190134_398868c4-e800-4ab9-9dee-b7b73f8400ab); Time taken: 0.052 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624190134_398868c4-e800-4ab9-9dee-b7b73f8400ab): LOAD DATA INPATH '/user/proyectos/proyecto_1/archivos/transacciones.data' INTO TABLE LANDING_TMP.TRANSACCION
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table landing_tmp.transaccion from hdfs://namenode:9000/user/proyectos/proyecto_1/archivos/transacciones.data
INFO  : Starting task [Stage-1:STATS] in serial mode
INFO  : Completed executing command(queryId=root_20240624190134_398868c4-e800-4ab9-9dee-b7b73f8400ab); Time taken: 0.268 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query LOAD DATA INPATH '/user/proyectos/proyecto_1/archivos/transacciones.data' INTO TABLE LANDING_TMP.TRANSACCION
No rows affected (0.374 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM LANDING_TMP.TRANSACCION LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624190134_d0aee9d1-7858-4495-b91e-f91194064ea9): SELECT * FROM LANDING_TMP.TRANSACCION LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:transaccion.id_persona, type:string, comment:null), FieldSchema(name:transaccion.id_empresa, type:string, comment:null), FieldSchema(name:transaccion.monto, type:string, comment:null), FieldSchema(name:transaccion.fecha, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624190134_d0aee9d1-7858-4495-b91e-f91194064ea9); Time taken: 0.315 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624190134_d0aee9d1-7858-4495-b91e-f91194064ea9): SELECT * FROM LANDING_TMP.TRANSACCION LIMIT 10
INFO  : Completed executing command(queryId=root_20240624190134_d0aee9d1-7858-4495-b91e-f91194064ea9); Time taken: 0.001 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM LANDING_TMP.TRANSACCION LIMIT 10
+-------------------------+-------------------------+--------------------+--------------------+
| transaccion.id_persona  | transaccion.id_empresa  | transaccion.monto  | transaccion.fecha  |
+-------------------------+-------------------------+--------------------+--------------------+
| ID_PERSONA              | ID_EMPRESA              | MONTO              | FECHA              |
| 18                      | 3                       | 1383               | 2018-01-21         |
| 30                      | 6                       | 2331               | 2018-01-21         |
| 47                      | 2                       | 2280               | 2018-01-21         |
| 28                      | 1                       | 730                | 2018-01-21         |
| 91                      | 4                       | 3081               | 2018-01-21         |
| 74                      | 8                       | 2409               | 2018-01-21         |
| 41                      | 2                       | 3754               | 2018-01-22         |
| 42                      | 9                       | 4079               | 2018-01-22         |
| 24                      | 6                       | 4475               | 2018-01-22         |
+-------------------------+-------------------------+--------------------+--------------------+
10 rows selected (0.429 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>                                    --    --------------------------------------------
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>                                    --    EJECUCION DE SCRIPTS DE SOLUCION POR CONSOLA
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>                                    --    --------------------------------------------
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Utilizar este comando para ejecutar script sql en mi estorno de Hadoop personal
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --      ___________________________________________________________________________________________________________________________________________
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --     |                                                                                                                                           |
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --     |   beeline -u jdbc:hive2://localhost:10000 -f /home/main/proceso_1.sql --hiveconf "PARAM_RAIZ=XXXX" --hiveconf "PARAM_PROYECTO=XXXX"       |
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --     |___________________________________________________________________________________________________________________________________________|
0: jdbc:hive2://localhost:10000> Closing: 0: jdbc:hive2://localhost:10000
root@hive-server:/opt/hive/bin#

# %% [markdown]
# #### Esquema `LANDING`

# %%
beeline -u jdbc:hive2://localhost:10000 -f /opt/hive/deploy/deploy_esquema_landing.sql --hiveconf "PARAM_RAIZ=proyectos" --hiveconf "PARAM_PROYECTO=proyecto_1"

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker exec -it hive-server bash
root@hive-server:/opt#
root@hive-server:/opt# cd hive
root@hive-server:/opt#
root@hive-server:/opt/hive# cd bin
root@hive-server:/opt#
root@hive-server:/opt/hive/bin# beeline -u jdbc:hive2://localhost:10000 -f /opt/hive/deploy/deploy_esquema_landing.sql --hiveconf "PARAM_RAIZ=proyectos" --hiveconf "PARAM_PROYECTO=proyecto_1"
SLF4J: Class path contains multiple SLF4J bindings.
SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
Connecting to jdbc:hive2://localhost:10000
Connected to: Apache Hive (version 3.1.2)
Driver: Hive JDBC (version 3.1.2)
Transaction isolation: TRANSACTION_REPEATABLE_READ
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @author Alfonso Perez
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @email perezlino@gmail.com
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @copyright Alfonso Perez
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Despliegue del esquema "LANDING"
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @section Tuning
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET hive.execution.engine=mr;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.job.maps=8;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.input.fileinputformat.split.maxsize=128000000;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.input.fileinputformat.split.minsize=128000000;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.map.cpu.vcores=2;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.map.memory.mb=128;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.job.reduces=8;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.reduce.cpu.vcores=2;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.reduce.memory.mb=128;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET hive.exec.dynamic.partition=true;    # <------- Activado en "true" por defecto desde Hive 0.14.0
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SET hive.exec.dynamic.partition.mode=nonstrict;
No rows affected (0.181 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET hive.exec.max.dynamic.partitions=9999;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET hive.exec.max.dynamic.partitions.pernode=9999;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SET hive.exec.compress.output=true;
No rows affected (0.015 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET parquet.compression=SNAPPY;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET orc.compression=SNAPPY;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SET avro.output.codec=snappy;
No rows affected (0.014 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.job.queue.name=q_user_main;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET spark.job.queue.name=q_user_main;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET tez.job.queue.name=q_user_main;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @section Programa
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Borrado de la base de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> DROP DATABASE IF EXISTS LANDING CASCADE;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624204725_2011e429-eb79-460c-b506-7374186b3218): DROP DATABASE IF EXISTS LANDING CASCADE
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624204725_2011e429-eb79-460c-b506-7374186b3218); Time taken: 0.102 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624204725_2011e429-eb79-460c-b506-7374186b3218): DROP DATABASE IF EXISTS LANDING CASCADE
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624204725_2011e429-eb79-460c-b506-7374186b3218); Time taken: 0.352 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query DROP DATABASE IF EXISTS LANDING CASCADE
No rows affected (0.472 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de la base de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- en LOCATION podemos indicar solo la ruta: "/user/..." o anteponer el "hdfs:///user/..."
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE DATABASE IF NOT EXISTS LANDING
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION '/user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/database/landing';
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624204725_e8ab5cdc-76ec-4282-a600-6abec8b9f053): CREATE DATABASE IF NOT EXISTS LANDING
LOCATION '/user/proyectos/proyecto_1/database/landing'
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624204725_e8ab5cdc-76ec-4282-a600-6abec8b9f053); Time taken: 0.004 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624204725_e8ab5cdc-76ec-4282-a600-6abec8b9f053): CREATE DATABASE IF NOT EXISTS LANDING
LOCATION '/user/proyectos/proyecto_1/database/landing'
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624204725_e8ab5cdc-76ec-4282-a600-6abec8b9f053); Time taken: 0.041 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE DATABASE IF NOT EXISTS LANDING
LOCATION '/user/proyectos/proyecto_1/database/landing'
No rows affected (0.073 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Persona
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de la tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- en LOCATION podemos indicar solo la ruta: "/user/..." o anteponer el "hdfs:///user/..."
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TABLE LANDING.PERSONA
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS AVRO
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION '/user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/database/landing/persona'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TBLPROPERTIES (
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> 'avro.schema.url'='hdfs:///user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/schema/landing/persona.avsc',
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> 'avro.output.codec'='snappy'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> );
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624204725_f6d5303e-68b6-4c47-b18e-3e170ea32987): CREATE TABLE LANDING.PERSONA
STORED AS AVRO
LOCATION '/user/proyectos/proyecto_1/database/landing/persona'
TBLPROPERTIES (
'avro.schema.url'='hdfs:///user/proyectos/proyecto_1/schema/landing/persona.avsc',
'avro.output.codec'='snappy'
)
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624204725_f6d5303e-68b6-4c47-b18e-3e170ea32987); Time taken: 0.01 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624204725_f6d5303e-68b6-4c47-b18e-3e170ea32987): CREATE TABLE LANDING.PERSONA
STORED AS AVRO
LOCATION '/user/proyectos/proyecto_1/database/landing/persona'
TBLPROPERTIES (
'avro.schema.url'='hdfs:///user/proyectos/proyecto_1/schema/landing/persona.avsc',
'avro.output.codec'='snappy'
)
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624204725_f6d5303e-68b6-4c47-b18e-3e170ea32987); Time taken: 0.086 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TABLE LANDING.PERSONA
STORED AS AVRO
LOCATION '/user/proyectos/proyecto_1/database/landing/persona'
TBLPROPERTIES (
'avro.schema.url'='hdfs:///user/proyectos/proyecto_1/schema/landing/persona.avsc',
'avro.output.codec'='snappy'
)
No rows affected (0.126 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Inserción de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> INSERT OVERWRITE TABLE LANDING.PERSONA SELECT * FROM LANDING_TMP.PERSONA;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624204726_ece47973-80e2-4331-846e-f851a03c923e): INSERT OVERWRITE TABLE LANDING.PERSONA SELECT * FROM LANDING_TMP.PERSONA
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:persona.id, type:string, comment:null), FieldSchema(name:persona.nombre, type:string, comment:null), FieldSchema(name:persona.telefono, type:string, comment:null), FieldSchema(name:persona.correo, type:string, comment:null), FieldSchema(name:persona.fecha_ingreso, type:string, comment:null), FieldSchema(name:persona.edad, type:string, comment:null), FieldSchema(name:persona.salario, type:string, comment:null), FieldSchema(name:persona.id_empresa, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624204726_ece47973-80e2-4331-846e-f851a03c923e); Time taken: 0.474 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624204726_ece47973-80e2-4331-846e-f851a03c923e): INSERT OVERWRITE TABLE LANDING.PERSONA SELECT * FROM LANDING_TMP.PERSONA
WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
INFO  : Query ID = root_20240624204726_ece47973-80e2-4331-846e-f851a03c923e
INFO  : Total jobs = 3
INFO  : Launching Job 1 out of 3
INFO  : Starting task [Stage-1:MAPRED] in serial mode
INFO  : Number of reduce tasks determined at compile time: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0022 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0022 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0022
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0022
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0022/
INFO  : Starting Job = job_1719249550016_0022, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0022/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0022
INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 20:47:42,122 Stage-1 map = 0%,  reduce = 0%
INFO  : 2024-06-24 20:47:51,881 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 6.73 sec
INFO  : 2024-06-24 20:48:01,568 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 11.74 sec
INFO  : MapReduce Total cumulative CPU time: 11 seconds 740 msec
INFO  : Ended Job = job_1719249550016_0022
INFO  : Starting task [Stage-7:CONDITIONAL] in serial mode
INFO  : Stage-4 is selected by condition resolver.
INFO  : Stage-3 is filtered out by condition resolver.
INFO  : Stage-5 is filtered out by condition resolver.
INFO  : Starting task [Stage-4:MOVE] in serial mode
INFO  : Moving data to directory hdfs://namenode:9000/user/proyectos/proyecto_1/database/landing/persona/.hive-staging_hive_2024-06-24_20-47-26_015_7293367991451794678-2/-ext-10000 from hdfs://namenode:9000/user/proyectos/proyecto_1/database/landing/persona/.hive-staging_hive_2024-06-24_20-47-26_015_7293367991451794678-2/-ext-10002
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table landing.persona from hdfs://namenode:9000/user/proyectos/proyecto_1/database/landing/persona/.hive-staging_hive_2024-06-24_20-47-26_015_7293367991451794678-2/-ext-10000
INFO  : Starting task [Stage-2:STATS] in serial mode
INFO  : MapReduce Jobs Launched:
INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 11.74 sec   HDFS Read: 29534 HDFS Write: 9491 SUCCESS
INFO  : Total MapReduce CPU Time Spent: 11 seconds 740 msec
INFO  : Completed executing command(queryId=root_20240624204726_ece47973-80e2-4331-846e-f851a03c923e); Time taken: 38.307 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query INSERT OVERWRITE TABLE LANDING.PERSONA SELECT * FROM LANDING_TMP.PERSONA
No rows affected (38.812 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM LANDING.PERSONA LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624204804_531195bc-1bd4-4a96-bc15-79c8836c0d7d): SELECT * FROM LANDING.PERSONA LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:persona.id, type:string, comment:null), FieldSchema(name:persona.nombre, type:string, comment:null), FieldSchema(name:persona.telefono, type:string, comment:null), FieldSchema(name:persona.correo, type:string, comment:null), FieldSchema(name:persona.fecha_ingreso, type:string, comment:null), FieldSchema(name:persona.edad, type:string, comment:null), FieldSchema(name:persona.salario, type:string, comment:null), FieldSchema(name:persona.id_empresa, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624204804_531195bc-1bd4-4a96-bc15-79c8836c0d7d); Time taken: 0.388 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624204804_531195bc-1bd4-4a96-bc15-79c8836c0d7d): SELECT * FROM LANDING.PERSONA LIMIT 10
INFO  : Completed executing command(queryId=root_20240624204804_531195bc-1bd4-4a96-bc15-79c8836c0d7d); Time taken: 0.001 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM LANDING.PERSONA LIMIT 10
+-------------+-----------------+-------------------+-----------------------------------------+------------------------+---------------+------------------+---------------------+
| persona.id  | persona.nombre  | persona.telefono  |             persona.correo              | persona.fecha_ingreso  | persona.edad  | persona.salario  | persona.id_empresa  |
+-------------+-----------------+-------------------+-----------------------------------------+------------------------+---------------+------------------+---------------------+
| ID          | NOMBRE          | TELEFONO          | CORREO                                  | FECHA_INGRESO          | EDAD          | SALARIO          | ID_EMPRESA          |
| 1           | Carl            | 1-745-633-9145    | arcu.Sed.et@ante.co.uk                  | 2004-04-23             | 32            | 20095            | 5                   |
| 2           | Priscilla       | 155-2498          | Donec.egestas.Aliquam@volutpatnunc.edu  | 2019-02-17             | 34            | 9298             | 2                   |
| 3           | Jocelyn         | 1-204-956-8594    | amet.diam@lobortis.co.uk                | 2002-08-01             | 27            | 10853            | 3                   |
| 4           | Aidan           | 1-719-862-9385    | euismod.et.commodo@nibhlaciniaorci.edu  | 2018-11-06             | 29            | 3387             | 10                  |
| 5           | Leandra         | 839-8044          | at@pretiumetrutrum.com                  | 2002-10-10             | 41            | 22102            | 1                   |
| 6           | Bert            | 797-4453          | a.felis.ullamcorper@arcu.org            | 2017-04-25             | 70            | 7800             | 7                   |
| 7           | Mark            | 1-680-102-6792    | Quisque.ac@placerat.ca                  | 2006-04-21             | 52            | 8112             | 5                   |
| 8           | Jonah           | 214-2975          | eu.ultrices.sit@vitae.ca                | 2017-10-07             | 23            | 17040            | 5                   |
| 9           | Hanae           | 935-2277          | eu@Nunc.ca                              | 2003-05-25             | 69            | 6834             | 3                   |
+-------------+-----------------+-------------------+-----------------------------------------+------------------------+---------------+------------------+---------------------+
10 rows selected (0.529 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Empresa
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- en LOCATION podemos indicar solo la ruta: "/user/..." o anteponer el "hdfs:///user/..."
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TABLE LANDING.EMPRESA
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS AVRO
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION '/user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/database/landing/empresa'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TBLPROPERTIES (
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> 'avro.schema.url'='hdfs:///user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/schema/landing/empresa.avsc',
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> 'avro.output.codec'='snappy'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> );
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624204805_8cb3e354-517e-4ebb-b3c1-f30e07fd310f): CREATE TABLE LANDING.EMPRESA
STORED AS AVRO
LOCATION '/user/proyectos/proyecto_1/database/landing/empresa'
TBLPROPERTIES (
'avro.schema.url'='hdfs:///user/proyectos/proyecto_1/schema/landing/empresa.avsc',
'avro.output.codec'='snappy'
)
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624204805_8cb3e354-517e-4ebb-b3c1-f30e07fd310f); Time taken: 0.024 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624204805_8cb3e354-517e-4ebb-b3c1-f30e07fd310f): CREATE TABLE LANDING.EMPRESA
STORED AS AVRO
LOCATION '/user/proyectos/proyecto_1/database/landing/empresa'
TBLPROPERTIES (
'avro.schema.url'='hdfs:///user/proyectos/proyecto_1/schema/landing/empresa.avsc',
'avro.output.codec'='snappy'
)
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624204805_8cb3e354-517e-4ebb-b3c1-f30e07fd310f); Time taken: 0.106 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TABLE LANDING.EMPRESA
STORED AS AVRO
LOCATION '/user/proyectos/proyecto_1/database/landing/empresa'
TBLPROPERTIES (
'avro.schema.url'='hdfs:///user/proyectos/proyecto_1/schema/landing/empresa.avsc',
'avro.output.codec'='snappy'
)
No rows affected (0.166 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Inserción de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> INSERT OVERWRITE TABLE LANDING.EMPRESA SELECT * FROM LANDING_TMP.EMPRESA;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624204805_b6e7a372-e79e-4b6f-abde-1fba96ca0d3c): INSERT OVERWRITE TABLE LANDING.EMPRESA SELECT * FROM LANDING_TMP.EMPRESA
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:empresa.id, type:string, comment:null), FieldSchema(name:empresa.nombre, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624204805_b6e7a372-e79e-4b6f-abde-1fba96ca0d3c); Time taken: 0.487 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624204805_b6e7a372-e79e-4b6f-abde-1fba96ca0d3c): INSERT OVERWRITE TABLE LANDING.EMPRESA SELECT * FROM LANDING_TMP.EMPRESA
WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
INFO  : Query ID = root_20240624204805_b6e7a372-e79e-4b6f-abde-1fba96ca0d3c
INFO  : Total jobs = 3
INFO  : Launching Job 1 out of 3
INFO  : Starting task [Stage-1:MAPRED] in serial mode
INFO  : Number of reduce tasks determined at compile time: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0023 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0023 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0023
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0023
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0023/
INFO  : Starting Job = job_1719249550016_0023, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0023/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0023
INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 20:48:24,650 Stage-1 map = 0%,  reduce = 0%
INFO  : 2024-06-24 20:48:36,609 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 8.35 sec
INFO  : 2024-06-24 20:48:46,332 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 12.78 sec
INFO  : MapReduce Total cumulative CPU time: 12 seconds 780 msec
INFO  : Ended Job = job_1719249550016_0023
INFO  : Starting task [Stage-7:CONDITIONAL] in serial mode
INFO  : Stage-4 is selected by condition resolver.
INFO  : Stage-3 is filtered out by condition resolver.
INFO  : Stage-5 is filtered out by condition resolver.
INFO  : Starting task [Stage-4:MOVE] in serial mode
INFO  : Moving data to directory hdfs://namenode:9000/user/proyectos/proyecto_1/database/landing/empresa/.hive-staging_hive_2024-06-24_20-48-05_767_3347621707128275406-2/-ext-10000 from hdfs://namenode:9000/user/proyectos/proyecto_1/database/landing/empresa/.hive-staging_hive_2024-06-24_20-48-05_767_3347621707128275406-2/-ext-10002
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table landing.empresa from hdfs://namenode:9000/user/proyectos/proyecto_1/database/landing/empresa/.hive-staging_hive_2024-06-24_20-48-05_767_3347621707128275406-2/-ext-10000
INFO  : Starting task [Stage-2:STATS] in serial mode
INFO  : MapReduce Jobs Launched:
INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 12.78 sec   HDFS Read: 14497 HDFS Write: 719 SUCCESS
INFO  : Total MapReduce CPU Time Spent: 12 seconds 780 msec
INFO  : Completed executing command(queryId=root_20240624204805_b6e7a372-e79e-4b6f-abde-1fba96ca0d3c); Time taken: 42.578 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query INSERT OVERWRITE TABLE LANDING.EMPRESA SELECT * FROM LANDING_TMP.EMPRESA
No rows affected (43.089 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM LANDING.EMPRESA LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624204848_d82106db-0674-435f-9eb7-3784935e9410): SELECT * FROM LANDING.EMPRESA LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:empresa.id, type:string, comment:null), FieldSchema(name:empresa.nombre, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624204848_d82106db-0674-435f-9eb7-3784935e9410); Time taken: 0.468 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624204848_d82106db-0674-435f-9eb7-3784935e9410): SELECT * FROM LANDING.EMPRESA LIMIT 10
INFO  : Completed executing command(queryId=root_20240624204848_d82106db-0674-435f-9eb7-3784935e9410); Time taken: 0.001 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM LANDING.EMPRESA LIMIT 10
+-------------+-----------------+
| empresa.id  | empresa.nombre  |
+-------------+-----------------+
| ID          | NOMBRE          |
| 1           | Walmart         |
| 2           | Microsoft       |
| 3           | Apple           |
| 4           | Toyota          |
| 5           | Amazon          |
| 6           | Google          |
| 7           | Samsung         |
| 8           | HP              |
| 9           | IBM             |
+-------------+-----------------+
10 rows selected (0.714 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Transaccion
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- en LOCATION podemos indicar solo la ruta: "/user/..." o anteponer el "hdfs:///user/..."
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TABLE LANDING.TRANSACCION
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> PARTITIONED BY (FECHA STRING)
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS AVRO
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION '/user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/database/landing/transaccion'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TBLPROPERTIES (
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> 'avro.schema.url'='hdfs:///user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/schema/landing/transaccion.avsc',
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> 'avro.output.codec'='snappy'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> );
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624204849_a09871d5-d932-4434-9d57-74bbb2de3916): CREATE TABLE LANDING.TRANSACCION
PARTITIONED BY (FECHA STRING)
STORED AS AVRO
LOCATION '/user/proyectos/proyecto_1/database/landing/transaccion'
TBLPROPERTIES (
'avro.schema.url'='hdfs:///user/proyectos/proyecto_1/schema/landing/transaccion.avsc',
'avro.output.codec'='snappy'
)
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624204849_a09871d5-d932-4434-9d57-74bbb2de3916); Time taken: 0.02 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624204849_a09871d5-d932-4434-9d57-74bbb2de3916): CREATE TABLE LANDING.TRANSACCION
PARTITIONED BY (FECHA STRING)
STORED AS AVRO
LOCATION '/user/proyectos/proyecto_1/database/landing/transaccion'
TBLPROPERTIES (
'avro.schema.url'='hdfs:///user/proyectos/proyecto_1/schema/landing/transaccion.avsc',
'avro.output.codec'='snappy'
)
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624204849_a09871d5-d932-4434-9d57-74bbb2de3916); Time taken: 0.195 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TABLE LANDING.TRANSACCION
PARTITIONED BY (FECHA STRING)
STORED AS AVRO
LOCATION '/user/proyectos/proyecto_1/database/landing/transaccion'
TBLPROPERTIES (
'avro.schema.url'='hdfs:///user/proyectos/proyecto_1/schema/landing/transaccion.avsc',
'avro.output.codec'='snappy'
)
No rows affected (0.257 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Inserción de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> INSERT OVERWRITE TABLE LANDING.TRANSACCION
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> PARTITION(FECHA)
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SELECT * FROM  LANDING_TMP.TRANSACCION;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624204850_94e11449-0044-4d24-8b25-1ade444f045f): INSERT OVERWRITE TABLE LANDING.TRANSACCION
PARTITION(FECHA)
SELECT * FROM  LANDING_TMP.TRANSACCION
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:transaccion.id_persona, type:string, comment:null), FieldSchema(name:transaccion.id_empresa, type:string, comment:null), FieldSchema(name:transaccion.monto, type:string, comment:null), FieldSchema(name:transaccion.fecha, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624204850_94e11449-0044-4d24-8b25-1ade444f045f); Time taken: 0.558 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624204850_94e11449-0044-4d24-8b25-1ade444f045f): INSERT OVERWRITE TABLE LANDING.TRANSACCION
PARTITION(FECHA)
SELECT * FROM  LANDING_TMP.TRANSACCION
WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
INFO  : Query ID = root_20240624204850_94e11449-0044-4d24-8b25-1ade444f045f
INFO  : Total jobs = 3
INFO  : Launching Job 1 out of 3
INFO  : Starting task [Stage-1:MAPRED] in serial mode
INFO  : Number of reduce tasks not specified. Estimated from input data size: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0024 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0024 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0024
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0024
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0024/
INFO  : Starting Job = job_1719249550016_0024, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0024/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0024
INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 20:49:10,854 Stage-1 map = 0%,  reduce = 0%
INFO  : 2024-06-24 20:49:26,239 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 16.58 sec
INFO  : 2024-06-24 20:49:35,065 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 21.37 sec
INFO  : MapReduce Total cumulative CPU time: 21 seconds 370 msec
INFO  : Ended Job = job_1719249550016_0024
INFO  : Starting task [Stage-7:CONDITIONAL] in serial mode
INFO  : Stage-4 is selected by condition resolver.
INFO  : Stage-3 is filtered out by condition resolver.
INFO  : Stage-5 is filtered out by condition resolver.
INFO  : Starting task [Stage-4:MOVE] in serial mode
INFO  : Moving data to directory hdfs://namenode:9000/user/proyectos/proyecto_1/database/landing/transaccion/.hive-staging_hive_2024-06-24_20-48-50_086_8280748685325100502-2/-ext-10000 from hdfs://namenode:9000/user/proyectos/proyecto_1/database/landing/transaccion/.hive-staging_hive_2024-06-24_20-48-50_086_8280748685325100502-2/-ext-10002
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table landing.transaccion partition (fecha=null) from hdfs://namenode:9000/user/proyectos/proyecto_1/database/landing/transaccion/.hive-staging_hive_2024-06-24_20-48-50_086_8280748685325100502-2/-ext-10000
INFO  :

INFO  :          Time taken to load dynamic partitions: 0.975 seconds
INFO  :          Time taken for adding to write entity : 0.009 seconds
INFO  : Starting task [Stage-2:STATS] in serial mode
INFO  : MapReduce Jobs Launched:
INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 21.37 sec   HDFS Read: 5146510 HDFS Write: 1860105 SUCCESS
INFO  : Total MapReduce CPU Time Spent: 21 seconds 370 msec
INFO  : Completed executing command(queryId=root_20240624204850_94e11449-0044-4d24-8b25-1ade444f045f); Time taken: 48.253 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query INSERT OVERWRITE TABLE LANDING.TRANSACCION
PARTITION(FECHA)
SELECT * FROM  LANDING_TMP.TRANSACCION
No rows affected (48.831 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM LANDING.TRANSACCION LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624204938_6d0515ef-bba8-44aa-9e5e-06b65ef26dc6): SELECT * FROM LANDING.TRANSACCION LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:transaccion.id_persona, type:string, comment:null), FieldSchema(name:transaccion.id_empresa, type:string, comment:null), FieldSchema(name:transaccion.monto, type:string, comment:null), FieldSchema(name:transaccion.fecha, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624204938_6d0515ef-bba8-44aa-9e5e-06b65ef26dc6); Time taken: 0.286 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624204938_6d0515ef-bba8-44aa-9e5e-06b65ef26dc6): SELECT * FROM LANDING.TRANSACCION LIMIT 10
INFO  : Completed executing command(queryId=root_20240624204938_6d0515ef-bba8-44aa-9e5e-06b65ef26dc6); Time taken: 0.0 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM LANDING.TRANSACCION LIMIT 10
+-------------------------+-------------------------+--------------------+--------------------+
| transaccion.id_persona  | transaccion.id_empresa  | transaccion.monto  | transaccion.fecha  |
+-------------------------+-------------------------+--------------------+--------------------+
| 18                      | 3                       | 1383               | 2018-01-21         |
| 30                      | 6                       | 2331               | 2018-01-21         |
| 47                      | 2                       | 2280               | 2018-01-21         |
| 28                      | 1                       | 730                | 2018-01-21         |
| 91                      | 4                       | 3081               | 2018-01-21         |
| 74                      | 8                       | 2409               | 2018-01-21         |
| 83                      | 5                       | 2079               | 2018-01-21         |
| 48                      | 4                       | 2543               | 2018-01-21         |
| 15                      | 6                       | 1434               | 2018-01-21         |
| 89                      | 4                       | 780                | 2018-01-21         |
+-------------------------+-------------------------+--------------------+--------------------+
10 rows selected (0.428 seconds)
0: jdbc:hive2://localhost:10000> Closing: 0: jdbc:hive2://localhost:10000
root@hive-server:/opt/hive/bin#

# %% [markdown]
# #### Esquema `UNIVERSAL`

# %%
beeline -u jdbc:hive2://localhost:10000 -f /opt/hive/deploy/deploy_esquema_universal.sql --hiveconf "PARAM_RAIZ=proyectos" --hiveconf "PARAM_PROYECTO=proyecto_1"

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker exec -it hive-server bash
root@hive-server:/opt#
root@hive-server:/opt# cd hive
root@hive-server:/opt/hive#
root@hive-server:/opt/hive# cd bin
root@hive-server:/opt/hive/bin#
root@hive-server:/opt/hive/bin# beeline -u jdbc:hive2://localhost:10000 -f /opt/hive/deploy/deploy_esquema_universal.sql --hiveconf "PARAM_RAIZ=proyectos" --hiveconf "P
ARAM_PROYECTO=proyecto_1"
SLF4J: Class path contains multiple SLF4J bindings.
SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
Connecting to jdbc:hive2://localhost:10000
Connected to: Apache Hive (version 3.1.2)
Driver: Hive JDBC (version 3.1.2)
Transaction isolation: TRANSACTION_REPEATABLE_READ
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @author Alfonso Perez
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @email perezlino@gmail.com
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @copyright Alfonso Perez
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Despliegue del esquema "UNIVERSAL"
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @section Tuning
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET hive.execution.engine=mr;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.job.maps=8;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.input.fileinputformat.split.maxsize=128000000;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.input.fileinputformat.split.minsize=128000000;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.map.cpu.vcores=2;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.map.memory.mb=128;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.job.reduces=8;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.reduce.cpu.vcores=2;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.reduce.memory.mb=128;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET hive.exec.dynamic.partition=true;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SET hive.exec.dynamic.partition.mode=nonstrict;
No rows affected (0.284 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SET hive.exec.max.dynamic.partitions=9999;
No rows affected (0.013 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SET hive.exec.max.dynamic.partitions.pernode=9999;
No rows affected (0.019 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SET hive.exec.compress.output=true;
No rows affected (0.016 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SET parquet.compression=SNAPPY;
No rows affected (0.017 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET orc.compression=SNAPPY;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET avro.output.codec=SNAPPY;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.job.queue.name=q_user_main;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET spark.job.queue.name=q_user_main;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET tez.job.queue.name=q_user_main;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @section Programa
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Borrado de la base de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> DROP DATABASE IF EXISTS UNIVERSAL CASCADE;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624205716_b83e2b35-0e01-41a7-8e0d-d9d3d812a218): DROP DATABASE IF EXISTS UNIVERSAL CASCADE
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624205716_b83e2b35-0e01-41a7-8e0d-d9d3d812a218); Time taken: 0.09 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624205716_b83e2b35-0e01-41a7-8e0d-d9d3d812a218): DROP DATABASE IF EXISTS UNIVERSAL CASCADE
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624205716_b83e2b35-0e01-41a7-8e0d-d9d3d812a218); Time taken: 0.801 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query DROP DATABASE IF EXISTS UNIVERSAL CASCADE
No rows affected (0.929 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de la base de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- en LOCATION podemos indicar solo la ruta: "/user/..." o anteponer el "hdfs:///user/..."
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE DATABASE IF NOT EXISTS UNIVERSAL
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION '/user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/database/universal';
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624205717_c78d92a4-0267-4bd3-bd28-0f88b727eefe): CREATE DATABASE IF NOT EXISTS UNIVERSAL
LOCATION '/user/proyectos/proyecto_1/database/universal'
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624205717_c78d92a4-0267-4bd3-bd28-0f88b727eefe); Time taken: 0.008 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624205717_c78d92a4-0267-4bd3-bd28-0f88b727eefe): CREATE DATABASE IF NOT EXISTS UNIVERSAL
LOCATION '/user/proyectos/proyecto_1/database/universal'
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624205717_c78d92a4-0267-4bd3-bd28-0f88b727eefe); Time taken: 0.034 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE DATABASE IF NOT EXISTS UNIVERSAL
LOCATION '/user/proyectos/proyecto_1/database/universal'
No rows affected (0.086 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Persona
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de la tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- en LOCATION podemos indicar solo la ruta: "/user/..." o anteponer el "hdfs:///user/..."
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TABLE UNIVERSAL.PERSONA(
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> NOMBRE STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TELEFONO STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> CORREO STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FECHA_INGRESO STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> EDAD INT,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SALARIO DOUBLE,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID_EMPRESA STRING
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> )
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS PARQUET
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION '/user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/database/universal/persona'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TBLPROPERTIES ("parquet.compression"="SNAPPY");
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624205717_2d3e0c1f-9ef4-444c-b4db-7709bf6cce6b): CREATE TABLE UNIVERSAL.PERSONA(
ID STRING,
NOMBRE STRING,
TELEFONO STRING,
CORREO STRING,
FECHA_INGRESO STRING,
EDAD INT,
SALARIO DOUBLE,
ID_EMPRESA STRING
)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto_1/database/universal/persona'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624205717_2d3e0c1f-9ef4-444c-b4db-7709bf6cce6b); Time taken: 0.01 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624205717_2d3e0c1f-9ef4-444c-b4db-7709bf6cce6b): CREATE TABLE UNIVERSAL.PERSONA(
ID STRING,
NOMBRE STRING,
TELEFONO STRING,
CORREO STRING,
FECHA_INGRESO STRING,
EDAD INT,
SALARIO DOUBLE,
ID_EMPRESA STRING
)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto_1/database/universal/persona'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624205717_2d3e0c1f-9ef4-444c-b4db-7709bf6cce6b); Time taken: 0.083 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TABLE UNIVERSAL.PERSONA(
ID STRING,
NOMBRE STRING,
TELEFONO STRING,
CORREO STRING,
FECHA_INGRESO STRING,
EDAD INT,
SALARIO DOUBLE,
ID_EMPRESA STRING
)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto_1/database/universal/persona'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
No rows affected (0.129 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Inserción de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> INSERT OVERWRITE TABLE UNIVERSAL.PERSONA
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SELECT
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   cast(ID AS STRING),
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   cast(NOMBRE AS STRING),
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   cast(TELEFONO AS STRING),
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   cast(CORREO AS STRING),
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   cast(FECHA_INGRESO AS STRING),
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   cast(EDAD AS INT),
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   cast(SALARIO AS DOUBLE),
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   cast(ID_EMPRESA AS STRING)
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FROM
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   LANDING.PERSONA
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> WHERE
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   ID != 'ID';
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624205717_5effc341-d5d8-40eb-aa76-1612e34a40cd): INSERT OVERWRITE TABLE UNIVERSAL.PERSONA
SELECT
cast(ID AS STRING),
cast(NOMBRE AS STRING),
cast(TELEFONO AS STRING),
cast(CORREO AS STRING),
cast(FECHA_INGRESO AS STRING),
cast(EDAD AS INT),
cast(SALARIO AS DOUBLE),
cast(ID_EMPRESA AS STRING)
FROM
LANDING.PERSONA
WHERE
ID != 'ID'
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:id, type:string, comment:null), FieldSchema(name:nombre, type:string, comment:null), FieldSchema(name:telefono, type:string, comment:null), FieldSchema(name:correo, type:string, comment:null), FieldSchema(name:fecha_ingreso, type:string, comment:null), FieldSchema(name:edad, type:int, comment:null), FieldSchema(name:salario, type:double, comment:null), FieldSchema(name:id_empresa, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624205717_5effc341-d5d8-40eb-aa76-1612e34a40cd); Time taken: 0.931 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624205717_5effc341-d5d8-40eb-aa76-1612e34a40cd): INSERT OVERWRITE TABLE UNIVERSAL.PERSONA
SELECT
cast(ID AS STRING),
cast(NOMBRE AS STRING),
cast(TELEFONO AS STRING),
cast(CORREO AS STRING),
cast(FECHA_INGRESO AS STRING),
cast(EDAD AS INT),
cast(SALARIO AS DOUBLE),
cast(ID_EMPRESA AS STRING)
FROM
LANDING.PERSONA
WHERE
ID != 'ID'
WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
INFO  : Query ID = root_20240624205717_5effc341-d5d8-40eb-aa76-1612e34a40cd
INFO  : Total jobs = 3
INFO  : Launching Job 1 out of 3
INFO  : Starting task [Stage-1:MAPRED] in serial mode
INFO  : Number of reduce tasks determined at compile time: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0025 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0025 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0025
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0025
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0025/
INFO  : Starting Job = job_1719249550016_0025, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0025/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0025
INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 20:57:41,259 Stage-1 map = 0%,  reduce = 0%
INFO  : 2024-06-24 20:57:55,181 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 12.2 sec
INFO  : 2024-06-24 20:58:07,197 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 22.83 sec
INFO  : MapReduce Total cumulative CPU time: 22 seconds 830 msec
INFO  : Ended Job = job_1719249550016_0025
INFO  : Starting task [Stage-7:CONDITIONAL] in serial mode
INFO  : Stage-4 is selected by condition resolver.
INFO  : Stage-3 is filtered out by condition resolver.
INFO  : Stage-5 is filtered out by condition resolver.
INFO  : Starting task [Stage-4:MOVE] in serial mode
INFO  : Moving data to directory hdfs://namenode:9000/user/proyectos/proyecto_1/database/universal/persona/.hive-staging_hive_2024-06-24_20-57-17_869_2066399624918862909-2/-ext-10000 from hdfs://namenode:9000/user/proyectos/proyecto_1/database/universal/persona/.hive-staging_hive_2024-06-24_20-57-17_869_2066399624918862909-2/-ext-10002
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table universal.persona from hdfs://namenode:9000/user/proyectos/proyecto_1/database/universal/persona/.hive-staging_hive_2024-06-24_20-57-17_869_2066399624918862909-2/-ext-10000
INFO  : Starting task [Stage-2:STATS] in serial mode
INFO  : MapReduce Jobs Launched:
INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 22.83 sec   HDFS Read: 44919 HDFS Write: 10267 SUCCESS
INFO  : Total MapReduce CPU Time Spent: 22 seconds 830 msec
INFO  : Completed executing command(queryId=root_20240624205717_5effc341-d5d8-40eb-aa76-1612e34a40cd); Time taken: 51.198 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query INSERT OVERWRITE TABLE UNIVERSAL.PERSONA
SELECT
cast(ID AS STRING),
cast(NOMBRE AS STRING),
cast(TELEFONO AS STRING),
cast(CORREO AS STRING),
cast(FECHA_INGRESO AS STRING),
cast(EDAD AS INT),
cast(SALARIO AS DOUBLE),
cast(ID_EMPRESA AS STRING)
FROM
LANDING.PERSONA
WHERE
ID != 'ID'
No rows affected (52.184 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM UNIVERSAL.PERSONA LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624205810_de46d71b-a1dc-4432-b7e3-a66dc09fb7a5): SELECT * FROM UNIVERSAL.PERSONA LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:persona.id, type:string, comment:null), FieldSchema(name:persona.nombre, type:string, comment:null), FieldSchema(name:persona.telefono, type:string, comment:null), FieldSchema(name:persona.correo, type:string, comment:null), FieldSchema(name:persona.fecha_ingreso, type:string, comment:null), FieldSchema(name:persona.edad, type:int, comment:null), FieldSchema(name:persona.salario, type:double, comment:null), FieldSchema(name:persona.id_empresa, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624205810_de46d71b-a1dc-4432-b7e3-a66dc09fb7a5); Time taken: 0.568 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624205810_de46d71b-a1dc-4432-b7e3-a66dc09fb7a5): SELECT * FROM UNIVERSAL.PERSONA LIMIT 10
INFO  : Completed executing command(queryId=root_20240624205810_de46d71b-a1dc-4432-b7e3-a66dc09fb7a5); Time taken: 0.001 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM UNIVERSAL.PERSONA LIMIT 10
+-------------+-----------------+-------------------+-----------------------------------------+------------------------+---------------+------------------+---------------------+
| persona.id  | persona.nombre  | persona.telefono  |             persona.correo              | persona.fecha_ingreso  | persona.edad  | persona.salario  | persona.id_empresa  |
+-------------+-----------------+-------------------+-----------------------------------------+------------------------+---------------+------------------+---------------------+
| 1           | Carl            | 1-745-633-9145    | arcu.Sed.et@ante.co.uk                  | 2004-04-23             | 32            | 20095.0          | 5                   |
| 2           | Priscilla       | 155-2498          | Donec.egestas.Aliquam@volutpatnunc.edu  | 2019-02-17             | 34            | 9298.0           | 2                   |
| 3           | Jocelyn         | 1-204-956-8594    | amet.diam@lobortis.co.uk                | 2002-08-01             | 27            | 10853.0          | 3                   |
| 4           | Aidan           | 1-719-862-9385    | euismod.et.commodo@nibhlaciniaorci.edu  | 2018-11-06             | 29            | 3387.0           | 10                  |
| 5           | Leandra         | 839-8044          | at@pretiumetrutrum.com                  | 2002-10-10             | 41            | 22102.0          | 1                   |
| 6           | Bert            | 797-4453          | a.felis.ullamcorper@arcu.org            | 2017-04-25             | 70            | 7800.0           | 7                   |
| 7           | Mark            | 1-680-102-6792    | Quisque.ac@placerat.ca                  | 2006-04-21             | 52            | 8112.0           | 5                   |
| 8           | Jonah           | 214-2975          | eu.ultrices.sit@vitae.ca                | 2017-10-07             | 23            | 17040.0          | 5                   |
| 9           | Hanae           | 935-2277          | eu@Nunc.ca                              | 2003-05-25             | 69            | 6834.0           | 3                   |
| 10          | Cadman          | 1-866-561-2701    | orci.adipiscing.non@semperNam.ca        | 2001-05-19             | 19            | 7996.0           | 7                   |
+-------------+-----------------+-------------------+-----------------------------------------+------------------------+---------------+------------------+---------------------+
10 rows selected (1.037 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Empresa
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- en LOCATION podemos indicar solo la ruta: "/user/..." o anteponer el "hdfs:///user/..."
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TABLE UNIVERSAL.EMPRESA(
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> NOMBRE STRING
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> )
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS PARQUET
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION '/user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/database/universal/empresa'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TBLPROPERTIES ("parquet.compression"="SNAPPY");
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624205811_01cbb347-dbb6-4a94-ba95-34d37a4c6d5d): CREATE TABLE UNIVERSAL.EMPRESA(
ID STRING,
NOMBRE STRING
)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto_1/database/universal/empresa'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624205811_01cbb347-dbb6-4a94-ba95-34d37a4c6d5d); Time taken: 0.033 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624205811_01cbb347-dbb6-4a94-ba95-34d37a4c6d5d): CREATE TABLE UNIVERSAL.EMPRESA(
ID STRING,
NOMBRE STRING
)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto_1/database/universal/empresa'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624205811_01cbb347-dbb6-4a94-ba95-34d37a4c6d5d); Time taken: 0.189 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TABLE UNIVERSAL.EMPRESA(
ID STRING,
NOMBRE STRING
)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto_1/database/universal/empresa'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
No rows affected (0.295 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Inserción de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> INSERT OVERWRITE TABLE UNIVERSAL.EMPRESA
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SELECT
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   cast(ID AS STRING),
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   cast(NOMBRE AS STRING)
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FROM
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   LANDING.EMPRESA
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> WHERE
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   ID != 'ID';
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624205811_fad8dabb-61be-4b20-9971-652463ee3f4c): INSERT OVERWRITE TABLE UNIVERSAL.EMPRESA
SELECT
cast(ID AS STRING),
cast(NOMBRE AS STRING)
FROM
LANDING.EMPRESA
WHERE
ID != 'ID'
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:id, type:string, comment:null), FieldSchema(name:nombre, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624205811_fad8dabb-61be-4b20-9971-652463ee3f4c); Time taken: 1.076 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624205811_fad8dabb-61be-4b20-9971-652463ee3f4c): INSERT OVERWRITE TABLE UNIVERSAL.EMPRESA
SELECT
cast(ID AS STRING),
cast(NOMBRE AS STRING)
FROM
LANDING.EMPRESA
WHERE
ID != 'ID'
WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
INFO  : Query ID = root_20240624205811_fad8dabb-61be-4b20-9971-652463ee3f4c
INFO  : Total jobs = 3
INFO  : Launching Job 1 out of 3
INFO  : Starting task [Stage-1:MAPRED] in serial mode
INFO  : Number of reduce tasks determined at compile time: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0026 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0026 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0026
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0026
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0026/
INFO  : Starting Job = job_1719249550016_0026, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0026/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0026
INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 20:58:36,064 Stage-1 map = 0%,  reduce = 0%
INFO  : 2024-06-24 20:58:49,995 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 10.47 sec
INFO  : 2024-06-24 20:59:01,990 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 19.95 sec
INFO  : MapReduce Total cumulative CPU time: 19 seconds 950 msec
INFO  : Ended Job = job_1719249550016_0026
INFO  : Starting task [Stage-7:CONDITIONAL] in serial mode
INFO  : Stage-4 is selected by condition resolver.
INFO  : Stage-3 is filtered out by condition resolver.
INFO  : Stage-5 is filtered out by condition resolver.
INFO  : Starting task [Stage-4:MOVE] in serial mode
INFO  : Moving data to directory hdfs://namenode:9000/user/proyectos/proyecto_1/database/universal/empresa/.hive-staging_hive_2024-06-24_20-58-11_952_5343114469009072770-2/-ext-10000 from hdfs://namenode:9000/user/proyectos/proyecto_1/database/universal/empresa/.hive-staging_hive_2024-06-24_20-58-11_952_5343114469009072770-2/-ext-10002
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table universal.empresa from hdfs://namenode:9000/user/proyectos/proyecto_1/database/universal/empresa/.hive-staging_hive_2024-06-24_20-58-11_952_5343114469009072770-2/-ext-10000
INFO  : Starting task [Stage-2:STATS] in serial mode
INFO  : MapReduce Jobs Launched:
INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 19.95 sec   HDFS Read: 16395 HDFS Write: 889 SUCCESS
INFO  : Total MapReduce CPU Time Spent: 19 seconds 950 msec
INFO  : Completed executing command(queryId=root_20240624205811_fad8dabb-61be-4b20-9971-652463ee3f4c); Time taken: 51.728 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query INSERT OVERWRITE TABLE UNIVERSAL.EMPRESA
SELECT
cast(ID AS STRING),
cast(NOMBRE AS STRING)
FROM
LANDING.EMPRESA
WHERE
ID != 'ID'
No rows affected (52.848 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM UNIVERSAL.EMPRESA LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624205904_7783470a-9f7a-4140-847d-051caf91eaa5): SELECT * FROM UNIVERSAL.EMPRESA LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:empresa.id, type:string, comment:null), FieldSchema(name:empresa.nombre, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624205904_7783470a-9f7a-4140-847d-051caf91eaa5); Time taken: 0.283 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624205904_7783470a-9f7a-4140-847d-051caf91eaa5): SELECT * FROM UNIVERSAL.EMPRESA LIMIT 10
INFO  : Completed executing command(queryId=root_20240624205904_7783470a-9f7a-4140-847d-051caf91eaa5); Time taken: 0.004 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM UNIVERSAL.EMPRESA LIMIT 10
+-------------+-----------------+
| empresa.id  | empresa.nombre  |
+-------------+-----------------+
| 1           | Walmart         |
| 2           | Microsoft       |
| 3           | Apple           |
| 4           | Toyota          |
| 5           | Amazon          |
| 6           | Google          |
| 7           | Samsung         |
| 8           | HP              |
| 9           | IBM             |
| 10          | Sony            |
+-------------+-----------------+
10 rows selected (0.509 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Transaccion
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- en LOCATION podemos indicar solo la ruta: "/user/..." o anteponer el "hdfs:///user/..."
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TABLE UNIVERSAL.TRANSACCION(
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID_PERSONA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID_EMPRESA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> MONTO DOUBLE
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> )
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> PARTITIONED BY (FECHA STRING)
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS PARQUET
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION '/user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/database/universal/transaccion'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TBLPROPERTIES ("parquet.compression"="SNAPPY");
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624205905_b591f314-61e0-481c-ad3c-41f93d1ea341): CREATE TABLE UNIVERSAL.TRANSACCION(
ID_PERSONA STRING,
ID_EMPRESA STRING,
MONTO DOUBLE
)
PARTITIONED BY (FECHA STRING)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto_1/database/universal/transaccion'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624205905_b591f314-61e0-481c-ad3c-41f93d1ea341); Time taken: 0.023 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624205905_b591f314-61e0-481c-ad3c-41f93d1ea341): CREATE TABLE UNIVERSAL.TRANSACCION(
ID_PERSONA STRING,
ID_EMPRESA STRING,
MONTO DOUBLE
)
PARTITIONED BY (FECHA STRING)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto_1/database/universal/transaccion'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624205905_b591f314-61e0-481c-ad3c-41f93d1ea341); Time taken: 0.17 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TABLE UNIVERSAL.TRANSACCION(
ID_PERSONA STRING,
ID_EMPRESA STRING,
MONTO DOUBLE
)
PARTITIONED BY (FECHA STRING)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto_1/database/universal/transaccion'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
No rows affected (0.269 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Inserción de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> INSERT OVERWRITE TABLE UNIVERSAL.TRANSACCION
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> PARTITION(FECHA)
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SELECT
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   cast(ID_PERSONA AS STRING),
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   cast(ID_EMPRESA AS STRING),
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   cast(MONTO AS DOUBLE),
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   cast(FECHA AS STRING)
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FROM
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   LANDING.TRANSACCION
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> WHERE
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   ID_PERSONA != 'ID_PERSONA';
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624205906_584ea77e-fd9c-4d36-82b3-831d427e6785): INSERT OVERWRITE TABLE UNIVERSAL.TRANSACCION
PARTITION(FECHA)
SELECT
cast(ID_PERSONA AS STRING),
cast(ID_EMPRESA AS STRING),
cast(MONTO AS DOUBLE),
cast(FECHA AS STRING)
FROM
LANDING.TRANSACCION
WHERE
ID_PERSONA != 'ID_PERSONA'
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:id_persona, type:string, comment:null), FieldSchema(name:id_empresa, type:string, comment:null), FieldSchema(name:monto, type:double, comment:null), FieldSchema(name:fecha, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624205906_584ea77e-fd9c-4d36-82b3-831d427e6785); Time taken: 1.399 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624205906_584ea77e-fd9c-4d36-82b3-831d427e6785): INSERT OVERWRITE TABLE UNIVERSAL.TRANSACCION
PARTITION(FECHA)
SELECT
cast(ID_PERSONA AS STRING),
cast(ID_EMPRESA AS STRING),
cast(MONTO AS DOUBLE),
cast(FECHA AS STRING)
FROM
LANDING.TRANSACCION
WHERE
ID_PERSONA != 'ID_PERSONA'
WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
INFO  : Query ID = root_20240624205906_584ea77e-fd9c-4d36-82b3-831d427e6785
INFO  : Total jobs = 3
INFO  : Launching Job 1 out of 3
INFO  : Starting task [Stage-1:MAPRED] in serial mode
INFO  : Number of reduce tasks not specified. Estimated from input data size: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0027 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0027 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0027
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0027
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0027/
INFO  : Starting Job = job_1719249550016_0027, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0027/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0027
INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 20:59:31,981 Stage-1 map = 0%,  reduce = 0%
INFO  : 2024-06-24 20:59:53,434 Stage-1 map = 14%,  reduce = 0%, Cumulative CPU 27.98 sec
INFO  : 2024-06-24 20:59:57,868 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 36.46 sec
INFO  : 2024-06-24 21:00:15,005 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 46.67 sec
INFO  : MapReduce Total cumulative CPU time: 46 seconds 670 msec
INFO  : Ended Job = job_1719249550016_0027
INFO  : Starting task [Stage-7:CONDITIONAL] in serial mode
INFO  : Stage-4 is selected by condition resolver.
INFO  : Stage-3 is filtered out by condition resolver.
INFO  : Stage-5 is filtered out by condition resolver.
INFO  : Starting task [Stage-4:MOVE] in serial mode
INFO  : Moving data to directory hdfs://namenode:9000/user/proyectos/proyecto_1/database/universal/transaccion/.hive-staging_hive_2024-06-24_20-59-06_141_999237016273332317-2/-ext-10000 from hdfs://namenode:9000/user/proyectos/proyecto_1/database/universal/transaccion/.hive-staging_hive_2024-06-24_20-59-06_141_999237016273332317-2/-ext-10002
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table universal.transaccion partition (fecha=null) from hdfs://namenode:9000/user/proyectos/proyecto_1/database/universal/transaccion/.hive-staging_hive_2024-06-24_20-59-06_141_999237016273332317-2/-ext-10000
INFO  :

INFO  :          Time taken to load dynamic partitions: 1.226 seconds
INFO  :          Time taken for adding to write entity : 0.018 seconds
INFO  : Starting task [Stage-2:STATS] in serial mode
INFO  : MapReduce Jobs Launched:
INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 46.67 sec   HDFS Read: 1926879 HDFS Write: 754806 SUCCESS
INFO  : Total MapReduce CPU Time Spent: 46 seconds 670 msec
INFO  : Completed executing command(queryId=root_20240624205906_584ea77e-fd9c-4d36-82b3-831d427e6785); Time taken: 72.651 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query INSERT OVERWRITE TABLE UNIVERSAL.TRANSACCION
PARTITION(FECHA)
SELECT
cast(ID_PERSONA AS STRING),
cast(ID_EMPRESA AS STRING),
cast(MONTO AS DOUBLE),
cast(FECHA AS STRING)
FROM
LANDING.TRANSACCION
WHERE
ID_PERSONA != 'ID_PERSONA'
No rows affected (74.119 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM UNIVERSAL.TRANSACCION LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210020_f66505fa-a4ae-48b5-b2b7-2bb594a589fe): SELECT * FROM UNIVERSAL.TRANSACCION LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:transaccion.id_persona, type:string, comment:null), FieldSchema(name:transaccion.id_empresa, type:string, comment:null), FieldSchema(name:transaccion.monto, type:double, comment:null), FieldSchema(name:transaccion.fecha, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624210020_f66505fa-a4ae-48b5-b2b7-2bb594a589fe); Time taken: 0.435 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210020_f66505fa-a4ae-48b5-b2b7-2bb594a589fe): SELECT * FROM UNIVERSAL.TRANSACCION LIMIT 10
INFO  : Completed executing command(queryId=root_20240624210020_f66505fa-a4ae-48b5-b2b7-2bb594a589fe); Time taken: 0.001 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM UNIVERSAL.TRANSACCION LIMIT 10
+-------------------------+-------------------------+--------------------+--------------------+
| transaccion.id_persona  | transaccion.id_empresa  | transaccion.monto  | transaccion.fecha  |
+-------------------------+-------------------------+--------------------+--------------------+
| 18                      | 3                       | 1383.0             | 2018-01-21         |
| 30                      | 6                       | 2331.0             | 2018-01-21         |
| 47                      | 2                       | 2280.0             | 2018-01-21         |
| 28                      | 1                       | 730.0              | 2018-01-21         |
| 91                      | 4                       | 3081.0             | 2018-01-21         |
| 74                      | 8                       | 2409.0             | 2018-01-21         |
| 83                      | 5                       | 2079.0             | 2018-01-21         |
| 48                      | 4                       | 2543.0             | 2018-01-21         |
| 15                      | 6                       | 1434.0             | 2018-01-21         |
| 89                      | 4                       | 780.0              | 2018-01-21         |
+-------------------------+-------------------------+--------------------+--------------------+
10 rows selected (0.785 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Transaccion_Enriquecida
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- en LOCATION podemos indicar solo la ruta: "/user/..." o anteponer el "hdfs:///user/..."
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TABLE UNIVERSAL.TRANSACCION_ENRIQUECIDA(
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID_PERSONA INT,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> NOMBRE_PERSONA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> EDAD_PERSONA INT,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SALARIO_PERSONA DOUBLE,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TRABAJO_PERSONA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> MONTO_TRANSACCION DOUBLE,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> EMPRESA_TRANSACCION STRING
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> )
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> PARTITIONED BY (FECHA_TRANSACCION STRING)
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS PARQUET
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION '/user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/database/universal/transaccion_enriquecida'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TBLPROPERTIES ("parquet.compression"="SNAPPY");
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210021_3bc0d11c-9f8b-43a0-aafc-d5998a6a25dc): CREATE TABLE UNIVERSAL.TRANSACCION_ENRIQUECIDA(
ID_PERSONA INT,
NOMBRE_PERSONA STRING,
EDAD_PERSONA INT,
SALARIO_PERSONA DOUBLE,
TRABAJO_PERSONA STRING,
MONTO_TRANSACCION DOUBLE,
EMPRESA_TRANSACCION STRING
)
PARTITIONED BY (FECHA_TRANSACCION STRING)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto_1/database/universal/transaccion_enriquecida'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624210021_3bc0d11c-9f8b-43a0-aafc-d5998a6a25dc); Time taken: 0.091 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210021_3bc0d11c-9f8b-43a0-aafc-d5998a6a25dc): CREATE TABLE UNIVERSAL.TRANSACCION_ENRIQUECIDA(
ID_PERSONA INT,
NOMBRE_PERSONA STRING,
EDAD_PERSONA INT,
SALARIO_PERSONA DOUBLE,
TRABAJO_PERSONA STRING,
MONTO_TRANSACCION DOUBLE,
EMPRESA_TRANSACCION STRING
)
PARTITIONED BY (FECHA_TRANSACCION STRING)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto_1/database/universal/transaccion_enriquecida'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624210021_3bc0d11c-9f8b-43a0-aafc-d5998a6a25dc); Time taken: 0.355 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TABLE UNIVERSAL.TRANSACCION_ENRIQUECIDA(
ID_PERSONA INT,
NOMBRE_PERSONA STRING,
EDAD_PERSONA INT,
SALARIO_PERSONA DOUBLE,
TRABAJO_PERSONA STRING,
MONTO_TRANSACCION DOUBLE,
EMPRESA_TRANSACCION STRING
)
PARTITIONED BY (FECHA_TRANSACCION STRING)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto_1/database/universal/transaccion_enriquecida'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
No rows affected (0.553 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Transaccion_Persona_Enriquecida_1
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TEMPORARY TABLE UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1(
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID_PERSONA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> NOMBRE_PERSONA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> EDAD_PERSONA INT,                                -- No es necesario COMPRIMIR una Tabla temporal
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SALARIO_PERSONA DOUBLE,                          -- Como tampoco indicar el LOCATION
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID_EMPRESA_PERSONA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> MONTO_TRANSACCION DOUBLE,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FECHA_TRANSACCION STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID_EMPRESA_TRANSACCION STRING
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> )
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS PARQUET;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210022_af86f335-8854-4d5a-929a-408751c73664): CREATE TEMPORARY TABLE UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1(
ID_PERSONA STRING,
NOMBRE_PERSONA STRING,
EDAD_PERSONA INT,
SALARIO_PERSONA DOUBLE,
ID_EMPRESA_PERSONA STRING,
MONTO_TRANSACCION DOUBLE,
FECHA_TRANSACCION STRING,
ID_EMPRESA_TRANSACCION STRING
)
STORED AS PARQUET
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624210022_af86f335-8854-4d5a-929a-408751c73664); Time taken: 0.023 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210022_af86f335-8854-4d5a-929a-408751c73664): CREATE TEMPORARY TABLE UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1(
ID_PERSONA STRING,
NOMBRE_PERSONA STRING,
EDAD_PERSONA INT,
SALARIO_PERSONA DOUBLE,
ID_EMPRESA_PERSONA STRING,
MONTO_TRANSACCION DOUBLE,
FECHA_TRANSACCION STRING,
ID_EMPRESA_TRANSACCION STRING
)
STORED AS PARQUET
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624210022_af86f335-8854-4d5a-929a-408751c73664); Time taken: 0.209 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TEMPORARY TABLE UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1(
ID_PERSONA STRING,
NOMBRE_PERSONA STRING,
EDAD_PERSONA INT,
SALARIO_PERSONA DOUBLE,
ID_EMPRESA_PERSONA STRING,
MONTO_TRANSACCION DOUBLE,
FECHA_TRANSACCION STRING,
ID_EMPRESA_TRANSACCION STRING
)
STORED AS PARQUET
No rows affected (0.433 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Inserción de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> INSERT INTO UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SELECT
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.ID_PERSONA AS ID_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   P.NOMBRE AS NOMBRE_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   P.EDAD AS EDAD_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   P.SALARIO AS SALARIO_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   P.ID_EMPRESA AS ID_EMPRESA_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.MONTO AS MONTO_TRANSACCION,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.FECHA AS FECHA_TRANSACCION,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.ID_EMPRESA AS ID_EMPRESA_TRANSACCION
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FROM
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   UNIVERSAL.TRANSACCION T
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> JOIN
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   UNIVERSAL.PERSONA P
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ON
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.ID_PERSONA = P.ID;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210023_b6054f89-1bf3-422c-acb3-5faee1301c86): INSERT INTO UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1
SELECT
T.ID_PERSONA AS ID_PERSONA,
P.NOMBRE AS NOMBRE_PERSONA,
P.EDAD AS EDAD_PERSONA,
P.SALARIO AS SALARIO_PERSONA,
P.ID_EMPRESA AS ID_EMPRESA_PERSONA,
T.MONTO AS MONTO_TRANSACCION,
T.FECHA AS FECHA_TRANSACCION,
T.ID_EMPRESA AS ID_EMPRESA_TRANSACCION
FROM
UNIVERSAL.TRANSACCION T
JOIN
UNIVERSAL.PERSONA P
ON
T.ID_PERSONA = P.ID
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:id_persona, type:string, comment:null), FieldSchema(name:nombre_persona, type:string, comment:null), FieldSchema(name:edad_persona, type:int, comment:null), FieldSchema(name:salario_persona, type:double, comment:null), FieldSchema(name:id_empresa_persona, type:string, comment:null), FieldSchema(name:monto_transaccion, type:double, comment:null), FieldSchema(name:fecha_transaccion, type:string, comment:null), FieldSchema(name:id_empresa_transaccion, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624210023_b6054f89-1bf3-422c-acb3-5faee1301c86); Time taken: 1.17 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210023_b6054f89-1bf3-422c-acb3-5faee1301c86): INSERT INTO UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1
SELECT
T.ID_PERSONA AS ID_PERSONA,
P.NOMBRE AS NOMBRE_PERSONA,
P.EDAD AS EDAD_PERSONA,
P.SALARIO AS SALARIO_PERSONA,
P.ID_EMPRESA AS ID_EMPRESA_PERSONA,
T.MONTO AS MONTO_TRANSACCION,
T.FECHA AS FECHA_TRANSACCION,
T.ID_EMPRESA AS ID_EMPRESA_TRANSACCION
FROM
UNIVERSAL.TRANSACCION T
JOIN
UNIVERSAL.PERSONA P
ON
T.ID_PERSONA = P.ID
WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
INFO  : Query ID = root_20240624210023_b6054f89-1bf3-422c-acb3-5faee1301c86
INFO  : Total jobs = 2
INFO  : Starting task [Stage-6:MAPREDLOCAL] in serial mode
INFO  : Execution completed successfully
INFO  : MapredLocal task succeeded
INFO  : Launching Job 1 out of 2
INFO  : Starting task [Stage-5:MAPRED] in serial mode
INFO  : Number of reduce tasks is set to 0 since there's no reduce operator
DEBUG : Configuring job job_1719249550016_0028 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0028 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0028
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0028
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0028/
INFO  : Starting Job = job_1719249550016_0028, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0028/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0028
INFO  : Hadoop job information for Stage-5: number of mappers: 1; number of reducers: 0
INFO  : 2024-06-24 21:01:14,636 Stage-5 map = 0%,  reduce = 0%
INFO  : 2024-06-24 21:01:41,857 Stage-5 map = 100%,  reduce = 0%, Cumulative CPU 28.82 sec
INFO  : MapReduce Total cumulative CPU time: 28 seconds 820 msec
INFO  : Ended Job = job_1719249550016_0028
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table universal.transaccion_persona_enriquecida_1 from hdfs://namenode:9000/tmp/hive/root/54a9e133-2690-45b5-b216-e8b9eccba2cd/_tmp_space.db/f782ed6e-2cab-4557-9c5b-2d626b164420/.hive-staging_hive_2024-06-24_21-00-23_663_6542431418253516082-2/-ext-10000
INFO  : Launching Job 2 out of 2
INFO  : Starting task [Stage-3:MAPRED] in serial mode
INFO  : Number of reduce tasks determined at compile time: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0029 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0029 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0029
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0029
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0029/
INFO  : Starting Job = job_1719249550016_0029, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0029/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0029
INFO  : Hadoop job information for Stage-3: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 21:02:07,164 Stage-3 map = 0%,  reduce = 0%
INFO  : 2024-06-24 21:02:20,348 Stage-3 map = 100%,  reduce = 0%, Cumulative CPU 6.39 sec
INFO  : 2024-06-24 21:02:36,499 Stage-3 map = 100%,  reduce = 100%, Cumulative CPU 16.63 sec
INFO  : MapReduce Total cumulative CPU time: 16 seconds 630 msec
INFO  : Ended Job = job_1719249550016_0029
INFO  : Starting task [Stage-2:STATS] in serial mode
INFO  : MapReduce Jobs Launched:
INFO  : Stage-Stage-5: Map: 1   Cumulative CPU: 28.82 sec   HDFS Read: 768500 HDFS Write: 1439040 SUCCESS
INFO  : Stage-Stage-3: Map: 1  Reduce: 1   Cumulative CPU: 16.63 sec   HDFS Read: 20647 HDFS Write: 1409 SUCCESS
INFO  : Total MapReduce CPU Time Spent: 45 seconds 450 msec
INFO  : Completed executing command(queryId=root_20240624210023_b6054f89-1bf3-422c-acb3-5faee1301c86); Time taken: 134.136 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query INSERT INTO UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1
SELECT
T.ID_PERSONA AS ID_PERSONA,
P.NOMBRE AS NOMBRE_PERSONA,
P.EDAD AS EDAD_PERSONA,
P.SALARIO AS SALARIO_PERSONA,
P.ID_EMPRESA AS ID_EMPRESA_PERSONA,
T.MONTO AS MONTO_TRANSACCION,
T.FECHA AS FECHA_TRANSACCION,
T.ID_EMPRESA AS ID_EMPRESA_TRANSACCION
FROM
UNIVERSAL.TRANSACCION T
JOIN
UNIVERSAL.PERSONA P
ON
T.ID_PERSONA = P.ID
No rows affected (135.423 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1 LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210239_73a9980e-04dd-41d9-8700-a6568252f430): SELECT * FROM UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1 LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:transaccion_persona_enriquecida_1.id_persona, type:string, comment:null), FieldSchema(name:transaccion_persona_enriquecida_1.nombre_persona, type:string, comment:null), FieldSchema(name:transaccion_persona_enriquecida_1.edad_persona, type:int, comment:null), FieldSchema(name:transaccion_persona_enriquecida_1.salario_persona, type:double, comment:null), FieldSchema(name:transaccion_persona_enriquecida_1.id_empresa_persona, type:string, comment:null), FieldSchema(name:transaccion_persona_enriquecida_1.monto_transaccion, type:double, comment:null), FieldSchema(name:transaccion_persona_enriquecida_1.fecha_transaccion, type:string, comment:null), FieldSchema(name:transaccion_persona_enriquecida_1.id_empresa_transaccion, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624210239_73a9980e-04dd-41d9-8700-a6568252f430); Time taken: 0.158 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210239_73a9980e-04dd-41d9-8700-a6568252f430): SELECT * FROM UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1 LIMIT 10
INFO  : Completed executing command(queryId=root_20240624210239_73a9980e-04dd-41d9-8700-a6568252f430); Time taken: 0.002 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1 LIMIT 10
+-----------------------------------------------+---------------------------------------------------+-------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
| transaccion_persona_enriquecida_1.id_persona  | transaccion_persona_enriquecida_1.nombre_persona  | transaccion_persona_enriquecida_1.edad_persona  | transaccion_persona_enriquecida_1.salario_persona  | transaccion_persona_enriquecida_1.id_empresa_persona | transaccion_persona_enriquecida_1.monto_transaccion | transaccion_persona_enriquecida_1.fecha_transaccion | transaccion_persona_enriquecida_1.id_empresa_transaccion |
+-----------------------------------------------+---------------------------------------------------+-------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
| 18                                            | Owen                                              | 34                                              | 4759.0                                             | 7                                                  | 1383.0                                             | 2018-01-21                                         | 3                                                  |
| 30                                            | Clayton                                           | 52                                              | 9505.0                                             | 8                                                  | 2331.0                                             | 2018-01-21                                         | 6                                                  |
| 47                                            | Vernon                                            | 35                                              | 7109.0                                             | 10                                                 | 2280.0                                             | 2018-01-21                                         | 2                                                  |
| 28                                            | Stephen                                           | 53                                              | 9469.0                                             | 8                                                  | 730.0                                              | 2018-01-21                                         | 1                                                  |
| 91                                            | Erica                                             | 32                                              | 8934.0                                             | 6                                                  | 3081.0                                             | 2018-01-21                                         | 4                                                  |
| 74                                            | Kaitlin                                           | 56                                              | 6515.0                                             | 10                                                 | 2409.0                                             | 2018-01-21                                         | 8                                                  |
| 83                                            | Giselle                                           | 45                                              | 2503.0                                             | 2                                                  | 2079.0                                             | 2018-01-21                                         | 5                                                  |
| 48                                            | Illiana                                           | 18                                              | 1454.0                                             | 8                                                  | 2543.0                                             | 2018-01-21                                         | 4                                                  |
| 15                                            | Wanda                                             | 27                                              | 1539.0                                             | 5                                                  | 1434.0                                             | 2018-01-21                                         | 6                                                  |
| 89                                            | Kelly                                             | 55                                              | 10110.0                                            | 6                                                  | 780.0                                              | 2018-01-21                                         | 4                                                  |
+-----------------------------------------------+---------------------------------------------------+-------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
10 rows selected (0.454 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Transaccion_Persona_Enriquecida_2
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TEMPORARY TABLE UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2(
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID_PERSONA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> NOMBRE_PERSONA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> EDAD_PERSONA INT,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SALARIO_PERSONA DOUBLE,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TRABAJO_PERSONA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> MONTO_TRANSACCION DOUBLE,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FECHA_TRANSACCION STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID_EMPRESA_TRANSACCION STRING
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> )
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS PARQUET;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210239_3b7c7a4b-5138-4d4d-8b69-6e49c731b312): CREATE TEMPORARY TABLE UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2(
ID_PERSONA STRING,
NOMBRE_PERSONA STRING,
EDAD_PERSONA INT,
SALARIO_PERSONA DOUBLE,
TRABAJO_PERSONA STRING,
MONTO_TRANSACCION DOUBLE,
FECHA_TRANSACCION STRING,
ID_EMPRESA_TRANSACCION STRING
)
STORED AS PARQUET
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624210239_3b7c7a4b-5138-4d4d-8b69-6e49c731b312); Time taken: 0.024 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210239_3b7c7a4b-5138-4d4d-8b69-6e49c731b312): CREATE TEMPORARY TABLE UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2(
ID_PERSONA STRING,
NOMBRE_PERSONA STRING,
EDAD_PERSONA INT,
SALARIO_PERSONA DOUBLE,
TRABAJO_PERSONA STRING,
MONTO_TRANSACCION DOUBLE,
FECHA_TRANSACCION STRING,
ID_EMPRESA_TRANSACCION STRING
)
STORED AS PARQUET
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624210239_3b7c7a4b-5138-4d4d-8b69-6e49c731b312); Time taken: 0.026 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TEMPORARY TABLE UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2(
ID_PERSONA STRING,
NOMBRE_PERSONA STRING,
EDAD_PERSONA INT,
SALARIO_PERSONA DOUBLE,
TRABAJO_PERSONA STRING,
MONTO_TRANSACCION DOUBLE,
FECHA_TRANSACCION STRING,
ID_EMPRESA_TRANSACCION STRING
)
STORED AS PARQUET
No rows affected (0.092 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Inserción de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> INSERT INTO UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SELECT
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.ID_PERSONA AS ID_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.NOMBRE_PERSONA AS NOMBRE_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.EDAD_PERSONA AS EDAD_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.SALARIO_PERSONA AS SALARIO_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   E.NOMBRE AS TRABAJO_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.MONTO_TRANSACCION AS MONTO_TRANSACCION,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.FECHA_TRANSACCION AS FECHA_TRANSACCION,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.ID_EMPRESA_TRANSACCION AS ID_EMPRESA_TRANSACCION
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FROM
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1 T
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> JOIN
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   UNIVERSAL.EMPRESA E
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ON
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.ID_EMPRESA_PERSONA = E.ID;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210239_5275b442-561c-4672-99b9-f260299002d6): INSERT INTO UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2
SELECT
T.ID_PERSONA AS ID_PERSONA,
T.NOMBRE_PERSONA AS NOMBRE_PERSONA,
T.EDAD_PERSONA AS EDAD_PERSONA,
T.SALARIO_PERSONA AS SALARIO_PERSONA,
E.NOMBRE AS TRABAJO_PERSONA,
T.MONTO_TRANSACCION AS MONTO_TRANSACCION,
T.FECHA_TRANSACCION AS FECHA_TRANSACCION,
T.ID_EMPRESA_TRANSACCION AS ID_EMPRESA_TRANSACCION
FROM
UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1 T
JOIN
UNIVERSAL.EMPRESA E
ON
T.ID_EMPRESA_PERSONA = E.ID
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:id_persona, type:string, comment:null), FieldSchema(name:nombre_persona, type:string, comment:null), FieldSchema(name:edad_persona, type:int, comment:null), FieldSchema(name:salario_persona, type:double, comment:null), FieldSchema(name:trabajo_persona, type:string, comment:null), FieldSchema(name:monto_transaccion, type:double, comment:null), FieldSchema(name:fecha_transaccion, type:string, comment:null), FieldSchema(name:id_empresa_transaccion, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624210239_5275b442-561c-4672-99b9-f260299002d6); Time taken: 0.944 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210239_5275b442-561c-4672-99b9-f260299002d6): INSERT INTO UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2
SELECT
T.ID_PERSONA AS ID_PERSONA,
T.NOMBRE_PERSONA AS NOMBRE_PERSONA,
T.EDAD_PERSONA AS EDAD_PERSONA,
T.SALARIO_PERSONA AS SALARIO_PERSONA,
E.NOMBRE AS TRABAJO_PERSONA,
T.MONTO_TRANSACCION AS MONTO_TRANSACCION,
T.FECHA_TRANSACCION AS FECHA_TRANSACCION,
T.ID_EMPRESA_TRANSACCION AS ID_EMPRESA_TRANSACCION
FROM
UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1 T
JOIN
UNIVERSAL.EMPRESA E
ON
T.ID_EMPRESA_PERSONA = E.ID
WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
INFO  : Query ID = root_20240624210239_5275b442-561c-4672-99b9-f260299002d6
INFO  : Total jobs = 2
INFO  : Starting task [Stage-6:MAPREDLOCAL] in serial mode
INFO  : Execution completed successfully
INFO  : MapredLocal task succeeded
INFO  : Launching Job 1 out of 2
INFO  : Starting task [Stage-5:MAPRED] in serial mode
INFO  : Number of reduce tasks is set to 0 since there's no reduce operator
DEBUG : Configuring job job_1719249550016_0030 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0030 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0030
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0030
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0030/
INFO  : Starting Job = job_1719249550016_0030, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0030/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0030
INFO  : Hadoop job information for Stage-5: number of mappers: 1; number of reducers: 0
INFO  : 2024-06-24 21:03:17,434 Stage-5 map = 0%,  reduce = 0%
INFO  : 2024-06-24 21:03:46,903 Stage-5 map = 100%,  reduce = 0%, Cumulative CPU 21.87 sec
INFO  : MapReduce Total cumulative CPU time: 22 seconds 200 msec
INFO  : Ended Job = job_1719249550016_0030
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table universal.transaccion_persona_enriquecida_2 from hdfs://namenode:9000/tmp/hive/root/54a9e133-2690-45b5-b216-e8b9eccba2cd/_tmp_space.db/6307be09-5a5d-48da-8e29-70657ecaf5b1/.hive-staging_hive_2024-06-24_21-02-39_947_717674866010808448-2/-ext-10000
INFO  : Launching Job 2 out of 2
INFO  : Starting task [Stage-3:MAPRED] in serial mode
INFO  : Number of reduce tasks determined at compile time: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0031 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0031 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0031
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0031
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0031/
INFO  : Starting Job = job_1719249550016_0031, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0031/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0031
INFO  : Hadoop job information for Stage-3: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 21:04:18,542 Stage-3 map = 0%,  reduce = 0%
INFO  : 2024-06-24 21:04:31,682 Stage-3 map = 100%,  reduce = 0%, Cumulative CPU 6.46 sec
INFO  : 2024-06-24 21:04:45,848 Stage-3 map = 100%,  reduce = 100%, Cumulative CPU 14.59 sec
INFO  : MapReduce Total cumulative CPU time: 14 seconds 590 msec
INFO  : Ended Job = job_1719249550016_0031
INFO  : Starting task [Stage-2:STATS] in serial mode
INFO  : MapReduce Jobs Launched:
INFO  : Stage-Stage-5: Map: 1   Cumulative CPU: 22.2 sec   HDFS Read: 1450823 HDFS Write: 1439178 SUCCESS
INFO  : Stage-Stage-3: Map: 1  Reduce: 1   Cumulative CPU: 14.59 sec   HDFS Read: 20638 HDFS Write: 1425 SUCCESS
INFO  : Total MapReduce CPU Time Spent: 36 seconds 790 msec
INFO  : Completed executing command(queryId=root_20240624210239_5275b442-561c-4672-99b9-f260299002d6); Time taken: 127.538 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query INSERT INTO UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2
SELECT
T.ID_PERSONA AS ID_PERSONA,
T.NOMBRE_PERSONA AS NOMBRE_PERSONA,
T.EDAD_PERSONA AS EDAD_PERSONA,
T.SALARIO_PERSONA AS SALARIO_PERSONA,
E.NOMBRE AS TRABAJO_PERSONA,
T.MONTO_TRANSACCION AS MONTO_TRANSACCION,
T.FECHA_TRANSACCION AS FECHA_TRANSACCION,
T.ID_EMPRESA_TRANSACCION AS ID_EMPRESA_TRANSACCION
FROM
UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1 T
JOIN
UNIVERSAL.EMPRESA E
ON
T.ID_EMPRESA_PERSONA = E.ID
No rows affected (128.569 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2 LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210448_2664327e-c6ab-4778-9420-e5a4992ac95c): SELECT * FROM UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2 LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:transaccion_persona_enriquecida_2.id_persona, type:string, comment:null), FieldSchema(name:transaccion_persona_enriquecida_2.nombre_persona, type:string, comment:null), FieldSchema(name:transaccion_persona_enriquecida_2.edad_persona, type:int, comment:null), FieldSchema(name:transaccion_persona_enriquecida_2.salario_persona, type:double, comment:null), FieldSchema(name:transaccion_persona_enriquecida_2.trabajo_persona, type:string, comment:null), FieldSchema(name:transaccion_persona_enriquecida_2.monto_transaccion, type:double, comment:null), FieldSchema(name:transaccion_persona_enriquecida_2.fecha_transaccion, type:string, comment:null), FieldSchema(name:transaccion_persona_enriquecida_2.id_empresa_transaccion, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624210448_2664327e-c6ab-4778-9420-e5a4992ac95c); Time taken: 0.201 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210448_2664327e-c6ab-4778-9420-e5a4992ac95c): SELECT * FROM UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2 LIMIT 10
INFO  : Completed executing command(queryId=root_20240624210448_2664327e-c6ab-4778-9420-e5a4992ac95c); Time taken: 0.001 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2 LIMIT 10
+-----------------------------------------------+---------------------------------------------------+-------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
| transaccion_persona_enriquecida_2.id_persona  | transaccion_persona_enriquecida_2.nombre_persona  | transaccion_persona_enriquecida_2.edad_persona  | transaccion_persona_enriquecida_2.salario_persona  | transaccion_persona_enriquecida_2.trabajo_persona  | transaccion_persona_enriquecida_2.monto_transaccion | transaccion_persona_enriquecida_2.fecha_transaccion | transaccion_persona_enriquecida_2.id_empresa_transaccion |
+-----------------------------------------------+---------------------------------------------------+-------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
| 18                                            | Owen                                              | 34                                              | 4759.0                                             | Samsung                                            | 1383.0                                             | 2018-01-21                                         | 3                                                  |
| 30                                            | Clayton                                           | 52                                              | 9505.0                                             | HP                                                 | 2331.0                                             | 2018-01-21                                         | 6                                                  |
| 47                                            | Vernon                                            | 35                                              | 7109.0                                             | Sony                                               | 2280.0                                             | 2018-01-21                                         | 2                                                  |
| 28                                            | Stephen                                           | 53                                              | 9469.0                                             | HP                                                 | 730.0                                              | 2018-01-21                                         | 1                                                  |
| 91                                            | Erica                                             | 32                                              | 8934.0                                             | Google                                             | 3081.0                                             | 2018-01-21                                         | 4                                                  |
| 74                                            | Kaitlin                                           | 56                                              | 6515.0                                             | Sony                                               | 2409.0                                             | 2018-01-21                                         | 8                                                  |
| 83                                            | Giselle                                           | 45                                              | 2503.0                                             | Microsoft                                          | 2079.0                                             | 2018-01-21                                         | 5                                                  |
| 48                                            | Illiana                                           | 18                                              | 1454.0                                             | HP                                                 | 2543.0                                             | 2018-01-21                                         | 4                                                  |
| 15                                            | Wanda                                             | 27                                              | 1539.0                                             | Amazon                                             | 1434.0                                             | 2018-01-21                                         | 6                                                  |
| 89                                            | Kelly                                             | 55                                              | 10110.0                                            | Google                                             | 780.0                                              | 2018-01-21                                         | 4                                                  |
+-----------------------------------------------+---------------------------------------------------+-------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
10 rows selected (0.611 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Transaccion_Persona_Empresa_Enriquecida
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TEMPORARY TABLE UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA(
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ID_PERSONA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> NOMBRE_PERSONA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> EDAD_PERSONA INT,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SALARIO_PERSONA DOUBLE,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TRABAJO_PERSONA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> MONTO_TRANSACCION DOUBLE,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FECHA_TRANSACCION STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> EMPRESA_TRANSACCION STRING
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> )
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS PARQUET;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210449_b8f44b6c-6d44-4cd7-8e1e-0d3ab0b735a5): CREATE TEMPORARY TABLE UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA(
ID_PERSONA STRING,
NOMBRE_PERSONA STRING,
EDAD_PERSONA INT,
SALARIO_PERSONA DOUBLE,
TRABAJO_PERSONA STRING,
MONTO_TRANSACCION DOUBLE,
FECHA_TRANSACCION STRING,
EMPRESA_TRANSACCION STRING
)
STORED AS PARQUET
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624210449_b8f44b6c-6d44-4cd7-8e1e-0d3ab0b735a5); Time taken: 0.04 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210449_b8f44b6c-6d44-4cd7-8e1e-0d3ab0b735a5): CREATE TEMPORARY TABLE UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA(
ID_PERSONA STRING,
NOMBRE_PERSONA STRING,
EDAD_PERSONA INT,
SALARIO_PERSONA DOUBLE,
TRABAJO_PERSONA STRING,
MONTO_TRANSACCION DOUBLE,
FECHA_TRANSACCION STRING,
EMPRESA_TRANSACCION STRING
)
STORED AS PARQUET
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624210449_b8f44b6c-6d44-4cd7-8e1e-0d3ab0b735a5); Time taken: 0.044 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TEMPORARY TABLE UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA(
ID_PERSONA STRING,
NOMBRE_PERSONA STRING,
EDAD_PERSONA INT,
SALARIO_PERSONA DOUBLE,
TRABAJO_PERSONA STRING,
MONTO_TRANSACCION DOUBLE,
FECHA_TRANSACCION STRING,
EMPRESA_TRANSACCION STRING
)
STORED AS PARQUET
No rows affected (0.128 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Inserción de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> INSERT INTO UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SELECT
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.ID_PERSONA AS ID_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.NOMBRE_PERSONA AS NOMBRE_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.EDAD_PERSONA AS EDAD_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.SALARIO_PERSONA AS SALARIO_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.TRABAJO_PERSONA AS TRABAJO_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.MONTO_TRANSACCION AS MONTO_TRANSACCION,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.FECHA_TRANSACCION AS FECHA_TRANSACCION,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   E.NOMBRE AS EMPRESA_TRANSACCION
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FROM
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2 T
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> JOIN
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   UNIVERSAL.EMPRESA E
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> ON
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   T.ID_EMPRESA_TRANSACCION = E.ID;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210449_23e58cfb-938b-49a3-95af-5c804b68afe0): INSERT INTO UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA
SELECT
T.ID_PERSONA AS ID_PERSONA,
T.NOMBRE_PERSONA AS NOMBRE_PERSONA,
T.EDAD_PERSONA AS EDAD_PERSONA,
T.SALARIO_PERSONA AS SALARIO_PERSONA,
T.TRABAJO_PERSONA AS TRABAJO_PERSONA,
T.MONTO_TRANSACCION AS MONTO_TRANSACCION,
T.FECHA_TRANSACCION AS FECHA_TRANSACCION,
E.NOMBRE AS EMPRESA_TRANSACCION
FROM
UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2 T
JOIN
UNIVERSAL.EMPRESA E
ON
T.ID_EMPRESA_TRANSACCION = E.ID
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:id_persona, type:string, comment:null), FieldSchema(name:nombre_persona, type:string, comment:null), FieldSchema(name:edad_persona, type:int, comment:null), FieldSchema(name:salario_persona, type:double, comment:null), FieldSchema(name:trabajo_persona, type:string, comment:null), FieldSchema(name:monto_transaccion, type:double, comment:null), FieldSchema(name:fecha_transaccion, type:string, comment:null), FieldSchema(name:empresa_transaccion, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624210449_23e58cfb-938b-49a3-95af-5c804b68afe0); Time taken: 0.973 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210449_23e58cfb-938b-49a3-95af-5c804b68afe0): INSERT INTO UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA
SELECT
T.ID_PERSONA AS ID_PERSONA,
T.NOMBRE_PERSONA AS NOMBRE_PERSONA,
T.EDAD_PERSONA AS EDAD_PERSONA,
T.SALARIO_PERSONA AS SALARIO_PERSONA,
T.TRABAJO_PERSONA AS TRABAJO_PERSONA,
T.MONTO_TRANSACCION AS MONTO_TRANSACCION,
T.FECHA_TRANSACCION AS FECHA_TRANSACCION,
E.NOMBRE AS EMPRESA_TRANSACCION
FROM
UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2 T
JOIN
UNIVERSAL.EMPRESA E
ON
T.ID_EMPRESA_TRANSACCION = E.ID
WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
INFO  : Query ID = root_20240624210449_23e58cfb-938b-49a3-95af-5c804b68afe0
INFO  : Total jobs = 2
INFO  : Starting task [Stage-6:MAPREDLOCAL] in serial mode
INFO  : Execution completed successfully
INFO  : MapredLocal task succeeded
INFO  : Launching Job 1 out of 2
INFO  : Starting task [Stage-5:MAPRED] in serial mode
INFO  : Number of reduce tasks is set to 0 since there's no reduce operator
DEBUG : Configuring job job_1719249550016_0032 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0032 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0032
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0032
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0032/
INFO  : Starting Job = job_1719249550016_0032, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0032/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0032
INFO  : Hadoop job information for Stage-5: number of mappers: 1; number of reducers: 0
INFO  : 2024-06-24 21:05:31,100 Stage-5 map = 0%,  reduce = 0%
INFO  : 2024-06-24 21:05:48,799 Stage-5 map = 100%,  reduce = 0%, Cumulative CPU 20.34 sec
INFO  : MapReduce Total cumulative CPU time: 20 seconds 340 msec
INFO  : Ended Job = job_1719249550016_0032
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table universal.transaccion_persona_empresa_enriquecida from hdfs://namenode:9000/tmp/hive/root/54a9e133-2690-45b5-b216-e8b9eccba2cd/_tmp_space.db/92d1734e-4f8d-4081-904a-b3e31e4e317c/.hive-staging_hive_2024-06-24_21-04-49_647_2296084271181448620-2/-ext-10000
INFO  : Launching Job 2 out of 2
INFO  : Starting task [Stage-3:MAPRED] in serial mode
INFO  : Number of reduce tasks determined at compile time: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0033 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0033 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0033
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0033
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0033/
INFO  : Starting Job = job_1719249550016_0033, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0033/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0033
INFO  : Hadoop job information for Stage-3: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 21:06:10,848 Stage-3 map = 0%,  reduce = 0%
INFO  : 2024-06-24 21:06:21,631 Stage-3 map = 100%,  reduce = 0%, Cumulative CPU 5.76 sec
INFO  : 2024-06-24 21:06:32,312 Stage-3 map = 100%,  reduce = 100%, Cumulative CPU 12.27 sec
INFO  : MapReduce Total cumulative CPU time: 12 seconds 270 msec
INFO  : Ended Job = job_1719249550016_0033
INFO  : Starting task [Stage-2:STATS] in serial mode
INFO  : MapReduce Jobs Launched:
INFO  : Stage-Stage-5: Map: 1   Cumulative CPU: 20.34 sec   HDFS Read: 1450952 HDFS Write: 1439316 SUCCESS
INFO  : Stage-Stage-3: Map: 1  Reduce: 1   Cumulative CPU: 12.27 sec   HDFS Read: 20635 HDFS Write: 1396 SUCCESS
INFO  : Total MapReduce CPU Time Spent: 32 seconds 610 msec
INFO  : Completed executing command(queryId=root_20240624210449_23e58cfb-938b-49a3-95af-5c804b68afe0); Time taken: 102.967 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query INSERT INTO UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA
SELECT
T.ID_PERSONA AS ID_PERSONA,
T.NOMBRE_PERSONA AS NOMBRE_PERSONA,
T.EDAD_PERSONA AS EDAD_PERSONA,
T.SALARIO_PERSONA AS SALARIO_PERSONA,
T.TRABAJO_PERSONA AS TRABAJO_PERSONA,
T.MONTO_TRANSACCION AS MONTO_TRANSACCION,
T.FECHA_TRANSACCION AS FECHA_TRANSACCION,
E.NOMBRE AS EMPRESA_TRANSACCION
FROM
UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2 T
JOIN
UNIVERSAL.EMPRESA E
ON
T.ID_EMPRESA_TRANSACCION = E.ID
No rows affected (103.999 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210633_049e120a-706d-4e25-9ad1-578c4d99aa7b): SELECT * FROM UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:transaccion_persona_empresa_enriquecida.id_persona, type:string, comment:null), FieldSchema(name:transaccion_persona_empresa_enriquecida.nombre_persona, type:string, comment:null), FieldSchema(name:transaccion_persona_empresa_enriquecida.edad_persona, type:int, comment:null), FieldSchema(name:transaccion_persona_empresa_enriquecida.salario_persona, type:double, comment:null), FieldSchema(name:transaccion_persona_empresa_enriquecida.trabajo_persona, type:string, comment:null), FieldSchema(name:transaccion_persona_empresa_enriquecida.monto_transaccion, type:double, comment:null), FieldSchema(name:transaccion_persona_empresa_enriquecida.fecha_transaccion, type:string, comment:null), FieldSchema(name:transaccion_persona_empresa_enriquecida.empresa_transaccion, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624210633_049e120a-706d-4e25-9ad1-578c4d99aa7b); Time taken: 0.214 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210633_049e120a-706d-4e25-9ad1-578c4d99aa7b): SELECT * FROM UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA LIMIT 10
INFO  : Completed executing command(queryId=root_20240624210633_049e120a-706d-4e25-9ad1-578c4d99aa7b); Time taken: 0.005 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA LIMIT 10
+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
| transaccion_persona_empresa_enriquecida.id_persona | transaccion_persona_empresa_enriquecida.nombre_persona | transaccion_persona_empresa_enriquecida.edad_persona | transaccion_persona_empresa_enriquecida.salario_persona | transaccion_persona_empresa_enriquecida.trabajo_persona | transaccion_persona_empresa_enriquecida.monto_transaccion | transaccion_persona_empresa_enriquecida.fecha_transaccion | transaccion_persona_empresa_enriquecida.empresa_transaccion |
+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
| 18                                                 | Owen                                               | 34                                                 | 4759.0                                             | Samsung                                            | 1383.0                                             | 2018-01-21                                         | Apple                                              |
| 30                                                 | Clayton                                            | 52                                                 | 9505.0                                             | HP                                                 | 2331.0                                             | 2018-01-21                                         | Google                                             |
| 47                                                 | Vernon                                             | 35                                                 | 7109.0                                             | Sony                                               | 2280.0                                             | 2018-01-21                                         | Microsoft                                          |
| 28                                                 | Stephen                                            | 53                                                 | 9469.0                                             | HP                                                 | 730.0                                              | 2018-01-21                                         | Walmart                                            |
| 91                                                 | Erica                                              | 32                                                 | 8934.0                                             | Google                                             | 3081.0                                             | 2018-01-21                                         | Toyota                                             |
| 74                                                 | Kaitlin                                            | 56                                                 | 6515.0                                             | Sony                                               | 2409.0                                             | 2018-01-21                                         | HP                                                 |
| 83                                                 | Giselle                                            | 45                                                 | 2503.0                                             | Microsoft                                          | 2079.0                                             | 2018-01-21                                         | Amazon                                             |
| 48                                                 | Illiana                                            | 18                                                 | 1454.0                                             | HP                                                 | 2543.0                                             | 2018-01-21                                         | Toyota                                             |
| 15                                                 | Wanda                                              | 27                                                 | 1539.0                                             | Amazon                                             | 1434.0                                             | 2018-01-21                                         | Google                                             |
| 89                                                 | Kelly                                              | 55                                                 | 10110.0                                            | Google                                             | 780.0                                              | 2018-01-21                                         | Toyota                                             |
+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
10 rows selected (0.734 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Transaccion_Enriquecida
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Inserción de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> INSERT OVERWRITE TABLE UNIVERSAL.TRANSACCION_ENRIQUECIDA
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> PARTITION (FECHA_TRANSACCION)
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SELECT
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   ID_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   NOMBRE_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   EDAD_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   SALARIO_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   TRABAJO_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   MONTO_TRANSACCION,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   EMPRESA_TRANSACCION,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   FECHA_TRANSACCION
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FROM
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210634_ce097c57-0180-45b4-bcef-9f612593e323): INSERT OVERWRITE TABLE UNIVERSAL.TRANSACCION_ENRIQUECIDA
PARTITION (FECHA_TRANSACCION)
SELECT
ID_PERSONA,
NOMBRE_PERSONA,
EDAD_PERSONA,
SALARIO_PERSONA,
TRABAJO_PERSONA,
MONTO_TRANSACCION,
EMPRESA_TRANSACCION,
FECHA_TRANSACCION
FROM
UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:_col0, type:int, comment:null), FieldSchema(name:_col1, type:string, comment:null), FieldSchema(name:_col2, type:int, comment:null), FieldSchema(name:_col3, type:double, comment:null), FieldSchema(name:_col4, type:string, comment:null), FieldSchema(name:_col5, type:double, comment:null), FieldSchema(name:_col6, type:string, comment:null), FieldSchema(name:_col7, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624210634_ce097c57-0180-45b4-bcef-9f612593e323); Time taken: 1.489 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210634_ce097c57-0180-45b4-bcef-9f612593e323): INSERT OVERWRITE TABLE UNIVERSAL.TRANSACCION_ENRIQUECIDA
PARTITION (FECHA_TRANSACCION)
SELECT
ID_PERSONA,
NOMBRE_PERSONA,
EDAD_PERSONA,
SALARIO_PERSONA,
TRABAJO_PERSONA,
MONTO_TRANSACCION,
EMPRESA_TRANSACCION,
FECHA_TRANSACCION
FROM
UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA
WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
INFO  : Query ID = root_20240624210634_ce097c57-0180-45b4-bcef-9f612593e323
INFO  : Total jobs = 3
INFO  : Launching Job 1 out of 3
INFO  : Starting task [Stage-1:MAPRED] in serial mode
INFO  : Number of reduce tasks not specified. Estimated from input data size: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0034 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0034 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0034
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0034
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0034/
INFO  : Starting Job = job_1719249550016_0034, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0034/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0034
INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 21:06:56,512 Stage-1 map = 0%,  reduce = 0%
INFO  : 2024-06-24 21:07:22,637 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 32.53 sec
INFO  : 2024-06-24 21:07:34,484 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 38.09 sec
INFO  : MapReduce Total cumulative CPU time: 38 seconds 90 msec
INFO  : Ended Job = job_1719249550016_0034
INFO  : Starting task [Stage-7:CONDITIONAL] in serial mode
INFO  : Stage-4 is selected by condition resolver.
INFO  : Stage-3 is filtered out by condition resolver.
INFO  : Stage-5 is filtered out by condition resolver.
INFO  : Starting task [Stage-4:MOVE] in serial mode
INFO  : Moving data to directory hdfs://namenode:9000/user/proyectos/proyecto_1/database/universal/transaccion_enriquecida/.hive-staging_hive_2024-06-24_21-06-34_620_8809278051873532767-2/-ext-10000 from hdfs://namenode:9000/user/proyectos/proyecto_1/database/universal/transaccion_enriquecida/.hive-staging_hive_2024-06-24_21-06-34_620_8809278051873532767-2/-ext-10002
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table universal.transaccion_enriquecida partition (fecha_transaccion=null) from hdfs://namenode:9000/user/proyectos/proyecto_1/database/universal/transaccion_enriquecida/.hive-staging_hive_2024-06-24_21-06-34_620_8809278051873532767-2/-ext-10000
INFO  :

INFO  :          Time taken to load dynamic partitions: 0.42 seconds
INFO  :          Time taken for adding to write entity : 0.002 seconds
INFO  : Starting task [Stage-2:STATS] in serial mode
INFO  : MapReduce Jobs Launched:
INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 38.09 sec   HDFS Read: 1461600 HDFS Write: 1470857 SUCCESS
INFO  : Total MapReduce CPU Time Spent: 38 seconds 90 msec
INFO  : Completed executing command(queryId=root_20240624210634_ce097c57-0180-45b4-bcef-9f612593e323); Time taken: 60.707 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query INSERT OVERWRITE TABLE UNIVERSAL.TRANSACCION_ENRIQUECIDA
PARTITION (FECHA_TRANSACCION)
SELECT
ID_PERSONA,
NOMBRE_PERSONA,
EDAD_PERSONA,
SALARIO_PERSONA,
TRABAJO_PERSONA,
MONTO_TRANSACCION,
EMPRESA_TRANSACCION,
FECHA_TRANSACCION
FROM
UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA
No rows affected (62.256 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM UNIVERSAL.TRANSACCION_ENRIQUECIDA LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210736_5ddc2b2a-666d-4a22-a9f9-aa6266b3686e): SELECT * FROM UNIVERSAL.TRANSACCION_ENRIQUECIDA LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:transaccion_enriquecida.id_persona, type:int, comment:null), FieldSchema(name:transaccion_enriquecida.nombre_persona, type:string, comment:null), FieldSchema(name:transaccion_enriquecida.edad_persona, type:int, comment:null), FieldSchema(name:transaccion_enriquecida.salario_persona, type:double, comment:null), FieldSchema(name:transaccion_enriquecida.trabajo_persona, type:string, comment:null), FieldSchema(name:transaccion_enriquecida.monto_transaccion, type:double, comment:null), FieldSchema(name:transaccion_enriquecida.empresa_transaccion, type:string, comment:null), FieldSchema(name:transaccion_enriquecida.fecha_transaccion, type:string, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624210736_5ddc2b2a-666d-4a22-a9f9-aa6266b3686e); Time taken: 0.257 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210736_5ddc2b2a-666d-4a22-a9f9-aa6266b3686e): SELECT * FROM UNIVERSAL.TRANSACCION_ENRIQUECIDA LIMIT 10
INFO  : Completed executing command(queryId=root_20240624210736_5ddc2b2a-666d-4a22-a9f9-aa6266b3686e); Time taken: 0.001 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM UNIVERSAL.TRANSACCION_ENRIQUECIDA LIMIT 10
+-------------------------------------+-----------------------------------------+---------------------------------------+------------------------------------------+------------------------------------------+--------------------------------------------+----------------------------------------------+--------------------------------------------+
| transaccion_enriquecida.id_persona  | transaccion_enriquecida.nombre_persona  | transaccion_enriquecida.edad_persona  | transaccion_enriquecida.salario_persona  | transaccion_enriquecida.trabajo_persona  | transaccion_enriquecida.monto_transaccion  | transaccion_enriquecida.empresa_transaccion  | transaccion_enriquecida.fecha_transaccion  |
+-------------------------------------+-----------------------------------------+---------------------------------------+------------------------------------------+------------------------------------------+--------------------------------------------+----------------------------------------------+--------------------------------------------+
| 18                                  | Owen                                    | 34                                    | 4759.0                                   | Samsung                                  | 1383.0                                     | Apple                                        | 2018-01-21                                 |
| 30                                  | Clayton                                 | 52                                    | 9505.0                                   | HP                                       | 2331.0                                     | Google                                       | 2018-01-21                                 |
| 47                                  | Vernon                                  | 35                                    | 7109.0                                   | Sony                                     | 2280.0                                     | Microsoft                                    | 2018-01-21                                 |
| 28                                  | Stephen                                 | 53                                    | 9469.0                                   | HP                                       | 730.0                                      | Walmart                                      | 2018-01-21                                 |
| 91                                  | Erica                                   | 32                                    | 8934.0                                   | Google                                   | 3081.0                                     | Toyota                                       | 2018-01-21                                 |
| 74                                  | Kaitlin                                 | 56                                    | 6515.0                                   | Sony                                     | 2409.0                                     | HP                                           | 2018-01-21                                 |
| 83                                  | Giselle                                 | 45                                    | 2503.0                                   | Microsoft                                | 2079.0                                     | Amazon                                       | 2018-01-21                                 |
| 48                                  | Illiana                                 | 18                                    | 1454.0                                   | HP                                       | 2543.0                                     | Toyota                                       | 2018-01-21                                 |
| 15                                  | Wanda                                   | 27                                    | 1539.0                                   | Amazon                                   | 1434.0                                     | Google                                       | 2018-01-21                                 |
| 89                                  | Kelly                                   | 55                                    | 10110.0                                  | Google                                   | 780.0                                      | Toyota                                       | 2018-01-21                                 |
+-------------------------------------+-----------------------------------------+---------------------------------------+------------------------------------------+------------------------------------------+--------------------------------------------+----------------------------------------------+--------------------------------------------+
10 rows selected (0.463 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Borrar tablas temporales
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> DROP TABLE IF EXISTS UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210737_20e809e9-93ff-45aa-9946-720b54ab9194): DROP TABLE IF EXISTS UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624210737_20e809e9-93ff-45aa-9946-720b54ab9194); Time taken: 0.01 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210737_20e809e9-93ff-45aa-9946-720b54ab9194): DROP TABLE IF EXISTS UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624210737_20e809e9-93ff-45aa-9946-720b54ab9194); Time taken: 0.038 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query DROP TABLE IF EXISTS UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_1
No rows affected (0.105 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> DROP TABLE IF EXISTS UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210737_b9054556-3233-4e0d-8093-8add3841bb9d): DROP TABLE IF EXISTS UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624210737_b9054556-3233-4e0d-8093-8add3841bb9d); Time taken: 0.008 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210737_b9054556-3233-4e0d-8093-8add3841bb9d): DROP TABLE IF EXISTS UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624210737_b9054556-3233-4e0d-8093-8add3841bb9d); Time taken: 0.025 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query DROP TABLE IF EXISTS UNIVERSAL.TRANSACCION_PERSONA_ENRIQUECIDA_2
No rows affected (0.093 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> DROP TABLE IF EXISTS UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624210737_236a1025-cbee-417d-8103-b26cee441461): DROP TABLE IF EXISTS UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624210737_236a1025-cbee-417d-8103-b26cee441461); Time taken: 0.018 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624210737_236a1025-cbee-417d-8103-b26cee441461): DROP TABLE IF EXISTS UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624210737_236a1025-cbee-417d-8103-b26cee441461); Time taken: 0.024 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query DROP TABLE IF EXISTS UNIVERSAL.TRANSACCION_PERSONA_EMPRESA_ENRIQUECIDA
No rows affected (0.123 seconds)
0: jdbc:hive2://localhost:10000> Closing: 0: jdbc:hive2://localhost:10000
root@hive-server:/opt/hive/bin#

# %% [markdown]
# #### Esquema `SMART`

# %%
beeline -u jdbc:hive2://localhost:10000 -f /opt/hive/deploy/deploy_esquema_smart.sql --hiveconf "PARAM_RAIZ=proyectos" --hiveconf "PARAM_PROYECTO=proyecto_1"

# %%
C:\Users\Alfonso\Documents\ecosistema-hadoop>docker exec -it hive-server bash
root@hive-server:/opt#
root@hive-server:/opt# cd hive
root@hive-server:/opt/hive#
root@hive-server:/opt/hive# cd bin
root@hive-server:/opt/hive/bin#
root@hive-server:/opt/hive/bin# beeline -u jdbc:hive2://localhost:10000 -f /opt/hive/deploy/deploy_esquema_smart.sql --hiveconf "PARAM_RAIZ=proyectos" --hiveconf "PARAM
_PROYECTO=proyecto_1"
SLF4J: Class path contains multiple SLF4J bindings.
SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
Connecting to jdbc:hive2://localhost:10000
Connected to: Apache Hive (version 3.1.2)
Driver: Hive JDBC (version 3.1.2)
Transaction isolation: TRANSACTION_REPEATABLE_READ
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @author Alfonso Perez
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @email perezlino@gmail.com
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @copyright Alfonso Perez
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Despliegue del esquema "SMART"
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @section Tuning
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET hive.execution.engine=mr;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.job.maps=8;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.input.fileinputformat.split.maxsize=128000000;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.input.fileinputformat.split.minsize=128000000;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.map.cpu.vcores=2;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.map.memory.mb=128;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.job.reduces=8;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.reduce.cpu.vcores=2;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.reduce.memory.mb=128;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET hive.exec.dynamic.partition=true;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SET hive.exec.dynamic.partition.mode=nonstrict;
No rows affected (0.214 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SET hive.exec.max.dynamic.partitions=9999;
No rows affected (0.014 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SET hive.exec.max.dynamic.partitions.pernode=9999;
No rows affected (0.012 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SET hive.exec.compress.output=true;
No rows affected (0.015 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SET parquet.compression=SNAPPY;
No rows affected (0.01 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET orc.compression=SNAPPY;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET avro.output.codec=SNAPPY;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET mapreduce.job.queue.name=q_user_main;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET spark.job.queue.name=q_user_main;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- SET tez.job.queue.name=q_user_main;
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- @section Programa
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Borrado de la base de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> DROP DATABASE IF EXISTS SMART CASCADE;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624211220_0f6a8d9c-c036-4107-8eaf-5081f1ab1ac1): DROP DATABASE IF EXISTS SMART CASCADE
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624211220_0f6a8d9c-c036-4107-8eaf-5081f1ab1ac1); Time taken: 0.016 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624211220_0f6a8d9c-c036-4107-8eaf-5081f1ab1ac1): DROP DATABASE IF EXISTS SMART CASCADE
INFO  : Completed executing command(queryId=root_20240624211220_0f6a8d9c-c036-4107-8eaf-5081f1ab1ac1); Time taken: 0.0 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query DROP DATABASE IF EXISTS SMART CASCADE
No rows affected (0.045 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de la base de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- en LOCATION podemos indicar solo la ruta: "/user/..." o anteponer el "hdfs:///user/..."
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE DATABASE IF NOT EXISTS SMART
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION '/user/${hiveconf:PARAM_RAIZ}/${hiveconf:PARAM_PROYECTO}/database/smart';
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624211220_15d8d72d-bc12-4686-9412-410472f54da1): CREATE DATABASE IF NOT EXISTS SMART
LOCATION '/user/proyectos/proyecto_1/database/smart'
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624211220_15d8d72d-bc12-4686-9412-410472f54da1); Time taken: 0.007 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624211220_15d8d72d-bc12-4686-9412-410472f54da1): CREATE DATABASE IF NOT EXISTS SMART
LOCATION '/user/proyectos/proyecto_1/database/smart'
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624211220_15d8d72d-bc12-4686-9412-410472f54da1); Time taken: 0.07 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE DATABASE IF NOT EXISTS SMART
LOCATION '/user/proyectos/proyecto_1/database/smart'
No rows affected (0.106 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Transaccion_por_Edad
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de la tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- en LOCATION podemos indicar solo la ruta: "/user/..." o anteponer el "hdfs:///user/..."
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TABLE SMART.TRANSACCION_POR_EDAD(
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> EDAD_PERSONA INT,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> CANTIDAD_TRANSACCIONES INT,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SUMA_MONTO_TRANSACCIONES DOUBLE
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> )
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS PARQUET
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION '/user/proyectos/proyecto3/database/smart/transaccion_por_edad'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TBLPROPERTIES ("parquet.compression"="SNAPPY");
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624211220_c03b24c8-e182-4719-b469-263977f3359b): CREATE TABLE SMART.TRANSACCION_POR_EDAD(
EDAD_PERSONA INT,
CANTIDAD_TRANSACCIONES INT,
SUMA_MONTO_TRANSACCIONES DOUBLE
)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto3/database/smart/transaccion_por_edad'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624211220_c03b24c8-e182-4719-b469-263977f3359b); Time taken: 0.015 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624211220_c03b24c8-e182-4719-b469-263977f3359b): CREATE TABLE SMART.TRANSACCION_POR_EDAD(
EDAD_PERSONA INT,
CANTIDAD_TRANSACCIONES INT,
SUMA_MONTO_TRANSACCIONES DOUBLE
)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto3/database/smart/transaccion_por_edad'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624211220_c03b24c8-e182-4719-b469-263977f3359b); Time taken: 0.105 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TABLE SMART.TRANSACCION_POR_EDAD(
EDAD_PERSONA INT,
CANTIDAD_TRANSACCIONES INT,
SUMA_MONTO_TRANSACCIONES DOUBLE
)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto3/database/smart/transaccion_por_edad'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
No rows affected (0.163 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Inserción de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> INSERT OVERWRITE TABLE SMART.TRANSACCION_POR_EDAD
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SELECT
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   EDAD_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   COUNT(MONTO_TRANSACCION),
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   SUM(MONTO_TRANSACCION)
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FROM
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   UNIVERSAL.TRANSACCION_ENRIQUECIDA
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> GROUP BY
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   EDAD_PERSONA;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624211220_203a6b75-12af-4314-b5b1-0f0dd7cf3e65): INSERT OVERWRITE TABLE SMART.TRANSACCION_POR_EDAD
SELECT
EDAD_PERSONA,
COUNT(MONTO_TRANSACCION),
SUM(MONTO_TRANSACCION)
FROM
UNIVERSAL.TRANSACCION_ENRIQUECIDA
GROUP BY
EDAD_PERSONA
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:_col0, type:int, comment:null), FieldSchema(name:_col1, type:int, comment:null), FieldSchema(name:_col2, type:double, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624211220_203a6b75-12af-4314-b5b1-0f0dd7cf3e65); Time taken: 0.769 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624211220_203a6b75-12af-4314-b5b1-0f0dd7cf3e65): INSERT OVERWRITE TABLE SMART.TRANSACCION_POR_EDAD
SELECT
EDAD_PERSONA,
COUNT(MONTO_TRANSACCION),
SUM(MONTO_TRANSACCION)
FROM
UNIVERSAL.TRANSACCION_ENRIQUECIDA
GROUP BY
EDAD_PERSONA
WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
INFO  : Query ID = root_20240624211220_203a6b75-12af-4314-b5b1-0f0dd7cf3e65
INFO  : Total jobs = 2
INFO  : Launching Job 1 out of 2
INFO  : Starting task [Stage-1:MAPRED] in serial mode
INFO  : Number of reduce tasks not specified. Estimated from input data size: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0035 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0035 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0035
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0035
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0035/
INFO  : Starting Job = job_1719249550016_0035, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0035/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0035
INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 21:12:36,734 Stage-1 map = 0%,  reduce = 0%
INFO  : 2024-06-24 21:12:53,677 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 15.62 sec
INFO  : 2024-06-24 21:13:12,746 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 33.85 sec
INFO  : MapReduce Total cumulative CPU time: 33 seconds 850 msec
INFO  : Ended Job = job_1719249550016_0035
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table smart.transaccion_por_edad from hdfs://namenode:9000/user/proyectos/proyecto3/database/smart/transaccion_por_edad/.hive-staging_hive_2024-06-24_21-12-20_657_6149049041127834152-2/-ext-10000
INFO  : Launching Job 2 out of 2
INFO  : Starting task [Stage-3:MAPRED] in serial mode
INFO  : Number of reduce tasks determined at compile time: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0036 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0036 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0036
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0036
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0036/
INFO  : Starting Job = job_1719249550016_0036, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0036/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0036
INFO  : Hadoop job information for Stage-3: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 21:13:35,437 Stage-3 map = 0%,  reduce = 0%
INFO  : 2024-06-24 21:13:46,035 Stage-3 map = 100%,  reduce = 0%, Cumulative CPU 4.87 sec
INFO  : 2024-06-24 21:13:55,842 Stage-3 map = 100%,  reduce = 100%, Cumulative CPU 9.25 sec
INFO  : MapReduce Total cumulative CPU time: 9 seconds 250 msec
INFO  : Ended Job = job_1719249550016_0036
INFO  : Starting task [Stage-2:STATS] in serial mode
INFO  : MapReduce Jobs Launched:
INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 33.85 sec   HDFS Read: 629722 HDFS Write: 2102 SUCCESS
INFO  : Stage-Stage-3: Map: 1  Reduce: 1   Cumulative CPU: 9.25 sec   HDFS Read: 12096 HDFS Write: 763 SUCCESS
INFO  : Total MapReduce CPU Time Spent: 43 seconds 100 msec
INFO  : Completed executing command(queryId=root_20240624211220_203a6b75-12af-4314-b5b1-0f0dd7cf3e65); Time taken: 95.663 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query INSERT OVERWRITE TABLE SMART.TRANSACCION_POR_EDAD
SELECT
EDAD_PERSONA,
COUNT(MONTO_TRANSACCION),
SUM(MONTO_TRANSACCION)
FROM
UNIVERSAL.TRANSACCION_ENRIQUECIDA
GROUP BY
EDAD_PERSONA
No rows affected (96.462 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM SMART.TRANSACCION_POR_EDAD LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624211357_33802b06-a955-433b-8563-c971c3d56730): SELECT * FROM SMART.TRANSACCION_POR_EDAD LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:transaccion_por_edad.edad_persona, type:int, comment:null), FieldSchema(name:transaccion_por_edad.cantidad_transacciones, type:int, comment:null), FieldSchema(name:transaccion_por_edad.suma_monto_transacciones, type:double, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624211357_33802b06-a955-433b-8563-c971c3d56730); Time taken: 0.164 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624211357_33802b06-a955-433b-8563-c971c3d56730): SELECT * FROM SMART.TRANSACCION_POR_EDAD LIMIT 10
INFO  : Completed executing command(queryId=root_20240624211357_33802b06-a955-433b-8563-c971c3d56730); Time taken: 0.001 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM SMART.TRANSACCION_POR_EDAD LIMIT 10
+------------------------------------+----------------------------------------------+------------------------------------------------+
| transaccion_por_edad.edad_persona  | transaccion_por_edad.cantidad_transacciones  | transaccion_por_edad.suma_monto_transacciones  |
+------------------------------------+----------------------------------------------+------------------------------------------------+
| 18                                 | 4707                                         | 1.0478251E7                                    |
| 19                                 | 9513                                         | 2.1448462E7                                    |
| 22                                 | 11677                                        | 2.613166E7                                     |
| 23                                 | 4670                                         | 1.0415767E7                                    |
| 24                                 | 9379                                         | 2.1185021E7                                    |
| 25                                 | 4621                                         | 1.0358377E7                                    |
| 26                                 | 6891                                         | 1.5612084E7                                    |
| 27                                 | 11766                                        | 2.642914E7                                     |
| 28                                 | 2397                                         | 5419577.0                                      |
| 29                                 | 4607                                         | 1.0278431E7                                    |
+------------------------------------+----------------------------------------------+------------------------------------------------+
10 rows selected (0.356 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Transaccion_por_Trabajo
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de la tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- en LOCATION podemos indicar solo la ruta: "/user/..." o anteponer el "hdfs:///user/..."
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TABLE SMART.TRANSACCION_POR_TRABAJO(
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TRABAJO_PERSONA STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> CANTIDAD_TRANSACCIONES INT,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SUMA_MONTO_TRANSACCIONES DOUBLE
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> )
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS PARQUET
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION '/user/proyectos/proyecto3/database/smart/transaccion_por_trabajo'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TBLPROPERTIES ("parquet.compression"="SNAPPY");
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624211357_e9a21712-d4c4-47cf-b616-aeb380ceee36): CREATE TABLE SMART.TRANSACCION_POR_TRABAJO(
TRABAJO_PERSONA STRING,
CANTIDAD_TRANSACCIONES INT,
SUMA_MONTO_TRANSACCIONES DOUBLE
)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto3/database/smart/transaccion_por_trabajo'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624211357_e9a21712-d4c4-47cf-b616-aeb380ceee36); Time taken: 0.011 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624211357_e9a21712-d4c4-47cf-b616-aeb380ceee36): CREATE TABLE SMART.TRANSACCION_POR_TRABAJO(
TRABAJO_PERSONA STRING,
CANTIDAD_TRANSACCIONES INT,
SUMA_MONTO_TRANSACCIONES DOUBLE
)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto3/database/smart/transaccion_por_trabajo'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624211357_e9a21712-d4c4-47cf-b616-aeb380ceee36); Time taken: 0.135 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TABLE SMART.TRANSACCION_POR_TRABAJO(
TRABAJO_PERSONA STRING,
CANTIDAD_TRANSACCIONES INT,
SUMA_MONTO_TRANSACCIONES DOUBLE
)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto3/database/smart/transaccion_por_trabajo'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
No rows affected (0.196 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Inserción de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> INSERT OVERWRITE TABLE SMART.TRANSACCION_POR_TRABAJO
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SELECT
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   TRABAJO_PERSONA,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   COUNT(MONTO_TRANSACCION),
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   SUM(MONTO_TRANSACCION)
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FROM
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   UNIVERSAL.TRANSACCION_ENRIQUECIDA
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> GROUP BY
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   TRABAJO_PERSONA;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624211357_9b1d73de-bde2-44b2-8dbe-e302f74835d4): INSERT OVERWRITE TABLE SMART.TRANSACCION_POR_TRABAJO
SELECT
TRABAJO_PERSONA,
COUNT(MONTO_TRANSACCION),
SUM(MONTO_TRANSACCION)
FROM
UNIVERSAL.TRANSACCION_ENRIQUECIDA
GROUP BY
TRABAJO_PERSONA
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:_col0, type:string, comment:null), FieldSchema(name:_col1, type:int, comment:null), FieldSchema(name:_col2, type:double, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624211357_9b1d73de-bde2-44b2-8dbe-e302f74835d4); Time taken: 1.46 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624211357_9b1d73de-bde2-44b2-8dbe-e302f74835d4): INSERT OVERWRITE TABLE SMART.TRANSACCION_POR_TRABAJO
SELECT
TRABAJO_PERSONA,
COUNT(MONTO_TRANSACCION),
SUM(MONTO_TRANSACCION)
FROM
UNIVERSAL.TRANSACCION_ENRIQUECIDA
GROUP BY
TRABAJO_PERSONA
WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
INFO  : Query ID = root_20240624211357_9b1d73de-bde2-44b2-8dbe-e302f74835d4
INFO  : Total jobs = 2
INFO  : Launching Job 1 out of 2
INFO  : Starting task [Stage-1:MAPRED] in serial mode
INFO  : Number of reduce tasks not specified. Estimated from input data size: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0037 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0037 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0037
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0037
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0037/
INFO  : Starting Job = job_1719249550016_0037, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0037/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0037
INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 21:14:17,695 Stage-1 map = 0%,  reduce = 0%
INFO  : 2024-06-24 21:14:29,841 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 9.77 sec
INFO  : 2024-06-24 21:14:42,770 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 20.76 sec
INFO  : MapReduce Total cumulative CPU time: 20 seconds 760 msec
INFO  : Ended Job = job_1719249550016_0037
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table smart.transaccion_por_trabajo from hdfs://namenode:9000/user/proyectos/proyecto3/database/smart/transaccion_por_trabajo/.hive-staging_hive_2024-06-24_21-13-57_940_8793725007098056178-2/-ext-10000
INFO  : Launching Job 2 out of 2
INFO  : Starting task [Stage-3:MAPRED] in serial mode
INFO  : Number of reduce tasks determined at compile time: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0038 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0038 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0038
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0038
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0038/
INFO  : Starting Job = job_1719249550016_0038, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0038/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0038
INFO  : Hadoop job information for Stage-3: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 21:15:06,220 Stage-3 map = 0%,  reduce = 0%
INFO  : 2024-06-24 21:15:24,561 Stage-3 map = 100%,  reduce = 0%, Cumulative CPU 7.94 sec
INFO  : 2024-06-24 21:15:42,331 Stage-3 map = 100%,  reduce = 100%, Cumulative CPU 14.4 sec
INFO  : MapReduce Total cumulative CPU time: 14 seconds 400 msec
INFO  : Ended Job = job_1719249550016_0038
INFO  : Starting task [Stage-2:STATS] in serial mode
INFO  : MapReduce Jobs Launched:
INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 20.76 sec   HDFS Read: 571083 HDFS Write: 1291 SUCCESS
INFO  : Stage-Stage-3: Map: 1  Reduce: 1   Cumulative CPU: 14.4 sec   HDFS Read: 12580 HDFS Write: 379 SUCCESS
INFO  : Total MapReduce CPU Time Spent: 35 seconds 160 msec
INFO  : Completed executing command(queryId=root_20240624211357_9b1d73de-bde2-44b2-8dbe-e302f74835d4); Time taken: 104.84 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query INSERT OVERWRITE TABLE SMART.TRANSACCION_POR_TRABAJO
SELECT
TRABAJO_PERSONA,
COUNT(MONTO_TRANSACCION),
SUM(MONTO_TRANSACCION)
FROM
UNIVERSAL.TRANSACCION_ENRIQUECIDA
GROUP BY
TRABAJO_PERSONA
No rows affected (106.35 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM SMART.TRANSACCION_POR_TRABAJO LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624211544_660597a9-c4aa-4364-bc16-50bf01a1029d): SELECT * FROM SMART.TRANSACCION_POR_TRABAJO LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:transaccion_por_trabajo.trabajo_persona, type:string, comment:null), FieldSchema(name:transaccion_por_trabajo.cantidad_transacciones, type:int, comment:null), FieldSchema(name:transaccion_por_trabajo.suma_monto_transacciones, type:double, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624211544_660597a9-c4aa-4364-bc16-50bf01a1029d); Time taken: 0.345 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624211544_660597a9-c4aa-4364-bc16-50bf01a1029d): SELECT * FROM SMART.TRANSACCION_POR_TRABAJO LIMIT 10
INFO  : Completed executing command(queryId=root_20240624211544_660597a9-c4aa-4364-bc16-50bf01a1029d); Time taken: 0.003 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM SMART.TRANSACCION_POR_TRABAJO LIMIT 10
+------------------------------------------+-------------------------------------------------+---------------------------------------------------+
| transaccion_por_trabajo.trabajo_persona  | transaccion_por_trabajo.cantidad_transacciones  | transaccion_por_trabajo.suma_monto_transacciones  |
+------------------------------------------+-------------------------------------------------+---------------------------------------------------+
| Amazon                                   | 32911                                           | 7.3819971E7                                       |
| Apple                                    | 25923                                           | 5.801854E7                                        |
| Google                                   | 30583                                           | 6.8591761E7                                       |
| HP                                       | 21247                                           | 4.7466547E7                                       |
| IBM                                      | 14124                                           | 3.1569729E7                                       |
| Microsoft                                | 33098                                           | 7.4393407E7                                       |
| Samsung                                  | 21160                                           | 4.7443803E7                                       |
| Sony                                     | 20917                                           | 4.7099878E7                                       |
| Toyota                                   | 18979                                           | 4.2356472E7                                       |
| Walmart                                  | 16098                                           | 3.6413955E7                                       |
+------------------------------------------+-------------------------------------------------+---------------------------------------------------+
10 rows selected (0.738 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Tabla Transaccion_por_Empresa
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> --
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Creación de la tabla
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- en LOCATION podemos indicar solo la ruta: "/user/..." o anteponer el "hdfs:///user/..."
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> CREATE TABLE SMART.TRANSACCION_POR_EMPRESA(
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> EMPRESA_TRANSACCION STRING,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> CANTIDAD_TRANSACCIONES INT,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SUMA_MONTO_TRANSACCIONES DOUBLE
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> )
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> STORED AS PARQUET
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> LOCATION '/user/proyectos/proyecto3/database/smart/transaccion_por_empresa'
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> TBLPROPERTIES ("parquet.compression"="SNAPPY");
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624211545_aadeebc8-ff37-4d97-91c3-82aaa0c2858d): CREATE TABLE SMART.TRANSACCION_POR_EMPRESA(
EMPRESA_TRANSACCION STRING,
CANTIDAD_TRANSACCIONES INT,
SUMA_MONTO_TRANSACCIONES DOUBLE
)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto3/database/smart/transaccion_por_empresa'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
INFO  : Completed compiling command(queryId=root_20240624211545_aadeebc8-ff37-4d97-91c3-82aaa0c2858d); Time taken: 0.066 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624211545_aadeebc8-ff37-4d97-91c3-82aaa0c2858d): CREATE TABLE SMART.TRANSACCION_POR_EMPRESA(
EMPRESA_TRANSACCION STRING,
CANTIDAD_TRANSACCIONES INT,
SUMA_MONTO_TRANSACCIONES DOUBLE
)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto3/database/smart/transaccion_por_empresa'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
INFO  : Starting task [Stage-0:DDL] in serial mode
INFO  : Completed executing command(queryId=root_20240624211545_aadeebc8-ff37-4d97-91c3-82aaa0c2858d); Time taken: 0.272 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query CREATE TABLE SMART.TRANSACCION_POR_EMPRESA(
EMPRESA_TRANSACCION STRING,
CANTIDAD_TRANSACCIONES INT,
SUMA_MONTO_TRANSACCIONES DOUBLE
)
STORED AS PARQUET
LOCATION '/user/proyectos/proyecto3/database/smart/transaccion_por_empresa'
TBLPROPERTIES ("parquet.compression"="SNAPPY")
No rows affected (0.445 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Inserción de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> INSERT OVERWRITE TABLE SMART.TRANSACCION_POR_EMPRESA
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> SELECT
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   EMPRESA_TRANSACCION,
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   COUNT(MONTO_TRANSACCION),
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   SUM(MONTO_TRANSACCION)
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> FROM
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   UNIVERSAL.TRANSACCION_ENRIQUECIDA
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .> GROUP BY
. . . . . . . . . . . . . . . .>
. . . . . . . . . . . . . . . .>   EMPRESA_TRANSACCION;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624211546_1108b205-3bbd-465d-8c7b-e07f6a21bfde): INSERT OVERWRITE TABLE SMART.TRANSACCION_POR_EMPRESA
SELECT
EMPRESA_TRANSACCION,
COUNT(MONTO_TRANSACCION),
SUM(MONTO_TRANSACCION)
FROM
UNIVERSAL.TRANSACCION_ENRIQUECIDA
GROUP BY
EMPRESA_TRANSACCION
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:_col0, type:string, comment:null), FieldSchema(name:_col1, type:int, comment:null), FieldSchema(name:_col2, type:double, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624211546_1108b205-3bbd-465d-8c7b-e07f6a21bfde); Time taken: 1.224 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624211546_1108b205-3bbd-465d-8c7b-e07f6a21bfde): INSERT OVERWRITE TABLE SMART.TRANSACCION_POR_EMPRESA
SELECT
EMPRESA_TRANSACCION,
COUNT(MONTO_TRANSACCION),
SUM(MONTO_TRANSACCION)
FROM
UNIVERSAL.TRANSACCION_ENRIQUECIDA
GROUP BY
EMPRESA_TRANSACCION
WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
INFO  : Query ID = root_20240624211546_1108b205-3bbd-465d-8c7b-e07f6a21bfde
INFO  : Total jobs = 2
INFO  : Launching Job 1 out of 2
INFO  : Starting task [Stage-1:MAPRED] in serial mode
INFO  : Number of reduce tasks not specified. Estimated from input data size: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0039 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0039 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0039
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0039
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0039/
INFO  : Starting Job = job_1719249550016_0039, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0039/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0039
INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 21:16:16,049 Stage-1 map = 0%,  reduce = 0%
INFO  : 2024-06-24 21:16:40,824 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 26.46 sec
INFO  : 2024-06-24 21:17:00,189 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 40.84 sec
INFO  : MapReduce Total cumulative CPU time: 40 seconds 840 msec
INFO  : Ended Job = job_1719249550016_0039
INFO  : Starting task [Stage-0:MOVE] in serial mode
INFO  : Loading data to table smart.transaccion_por_empresa from hdfs://namenode:9000/user/proyectos/proyecto3/database/smart/transaccion_por_empresa/.hive-staging_hive_2024-06-24_21-15-46_261_5351257610144553755-2/-ext-10000
INFO  : Launching Job 2 out of 2
INFO  : Starting task [Stage-3:MAPRED] in serial mode
INFO  : Number of reduce tasks determined at compile time: 1
INFO  : In order to change the average load for a reducer (in bytes):
INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
INFO  : In order to limit the maximum number of reducers:
INFO  :   set hive.exec.reducers.max=<number>
INFO  : In order to set a constant number of reducers:
INFO  :   set mapreduce.job.reduces=<number>
DEBUG : Configuring job job_1719249550016_0040 with /tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0040 as the submit dir
DEBUG : adding the following namenodes' delegation tokens:[hdfs://namenode:9000]
DEBUG : Creating splits at hdfs://namenode:9000/tmp/hadoop-yarn/staging/root/.staging/job_1719249550016_0040
INFO  : number of splits:1
INFO  : Submitting tokens for job: job_1719249550016_0040
INFO  : Executing with tokens: []
INFO  : The url to track the job: http://resourcemanager:8088/proxy/application_1719249550016_0040/
INFO  : Starting Job = job_1719249550016_0040, Tracking URL = http://resourcemanager:8088/proxy/application_1719249550016_0040/
INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1719249550016_0040
INFO  : Hadoop job information for Stage-3: number of mappers: 1; number of reducers: 1
INFO  : 2024-06-24 21:17:37,432 Stage-3 map = 0%,  reduce = 0%
INFO  : 2024-06-24 21:18:15,349 Stage-3 map = 100%,  reduce = 0%, Cumulative CPU 6.49 sec
INFO  : 2024-06-24 21:18:38,159 Stage-3 map = 100%,  reduce = 100%, Cumulative CPU 14.93 sec
INFO  : MapReduce Total cumulative CPU time: 14 seconds 930 msec
INFO  : Ended Job = job_1719249550016_0040
INFO  : Starting task [Stage-2:STATS] in serial mode
INFO  : MapReduce Jobs Launched:
INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 40.84 sec   HDFS Read: 571107 HDFS Write: 1294 SUCCESS
INFO  : Stage-Stage-3: Map: 1  Reduce: 1   Cumulative CPU: 14.93 sec   HDFS Read: 12587 HDFS Write: 376 SUCCESS
INFO  : Total MapReduce CPU Time Spent: 55 seconds 770 msec
INFO  : Completed executing command(queryId=root_20240624211546_1108b205-3bbd-465d-8c7b-e07f6a21bfde); Time taken: 174.964 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query INSERT OVERWRITE TABLE SMART.TRANSACCION_POR_EMPRESA
SELECT
EMPRESA_TRANSACCION,
COUNT(MONTO_TRANSACCION),
SUM(MONTO_TRANSACCION)
FROM
UNIVERSAL.TRANSACCION_ENRIQUECIDA
GROUP BY
EMPRESA_TRANSACCION
No rows affected (176.268 seconds)
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> -- Impresión de datos
0: jdbc:hive2://localhost:10000>
0: jdbc:hive2://localhost:10000> SELECT * FROM SMART.TRANSACCION_POR_EMPRESA LIMIT 10;
DEBUG : Acquired the compile lock.
INFO  : Compiling command(queryId=root_20240624211842_cb616bed-899c-4217-8ed2-35efbecbedba): SELECT * FROM SMART.TRANSACCION_POR_EMPRESA LIMIT 10
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Semantic Analysis Completed (retrial = false)
INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:transaccion_por_empresa.empresa_transaccion, type:string, comment:null), FieldSchema(name:transaccion_por_empresa.cantidad_transacciones, type:int, comment:null), FieldSchema(name:transaccion_por_empresa.suma_monto_transacciones, type:double, comment:null)], properties:null)
INFO  : Completed compiling command(queryId=root_20240624211842_cb616bed-899c-4217-8ed2-35efbecbedba); Time taken: 0.521 seconds
INFO  : Concurrency mode is disabled, not creating a lock manager
INFO  : Executing command(queryId=root_20240624211842_cb616bed-899c-4217-8ed2-35efbecbedba): SELECT * FROM SMART.TRANSACCION_POR_EMPRESA LIMIT 10
INFO  : Completed executing command(queryId=root_20240624211842_cb616bed-899c-4217-8ed2-35efbecbedba); Time taken: 0.002 seconds
INFO  : OK
INFO  : Concurrency mode is disabled, not creating a lock manager
DEBUG : Shutting down query SELECT * FROM SMART.TRANSACCION_POR_EMPRESA LIMIT 10
+----------------------------------------------+-------------------------------------------------+---------------------------------------------------+
| transaccion_por_empresa.empresa_transaccion  | transaccion_por_empresa.cantidad_transacciones  | transaccion_por_empresa.suma_monto_transacciones  |
+----------------------------------------------+-------------------------------------------------+---------------------------------------------------+
| Amazon                                       | 23443                                           | 5.2402645E7                                       |
| Apple                                        | 23575                                           | 5.342402E7                                        |
| Google                                       | 23406                                           | 5.2402979E7                                       |
| HP                                           | 23382                                           | 5.2488235E7                                       |
| IBM                                          | 23581                                           | 5.2589229E7                                       |
| Microsoft                                    | 23472                                           | 5.2680068E7                                       |
| Samsung                                      | 23522                                           | 5.2882909E7                                       |
| Sony                                         | 23616                                           | 5.296073E7                                        |
| Toyota                                       | 23389                                           | 5.2121975E7                                       |
| Walmart                                      | 23654                                           | 5.3221273E7                                       |
+----------------------------------------------+-------------------------------------------------+---------------------------------------------------+
10 rows selected (0.757 seconds)
0: jdbc:hive2://localhost:10000> Closing: 0: jdbc:hive2://localhost:10000
root@hive-server:/opt/hive/bin#
