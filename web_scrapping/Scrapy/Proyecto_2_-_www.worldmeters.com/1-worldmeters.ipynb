# %% [markdown]
# ### **Extraer el `pais` y su `población` y exportarlos a un archivo `JSON`**

# %% [markdown]
# Vamos a trabajar en el enlace:
#
# https://www.worldometers.info/world-population/population-by-country/

# %% [markdown]
# #### **Crear la spider**

# %% [markdown]
# Vamos a crear la spider:
#
# <center><img src="https://i.postimg.cc/7ZnHR7wM/ws-409.png"></center>
#
# Luego, debemos editar el archivo `worldmeters.py` que se crea, con el código que se muestra abajo.

# %% [markdown]
# #### **Paso a paso**

# %% [markdown]
# Vamos a inspeccionar el sitio:
#
# <center><img src="https://i.postimg.cc/3r0KTz3w/ws-410.png"></center>
#
# Localizamos `todas las filas` de la tabla:
#
# <center><img src="https://i.postimg.cc/hvQx8MF0/ws-415.png"></center>
#
# Localizamos el `nombre del pais` en cada fila:
#
# <center><img src="https://i.postimg.cc/1t2sFrrP/ws-411.png"></center>
#
# Localizamos la `población del pais` en cada fila:
#
# <center><img src="https://i.postimg.cc/D0GFP4xG/ws-412.png"></center>

# %% [markdown]
# #### **Código**

# %%
import scrapy


class WorldmetersSpider(scrapy.Spider):
    name = "worldmeters"
    allowed_domains = ["www.worldometers.info"]
    start_urls = ["https://www.worldometers.info/world-population/population-by-country"]

    def parse(self, response):
        # Extracción de nombres de paises y su población
        filas = response.xpath('//tbody/tr')

        for fila in filas:
            pais = fila.xpath('./td/a/text()').get()
            poblacion = fila.xpath('./td[3]/text()').get()

            # Devuelve los datos extraidos
            yield {
                'pais':pais,
                'poblacion': poblacion,
            }

# %% [markdown]
# #### **Ejecución**

# %% [markdown]
# Nos posicionamos en la ruta correcta y ejecutamos nuestra Spider:

# %%
scrapy crawl worldmeters

# %% [markdown]
# <center><img src="https://i.postimg.cc/mrZLWDrx/ws-413.png"></center>

# %% [markdown]
# De esta manera obtenemos toda la info que pedimos extraer del website:
#
# <center><img src="https://i.postimg.cc/bv6zyhGZ/ws-414.png"></center>

# %% [markdown]
# Podriamos exportar toda esta data en un archivo `JSON` escribiendo el siguiente comando:

# %%
scrapy crawl worldmeters -o worldmeters.json
