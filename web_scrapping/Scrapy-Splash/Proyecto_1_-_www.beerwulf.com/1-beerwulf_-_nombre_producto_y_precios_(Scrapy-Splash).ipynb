# %% [markdown]
# ### **Beerwulf - Extraer nombre de productos y sus precios de primera página (Scrapy/Splash)**

# %% [markdown]
# Este sitio a medida que scroleamos hacia abajo se van cargando nuevos productos (nuevas páginas), por tanto, nosotros solo extraeremos la data de la primera página que corresponde solo a 10 productos.

# %% [markdown]
# Vamos a trabajar con el sitio:
#
# https://www.beerwulf.com/en-gb/c/mixedbeercases

# %% [markdown]
# Creamos la spider:
#
# <center><img src="https://i.postimg.cc/NGnJygPS/ws-254.png"></center>
# <center><img src="https://i.postimg.cc/sDZn7tkX/ws-255.png"></center>

# %% [markdown]
# Inspeccionemos el sitio:
#
# <center><img src="https://i.postimg.cc/0yYcH721/ws-256.png"></center>
#
# Búsqueda de caja que contenga el producto completo (nombre y precio):
#
# <center><img src="https://i.postimg.cc/sXXmX8P3/ws-259.png"></center>
#
# Búsqueda de el nombre del producto:
#
# <center><img src="https://i.postimg.cc/Pqd2GNPp/ws-258.png"></center>
#
# Búsqueda del precio del producto:
#
# <center><img src="https://i.postimg.cc/SKVVmqMZ/ws-257.png"></center>

# %% [markdown]
# Este es el código que utilizaremos en el archivo **`beerwulf.py`**:

# %%
import scrapy
from scrapy_splash import SplashRequest


class BeerSpider(scrapy.Spider):
    name = 'beerwulf'

    def start_requests(self):
        url = 'https://www.beerwulf.com/en-gb/c/mixedbeercases'

        yield SplashRequest(url=url, callback=self.parse)

    def parse(self, response):
        products = response.css('a.product.search-product.product-info-container.draught-product.notranslate.pack-product')
        for item in products:
            yield{
                'name': item.css('div.product-name::text').get(),
                'price': item.css('span.price::text').get(),        
                }

# %% [markdown]
# Nos aseguramos de encender el contenedor en Docker Desktoop y luego ejecutamos por terminal y extraemos la data a un archivo **`JSON`**:
#
# <center><img src="https://i.postimg.cc/ZKBwh1jm/ws-260.png"></center>
# <center><img src="https://i.postimg.cc/4NDB4BF9/ws-261.png"></center>
# <center><img src="https://i.postimg.cc/Z56jWp1D/ws-262.png"></center>
