# %% [markdown]
# ### **Carga via `Terminal`**

# %% [markdown]
# Podemos visualizar que se realizó con éxito la carga:

# %%
C:\Users\Alfonso>

C:\Users\Alfonso>cd C:\github\proyectos\consumo_api\Proyecto_7_-_www.microsoftedge.github.io\scripts

C:\github\proyectos\consumo_api\Proyecto_7_-_www.microsoftedge.github.io\scripts>dir
 El volumen de la unidad C es Windows
 El número de serie del volumen es: E281-0020

 Directorio de C:\github\proyectos\consumo_api\Proyecto_7_-_www.microsoftedge.github.io\scripts

19-05-2024  02:18    <DIR>          .
19-05-2024  02:18    <DIR>          ..
19-05-2024  02:20             1.790 microsoftedge_func.py
               1 archivos          1.790 bytes
               2 dirs  44.490.842.112 bytes libres

C:\github\proyectos\consumo_api\Proyecto_7_-_www.microsoftedge.github.io\scripts>python microsoftedge_func.py
2024-05-19 02:21:15,734 - obtener_random_user - INFO - La respuesta fue exitosa
2024-05-19 02:21:15,738 - devolverDataframe - INFO - Se creó el Dataframe exitosamente
2024-05-19 02:21:15,738 - exportarCSV - INFO - Se exportó el Dataframe exitosamente

C:\github\proyectos\consumo_api\Proyecto_7_-_www.microsoftedge.github.io\scripts>
