# %% [markdown]
# ### **Carga via `Terminal`**

# %% [markdown]
# Podemos visualizar que se realizó con éxito la carga:

# %%
C:\Users\Alfonso>

C:\Users\Alfonso>cd C:\github\proyectos\consumo_api\Proyecto_3_-_www.jsonplaceholder.typicode.com\scripts

C:\github\proyectos\consumo_api\Proyecto_3_-_www.jsonplaceholder.typicode.com\scripts>dir
 El volumen de la unidad C es Windows
 El número de serie del volumen es: E281-0020

 Directorio de C:\github\proyectos\consumo_api\Proyecto_3_-_www.jsonplaceholder.typicode.com\scripts

18-05-2024  23:30    <DIR>          .
18-05-2024  23:30    <DIR>          ..
18-05-2024  23:30             1.749 jsonplaceholder_users_func.py
               1 archivos          1.749 bytes
               2 dirs  44.799.025.152 bytes libres

C:\github\proyectos\consumo_api\Proyecto_3_-_www.jsonplaceholder.typicode.com\scripts>python jsonplaceholder_users_func.py
2024-05-18 23:31:59,245 - obtener_users - INFO - La respuesta fue exitosa
2024-05-18 23:31:59,261 - devolverDataframe - INFO - Se creó el Dataframe exitosamente
2024-05-18 23:31:59,261 - exportarCSV - INFO - Se exportó el Dataframe exitosamente

C:\github\proyectos\consumo_api\Proyecto_3_-_www.jsonplaceholder.typicode.com\scripts>
