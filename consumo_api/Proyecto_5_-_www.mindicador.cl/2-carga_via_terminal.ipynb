# %% [markdown]
# ### **Carga via `Terminal`**

# %% [markdown]
# Podemos visualizar que se realizó con éxito la carga:

# %%
C:\Users\Alfonso>

C:\Users\Alfonso>cd C:\github\proyectos\consumo_api\Proyecto_5_-_www.mindicador.cl\scripts

C:\github\proyectos\consumo_api\Proyecto_5_-_www.mindicador.cl\scripts>dir
 El volumen de la unidad C es Windows
 El número de serie del volumen es: E281-0020

 Directorio de C:\github\proyectos\consumo_api\Proyecto_5_-_www.mindicador.cl\scripts

18-05-2024  23:39    <DIR>          .
18-05-2024  23:39    <DIR>          ..
18-05-2024  23:47             1.837 mindicador_func.py
               1 archivos          1.837 bytes
               2 dirs  44.781.391.872 bytes libres

C:\github\proyectos\consumo_api\Proyecto_5_-_www.mindicador.cl\scripts>python mindicador_func.py
2024-05-18 23:48:30,781 - obtener_indicadores - INFO - La respuesta fue exitosa
2024-05-18 23:48:30,797 - devolverDataframe - INFO - Se creó el Dataframe exitosamente
2024-05-18 23:48:30,806 - exportarCSV - INFO - Se exportó el Dataframe exitosamente
