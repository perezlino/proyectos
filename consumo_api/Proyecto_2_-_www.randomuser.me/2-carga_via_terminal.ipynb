# %% [markdown]
# ### **Carga via `Terminal`**

# %% [markdown]
# Podemos visualizar que se realizó con éxito la carga:

# %%
C:\Users\Alfonso>

C:\Users\Alfonso>cd C:\github\proyectos\consumo_api\Proyecto_2_-_www.randomuser.me\scripts

C:\github\proyectos\consumo_api\Proyecto_2_-_www.randomuser.me\scripts>dir
 El volumen de la unidad C es Windows
 El número de serie del volumen es: E281-0020

 Directorio de C:\github\proyectos\consumo_api\Proyecto_2_-_www.randomuser.me\scripts

18-05-2024  21:54    <DIR>          .
18-05-2024  21:54    <DIR>          ..
18-05-2024  22:02             2.497 randomuser_class.py
18-05-2024  22:26             2.169 randomuser_func.py
               2 archivos          4.666 bytes
               2 dirs  44.768.206.848 bytes libres

C:\github\proyectos\consumo_api\Proyecto_2_-_www.randomuser.me\scripts>python randomuser_func.py
2024-05-18 22:44:24,485 - obtener_random_user - INFO - La respuesta fue exitosa
2024-05-18 22:44:24,490 - devolverDataframe - INFO - Se creó el Dataframe exitosamente
2024-05-18 22:44:24,502 - exportarCSV - INFO - Se exportó el Dataframe exitosamente

C:\github\proyectos\consumo_api\Proyecto_2_-_www.randomuser.me\scripts>
