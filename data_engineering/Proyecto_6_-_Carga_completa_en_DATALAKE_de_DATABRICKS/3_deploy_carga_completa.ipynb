# %% [markdown]
# ## **Ingestar todos los archivos**

# %% [markdown]
# En cada notebook agregamos al final lo siguiente:
#
# **dbutils.notebook.exit("Success")**
#
# De esta manera al ir ejecutando cada **Notebook run** lo almacenamos en una variable y al ejecutar esa variable nos devolverá el valor de **success** si se ejecuta de manera correcta y total dicho notebook

# %%
# Obtener el contexto del notebook para extraer el usuario
user = dbutils.notebook.entry_point.getDbutils().notebook().getContext().userName().get()

# %%
notebook_path = f"/Users/{user}/proyecto_databricks/ingestion/circuits"
v_result = dbutils.notebook.run(notebook_path, 0, {"p_data_source": "Ergast API", "p_file_date": "2021-03-28"})

# %%
v_result #Success

# %%
notebook_path = f"/Users/{user}/proyecto_databricks/ingestion/races"
v_result = dbutils.notebook.run(notebook_path, 0, {"p_data_source": "Ergast API", "p_file_date": "2021-03-28"})

# %%
v_result #Success

# %%
notebook_path = f"/Users/{user}/proyecto_databricks/ingestion/constructors"
v_result = dbutils.notebook.run(notebook_path, 0, {"p_data_source": "Ergast API", "p_file_date": "2021-03-28"})

# %%
v_result #Success

# %%
notebook_path = f"/Users/{user}/proyecto_databricks/ingestion/drivers"
v_result = dbutils.notebook.run(notebook_path, 0, {"p_data_source": "Ergast API", "p_file_date": "2021-03-28"})

# %%
v_result #Success

# %%
notebook_path = f"/Users/{user}/proyecto_databricks/ingestion/results"
v_result = dbutils.notebook.run(notebook_path, 0, {"p_data_source": "Ergast API", "p_file_date": "2021-03-28"})

# %%
v_result #Success

# %%
notebook_path = f"/Users/{user}/proyecto_databricks/ingestion/pit_stops"
v_result = dbutils.notebook.run(notebook_path, 0, {"p_data_source": "Ergast API", "p_file_date": "2021-03-28"})

# %%
v_result #Success

# %%
notebook_path = f"/Users/{user}/proyecto_databricks/ingestion/lap_times"
v_result = dbutils.notebook.run(notebook_path, 0, {"p_data_source": "Ergast API", "p_file_date": "2021-03-28"})

# %%
v_result #Success

# %%
notebook_path = f"/Users/{user}/proyecto_databricks/ingestion/qualifying"
v_result = dbutils.notebook.run(notebook_path, 0, {"p_data_source": "Ergast API", "p_file_date": "2021-03-28"})

# %%
v_result #Success

# %%
notebook_path = f"/Users/{user}/proyecto_databricks/transformacion/race_results"
v_result = dbutils.notebook.run(notebook_path, 0)

# %%
v_result #Success

# %%
notebook_path = f"/Users/{user}/proyecto_databricks/transformacion/driver_standings"
v_result = dbutils.notebook.run(notebook_path, 0)

# %%
v_result #Success

# %%
notebook_path = f"/Users/{user}/proyecto_databricks/transformacion/constructor_standings"
v_result = dbutils.notebook.run(notebook_path, 0)

# %%
v_result #Success
