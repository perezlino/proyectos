# %% [markdown]
# ### **Test**

# %% [markdown]
# Para ejecutarlo desde la consola:

# %%
# Si la consola esta ubicada en esta ruta ---> PS C:\github\regular_expressions_regex>
# Ejecutamos este comando, dado que completa la ruta hacia el archivo
# En caso contrario, debemos ejecutar la ruta completa ---> github/regular_expressions_regex/5-Validar_los_datos_de_la_cuenta_de_usuario/template.py
python 5-Validar_los_datos_de_la_cuenta_de_usuario/template.py
