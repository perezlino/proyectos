# %% [markdown]
# ### **Revisión de carga en Postgres via `DBeaver`**

# %% [markdown]
# Para evitar fallos no se debe tener instalado Postgres Desktop:

# %% [markdown]
# <center><img src="https://i.postimg.cc/jjqHVZrd/p2.png"></center>
#
# <center><img src="https://i.postimg.cc/q7m8pykc/p3.png"></center>
#
# <center><img src="https://i.postimg.cc/NM5RFFM3/p4.png"></center>
