# %% [markdown]
# ### **Información proyecto - Movimiento de datos desde `API` a `Postgres`**

# %% [markdown]
# En este proyecto vamos a mover información desde la **`API`** **randomuser.me** hacia una base de datos de **`Postgres`** utilizando **Docker**, **Airflow** y **Postgres**:
#
# <center><img src="https://i.postimg.cc/gcvRR7rQ/p1.png"></center>
