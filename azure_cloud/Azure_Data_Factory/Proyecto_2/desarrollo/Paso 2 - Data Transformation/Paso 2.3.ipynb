# %% [markdown]
# ### **Paso 2.3 - Comenzar la lógica de transformación de los datos**
#
# 1. Comenzar la lógica de transformación de los datos
#
#     *   Identificar y eliminar filas duplicadas
#     *   Reemplazar valores Null
#     *   Creación de nuevas columnas
#     *   Cambio de tipo de datos
#     *   Renombrar columnas

# %% [markdown]
# #### Identificar y eliminar filas duplicadas

# %%
# %%pyspark
# source_df.groupBy(source_df.columns).count().filter(col('count')>1).show(truncate=False)
# Out:
# +----------------------------------------+-------------------+-----------+-------+----------+--------+------+----------+-----+
# |Title                                   |Genre              |ReleaseDate|Runtime|IMDB Score|Language|Views |AddedDate |count|
# +----------------------------------------+-------------------+-----------+-------+----------+--------+------+----------+-----+
# |Caught by a Wave                        |Romantic teen drama|25-03-2021 |99     |5.7       |Italian |246360|2023-01-21|2    |
# |Point Blank                             |Action             |12-07-2019 |86     |5.7       |English |243230|2023-01-21|2    |
# |When We First Met                       |Romantic comedy    |09-02-2018 |97     |6.4       |English |300803|2023-01-21|2    |
# |Good Sam                                |Drama              |16-05-2019 |89     |5.7       |English |442082|2023-01-21|2    |
# |Squared Love                            |Romantic comedy    |11-02-2021 |102    |5.0       |Polish  |3739  |2023-01-15|2    |
# |One-Way to Tomorrow                     |Romance            |19-06-2020 |90     |5.6       |Turkish |78328 |2023-01-28|2    |
# |Brahman Naman                           |Comedy             |07-07-2016 |95     |5.6       |English |69651 |2023-01-28|2    |
# |The Sleepover                           |Comedy             |21-08-2020 |103    |5.6       |English |855604|2023-01-28|2    |
# |The Most Assassinated Woman in the World|Thriller           |07-09-2018 |102    |5.3       |French  |162122|2023-02-02|2    |
# |null                                    |null               |null       |null   |null      |null    |null  |null      |48   |
# |The Three Deaths of Marisela Escobedo   |Documentary        |14-10-2020 |109    |8.2       |Spanish |238206|2023-01-17|2    |
# +----------------------------------------+-------------------+-----------+-------+----------+--------+------+----------+-----+

# %%
# %%pyspark
# df_nodups = source_df

# %%
# %%pyspark
# df_nodups = df_nodups.drop_duplicates()

# %%
# %%pyspark
# df_nodups.groupBy(source_df.columns).count().filter(col('count')>1).show(truncate=False)
# Out:
# +-----+-----+-----------+-------+----------+--------+-----+---------+-----+
# |Title|Genre|ReleaseDate|Runtime|IMDB Score|Language|Views|AddedDate|count|
# +-----+-----+-----------+-------+----------+--------+-----+---------+-----+
# +-----+-----+-----------+-------+----------+--------+-----+---------+-----+

# %%
# %%pyspark
# df_nodups.select([count(when(col(c).isNull(),c)).alias(c) for c in df_nodups.columns]).show()
# Out:
# +-----+-----+-----------+-------+----------+--------+-----+---------+
# |Title|Genre|ReleaseDate|Runtime|IMDB Score|Language|Views|AddedDate|
# +-----+-----+-----------+-------+----------+--------+-----+---------+
# |    1|    2|          1|      1|         1|      16|    1|        1|
# +-----+-----+-----------+-------+----------+--------+-----+---------+

# %%
# %%pyspark
#
# # Eliminar sólo si toda la fila es nula
# df_nodups = df_nodups.na.drop('all')

# %%
# %%pyspark
# df_nodups.select([count(when(col(c).isNull(),c)).alias(c) for c in df_nodups.columns]).show()
# Out:
# +-----+-----+-----------+-------+----------+--------+-----+---------+
# |Title|Genre|ReleaseDate|Runtime|IMDB Score|Language|Views|AddedDate|
# +-----+-----+-----------+-------+----------+--------+-----+---------+
# |    0|    1|          0|      0|         0|      15|    0|        0|
# +-----+-----+-----------+-------+----------+--------+-----+---------+

# %% [markdown]
# #### Reemplazar valores Null

# %%
# %%pyspark
# df_nonulls = df_nodups.na.fill(value="Unknown")

# %%
# %%pyspark
# df_nonulls.filter(col('Language').isNull()).show()
# Out:
# +-----+-----+-----------+-------+----------+--------+-----+---------+
# |Title|Genre|ReleaseDate|Runtime|IMDB Score|Language|Views|AddedDate|
# +-----+-----+-----------+-------+----------+--------+-----+---------+
# +-----+-----+-----------+-------+----------+--------+-----+---------+

# %%
# %%pyspark
# df_nonulls.filter(col('Genre').isNull()).show()
# Out:
# +-----+-----+-----------+-------+----------+--------+-----+---------+
# |Title|Genre|ReleaseDate|Runtime|IMDB Score|Language|Views|AddedDate|
# +-----+-----+-----------+-------+----------+--------+-----+---------+
# +-----+-----+-----------+-------+----------+--------+-----+---------+

# %%
# %%pyspark
# df_nonulls.select([count(when(col(c).isNull(),c)).alias(c) for c in df_nonulls.columns]).show()
# Out:
# +-----+-----+-----------+-------+----------+--------+-----+---------+
# |Title|Genre|ReleaseDate|Runtime|IMDB Score|Language|Views|AddedDate|
# +-----+-----+-----------+-------+----------+--------+-----+---------+
# |    0|    0|          0|      0|         0|       0|    0|        0|
# +-----+-----+-----------+-------+----------+--------+-----+---------+

# %%
# %%pyspark
# df_nonulls.filter(col('Genre') == "Unknown").show(truncate=False)
# Out:
# +----------------------------+-------+-----------+-------+----------+--------+------+----------+
# |Title                       |Genre  |ReleaseDate|Runtime|IMDB Score|Language|Views |AddedDate |
# +----------------------------+-------+-----------+-------+----------+--------+------+----------+
# |Between Two Ferns: The Movie|Unknown|20-09-2019 |82     |6.1       |English |283445|2023-01-28|
# +----------------------------+-------+-----------+-------+----------+--------+------+----------+

# %%
# %%pyspark
# df_nonulls.filter(col('Language') == "Unknown").show(truncate=False)
# Out:
# +------------------------------------------+-------------------+-----------+-------+----------+--------+-------+----------+
# |Title                                     |Genre              |ReleaseDate|Runtime|IMDB Score|Language|Views  |AddedDate |
# +------------------------------------------+-------------------+-----------+-------+----------+--------+-------+----------+
# |Bomb Scared                               |Black comedy       |12-10-2017 |89     |5.6       |Unknown |255483 |2023-01-21|
# |Space Sweepers                            |Science fiction    |05-02-2021 |136    |6.6       |Unknown |327838 |2023-02-03|
# |His House                                 |Thriller           |30-10-2020 |93     |6.5       |Unknown |352801 |2023-02-03|
# |Mowgli: Legend of the Jungle              |Adventure          |07-12-2018 |104    |6.5       |Unknown |115    |2023-01-21|
# |Hot Girls Wanted                          |Documentary        |29-05-2015 |84     |6.1       |Unknown |268877 |2023-01-14|
# |Fatal Affair                              |Thriller           |16-07-2020 |89     |4.5       |Unknown |222144 |2023-01-28|
# |The Last Days of American Crime           |Heist film/Thriller|05-06-2020 |149    |3.7       |Unknown |249014 |2023-01-13|
# |Olette                                    |Crime drama        |02-10-2020 |106    |5.5       |Unknown |50359  |2023-01-28|
# |Dead Kids                                 |Thriller           |01-12-2019 |94     |5.5       |Unknown |339797 |2023-01-28|
# |The Incredible Jessica James              |Comedy             |28-07-2017 |83     |6.5       |Unknown |173320 |2023-02-08|
# |Red Dot                                   |Thriller           |11-02-2021 |86     |5.5       |Unknown |48969  |2023-02-02|
# |The Binding                               |Drama              |02-10-2020 |93     |4.7       |Unknown |135095 |2023-02-10|
# |Heroin(e)                                 |Documentary        |12-09-2017 |39     |6.8       |Unknown |93972  |2023-02-09|
# |Our Souls at Night                        |Romance            |29-09-2017 |103    |6.9       |Unknown |8914127|2023-02-09|
# |ReMastered: Tricky Dick & the Man in Black|Documentary        |02-11-2018 |58     |7.1       |Unknown |297984 |2023-01-17|
# +------------------------------------------+-------------------+-----------+-------+----------+--------+-------+----------+

# %% [markdown]
# #### Creación de una nueva columna basada en el rating de IMDB

# %%
# %%pyspark
# df = df_nonulls.withColumn("IMDB Category", when(col("IMDB Score").between(0.1,2.9),"Very Low"). \
#                                             when(col("IMDB Score").between(3,4.9),"Low"). \
#                                             when(col("IMDB Score").between(3,4.9),"Medium"). \
#                                             otherwise("High"))

# %%
# %%pyspark
# df.show(15,truncate=False)
# Out:
# +-------------------------------------------------+---------------------+-----------+-------+----------+---------+-------+----------+-------------+
# |Title                                            |Genre                |ReleaseDate|Runtime|IMDB Score|Language |Views  |AddedDate |IMDB Category|
# +-------------------------------------------------+---------------------+-----------+-------+----------+---------+-------+----------+-------------+
# |Holiday Rush                                     |Family film          |28-11-2019 |94     |4.9       |English  |20221  |2023-01-21|Low          |
# |IO                                               |Science fiction/Drama|18-01-2019 |95     |4.7       |English  |122853 |2023-01-21|Low          |
# |Strip Down, Rise Up                              |Documentary          |05-02-2021 |112    |5.2       |English  |1583625|2023-01-21|High         |
# |Handsome: A Netflix Mystery Movie                |Comedy               |05-05-2017 |81     |5.2       |English  |43977  |2023-01-21|High         |
# |Thunder Force                                    |Superhero-Comedy     |09-04-2021 |105    |4.4       |English  |127553 |2023-01-21|Low          |
# |The Open House                                   |Horror thriller      |19-01-2018 |94     |3.2       |English  |60545  |2023-01-21|Low          |
# |Searching for Sheela                             |Documentary          |22-04-2021 |58     |4.1       |English  |232072 |2023-01-21|Low          |
# |Mrs. Serial Killer                               |Thriller             |01-05-2020 |106    |4.8       |Hindi    |395025 |2023-01-21|Low          |
# |I Am the Pretty Thing That Lives in the House    |Horror               |28-10-2016 |89     |4.6       |English  |126030 |2023-01-21|Low          |
# |Cadaver                                          |Horror               |22-10-2020 |86     |5.1       |Norwegian|137608 |2023-01-21|High         |
# |Gunjan Saxena: The Kargil Girl                   |Drama                |12-08-2020 |112    |5.3       |Hindi    |935408 |2023-01-21|High         |
# |American Factory: A Conversation with the Obamas |Aftershow / Interview|21-08-2019 |10     |5.2       |English  |39784  |2023-01-21|High         |
# |A Babysitter's Guide to Monster Hunting          |Comedy/Fantasy/Family|15-10-2020 |98     |5.4       |English  |516895 |2023-01-21|High         |
# |In the Tall Grass                                |Horror               |04-10-2019 |101    |5.4       |English  |570814 |2023-01-21|High         |
# |The Last Thing He Wanted                         |Political thriller   |21-02-2020 |115    |4.3       |English  |150823 |2023-01-21|Low          |
# +-------------------------------------------------+---------------------+-----------+-------+----------+---------+-------+----------+-------------+
# only showing top 15 rows

# %% [markdown]
# #### Nueva columna Runtime en horas

# %%
# %%pyspark
# df = df.withColumn("RuntimeinHours", round(df.Runtime/60,2))

# %%
# %%pyspark
# df.show()
# Out:
# +--------------------+--------------------+-----------+-------+----------+---------+-------+----------+-------------+--------------+
# |               Title|               Genre|ReleaseDate|Runtime|IMDB Score| Language|  Views| AddedDate|IMDB Category|RuntimeinHours|
# +--------------------+--------------------+-----------+-------+----------+---------+-------+----------+-------------+--------------+
# |        Holiday Rush|         Family film| 28-11-2019|     94|       4.9|  English|  20221|2023-01-21|          Low|          1.57|
# |                  IO|Science fiction/D...| 18-01-2019|     95|       4.7|  English| 122853|2023-01-21|          Low|          1.58|
# |                Mute|Science fiction/M...| 23-02-2018|    126|       5.5|  English|  30761|2023-01-21|         High|           2.1|
# | Strip Down, Rise Up|         Documentary| 05-02-2021|    112|       5.2|  English|1583625|2023-01-21|         High|          1.87|
# |         Bomb Scared|        Black comedy| 12-10-2017|     89|       5.6|  Unknown| 255483|2023-01-21|         High|          1.48|
# |The Legacy of a W...|    Adventure/Comedy| 06-07-2018|     83|       5.5|  English|  53183|2023-01-21|         High|          1.38|
# |Handsome: A Netfl...|              Comedy| 05-05-2017|     81|       5.2|  English|  43977|2023-01-21|         High|          1.35|
# |       Thunder Force|    Superhero-Comedy| 09-04-2021|    105|       4.4|  English| 127553|2023-01-21|          Low|          1.75|
# |      The Open House|     Horror thriller| 19-01-2018|     94|       3.2|  English|  60545|2023-01-21|          Low|          1.57|
# |Searching for Sheela|         Documentary| 22-04-2021|     58|       4.1|  English| 232072|2023-01-21|          Low|          0.97|
# |       The Paramedic|            Thriller| 16-09-2020|     94|       5.6|  Spanish| 386102|2023-01-21|         High|          1.57|
# |  Mrs. Serial Killer|            Thriller| 01-05-2020|    106|       4.8|    Hindi| 395025|2023-01-21|          Low|          1.77|
# |I Am the Pretty T...|              Horror| 28-10-2016|     89|       4.6|  English| 126030|2023-01-21|          Low|          1.48|
# |             Cadaver|              Horror| 22-10-2020|     86|       5.1|Norwegian| 137608|2023-01-21|         High|          1.43|
# |Gunjan Saxena: Th...|               Drama| 12-08-2020|    112|       5.3|    Hindi| 935408|2023-01-21|         High|          1.87|
# |American Factory:...|Aftershow / Inter...| 21-08-2019|     10|       5.2|  English|  39784|2023-01-21|         High|          0.17|
# |    Love, Guaranteed|     Romantic comedy| 03-09-2020|     91|       5.6|  English| 109756|2023-01-21|         High|          1.52|
# |A Babysitter's Gu...|Comedy/Fantasy/Fa...| 15-10-2020|     98|       5.4|  English| 516895|2023-01-21|         High|          1.63|
# |   In the Tall Grass|              Horror| 04-10-2019|    101|       5.4|  English| 570814|2023-01-21|         High|          1.68|
# |The Last Thing He...|  Political thriller| 21-02-2020|    115|       4.3|  English| 150823|2023-01-21|          Low|          1.92|
# +--------------------+--------------------+-----------+-------+----------+---------+-------+----------+-------------+--------------+
# only showing top 20 rows

# %%
# %%pyspark
# df = df.drop('Runtime')

# %%
# %%pyspark
# df.show(15,truncate=False)
# Out:
# +-------------------------------------------------+---------------------+-----------+----------+---------+-------+----------+-------------+--------------+
# |Title                                            |Genre                |ReleaseDate|IMDB Score|Language |Views  |AddedDate |IMDB Category|RuntimeinHours|
# +-------------------------------------------------+---------------------+-----------+----------+---------+-------+----------+-------------+--------------+
# |Holiday Rush                                     |Family film          |28-11-2019 |4.9       |English  |20221  |2023-01-21|Low          |1.57          |
# |IO                                               |Science fiction/Drama|18-01-2019 |4.7       |English  |122853 |2023-01-21|Low          |1.58          |
# |Strip Down, Rise Up                              |Documentary          |05-02-2021 |5.2       |English  |1583625|2023-01-21|High         |1.87          |
# |Handsome: A Netflix Mystery Movie                |Comedy               |05-05-2017 |5.2       |English  |43977  |2023-01-21|High         |1.35          |
# |Thunder Force                                    |Superhero-Comedy     |09-04-2021 |4.4       |English  |127553 |2023-01-21|Low          |1.75          |
# |The Open House                                   |Horror thriller      |19-01-2018 |3.2       |English  |60545  |2023-01-21|Low          |1.57          |
# |Searching for Sheela                             |Documentary          |22-04-2021 |4.1       |English  |232072 |2023-01-21|Low          |0.97          |
# |Mrs. Serial Killer                               |Thriller             |01-05-2020 |4.8       |Hindi    |395025 |2023-01-21|Low          |1.77          |
# |I Am the Pretty Thing That Lives in the House    |Horror               |28-10-2016 |4.6       |English  |126030 |2023-01-21|Low          |1.48          |
# |Cadaver                                          |Horror               |22-10-2020 |5.1       |Norwegian|137608 |2023-01-21|High         |1.43          |
# |Gunjan Saxena: The Kargil Girl                   |Drama                |12-08-2020 |5.3       |Hindi    |935408 |2023-01-21|High         |1.87          |
# |American Factory: A Conversation with the Obamas |Aftershow / Interview|21-08-2019 |5.2       |English  |39784  |2023-01-21|High         |0.17          |
# |A Babysitter's Guide to Monster Hunting          |Comedy/Fantasy/Family|15-10-2020 |5.4       |English  |516895 |2023-01-21|High         |1.63          |
# |In the Tall Grass                                |Horror               |04-10-2019 |5.4       |English  |570814 |2023-01-21|High         |1.68          |
# |The Last Thing He Wanted                         |Political thriller   |21-02-2020 |4.3       |English  |150823 |2023-01-21|Low          |1.92          |
# +-------------------------------------------------+---------------------+-----------+----------+---------+-------+----------+-------------+--------------+
# only showing top 15 rows

# %% [markdown]
# #### Categoría 'Runtime'

# %%
# %%pyspark
# df = df.withColumn("Runtime_Category", when(col("RuntimeInHours").between(0,1.30),"Short Runtime").\
#                                        when(col("RuntimeInHours").between(1.31,2.15) , "Medium Runtime").\
#                                        otherwise("LongRuntime"))

# %%
# %%pyspark
# df.show()
# Out:
# +--------------------+--------------------+-----------+----------+--------+-------+----------+-------------+--------------+----------------+
# |               Title|               Genre|ReleaseDate|IMDB Score|Language|  Views| AddedDate|IMDB Category|RuntimeinHours|Runtime_Category|
# +--------------------+--------------------+-----------+----------+--------+-------+----------+-------------+--------------+----------------+
# |               Barry|              Biopic| 16-12-2016|       5.8| English| 156567|2023-01-15|         High|          1.73|  Medium Runtime|
# |        Holiday Rush|         Family film| 28-11-2019|       4.9| English|  20221|2023-01-21|          Low|          1.57|  Medium Runtime|
# |Michael Bolton's ...|        Variety Show| 07-02-2017|       6.7| English|  84016|2023-02-03|         High|           0.9|   Short Runtime|
# |        Road to Roma|           Making-of| 11-02-2020|       7.7| Spanish|  90372|2023-02-03|         High|           1.2|   Short Runtime|
# |    The Midnight Sky|     Science fiction| 23-12-2020|       5.6| English| 660286|2023-01-15|         High|          1.97|  Medium Runtime|
# |Eurovision Song C...|      Musical comedy| 26-06-2020|       6.5| English|  34248|2023-01-21|         High|          2.05|  Medium Runtime|
# |         Stuck Apart|               Drama| 08-01-2021|       6.1| Turkish| 377336|2023-01-21|         High|           1.6|  Medium Runtime|
# |                  IO|Science fiction/D...| 18-01-2019|       4.7| English| 122853|2023-01-21|          Low|          1.58|  Medium Runtime|
# |    Caught by a Wave| Romantic teen drama| 25-03-2021|       5.7| Italian| 246360|2023-01-21|         High|          1.65|  Medium Runtime|
# |        Giving Voice|         Documentary| 11-12-2020|       6.7| English| 312495|2023-01-21|         High|           1.5|  Medium Runtime|
# |     Imperial Dreams|               Drama| 03-02-2017|       6.7| English| 135706|2023-02-03|         High|          1.45|  Medium Runtime|
# |   Happy Anniversary|     Romantic comedy| 30-03-2018|       5.8| English|  72778|2023-01-21|         High|           1.3|   Short Runtime|
# |ReMastered: The M...|         Documentary| 22-03-2019|       7.0| English| 453179|2023-01-15|         High|          1.17|   Short Runtime|
# |Blackpink: Light ...|         Documentary| 14-10-2020|       7.5|  Korean| 352698|2023-01-15|         High|          1.32|  Medium Runtime|
# |              Oxygen|Science fiction t...| 12-05-2021|       6.5|  French| 217464|2023-02-03|         High|          1.68|  Medium Runtime|
# |        Shimmer Lake|      Crime thriller| 09-06-2017|       6.3| English| 492324|2023-02-03|         High|          1.43|  Medium Runtime|
# |            Good Sam|               Drama| 16-05-2019|       5.7| English| 442082|2023-01-21|         High|          1.48|  Medium Runtime|
# |      A Whisker Away|       Anime/Fantasy| 18-06-2020|       6.7|Japanese|  89059|2023-01-21|         High|          1.73|  Medium Runtime|
# |          Coin Heist|               Heist| 06-01-2017|       4.8| English|2791414|2023-01-15|          Low|          1.62|  Medium Runtime|
# |          Isi & Ossi|     Romantic comedy| 14-02-2020|       6.4|  German| 249425|2023-02-03|         High|          1.88|  Medium Runtime|
# +--------------------+--------------------+-----------+----------+--------+-------+----------+-------------+--------------+----------------+
# only showing top 20 rows

# %% [markdown]
# #### Cambio de tipo de datos de String a Date en la columna 'ReleaseDate'

# %%
# %%pyspark
# df.printSchema()
# Out:
# root
#  |-- Title: string (nullable = false)
#  |-- Genre: string (nullable = false)
#  |-- ReleaseDate: string (nullable = false)
#  |-- IMDB Score: double (nullable = true)
#  |-- Language: string (nullable = false)
#  |-- Views: integer (nullable = true)
#  |-- AddedDate: date (nullable = true)
#  |-- IMDB Category: string (nullable = false)
#  |-- RuntimeinHours: double (nullable = true)
#  |-- Runtime_Category: string (nullable = false)

# %%
# %%pyspark
# df = df.withColumn("ReleaseDate", to_date("ReleaseDate",'dd-MM-yyyy'))

# %%
# %%pyspark
# df.printSchema()
# Out:
# root
#  |-- Title: string (nullable = false)
#  |-- Genre: string (nullable = false)
#  |-- ReleaseDate: date (nullable = true)
#  |-- IMDB Score: double (nullable = true)
#  |-- Language: string (nullable = false)
#  |-- Views: integer (nullable = true)
#  |-- AddedDate: date (nullable = true)
#  |-- IMDB Category: string (nullable = false)
#  |-- RuntimeinHours: double (nullable = true)
#  |-- Runtime_Category: string (nullable = false)

# %%
# %%pyspark
# df.sort('ReleaseDate').show()
# Out:
# +--------------------+--------------------+-----------+----------+--------------------+------+----------+-------------+--------------+----------------+
# |               Title|               Genre|ReleaseDate|IMDB Score|            Language| Views| AddedDate|IMDB Category|RuntimeinHours|Runtime_Category|
# +--------------------+--------------------+-----------+----------+--------------------+------+----------+-------------+--------------+----------------+
# |Feminists: What W...|         Documentary|       null|       7.0|             English|494819|2023-02-23|         High|          1.43|  Medium Runtime|
# |The Meyerowitz St...|        Comedy-drama|       null|       6.9|             English| 48297|2023-02-23|         High|          1.87|  Medium Runtime|
# | Gaga: Five Foot Two|         Documentary|       null|       7.0|             English|382459|2023-02-23|         High|          1.67|  Medium Runtime|
# |The Lonely Island...|    Comedy / Musical|       null|       6.9|             English|238789|2023-02-23|         High|           0.5|   Short Runtime|
# |      The Highwaymen|         Crime drama|       null|       6.9|             English| 54216|2023-02-23|         High|          2.18|     LongRuntime|
# |       Kingdom of Us|         Documentary|       null|       7.0|             English| 81301|2023-02-23|         High|          1.82|  Medium Runtime|
# |I'm No Longer Her...|Aftershow / Inter...|       null|       7.0|             English|711223|2023-02-23|         High|          0.23|   Short Runtime|
# |          My Own Man|         Documentary| 2014-12-13|       6.4|             English|105619|2023-02-08|         High|          1.35|  Medium Runtime|
# |    Hot Girls Wanted|         Documentary| 2015-05-29|       6.1|             Unknown|268877|2023-01-14|         High|           1.4|  Medium Runtime|
# |Winter on Fire: U...|         Documentary| 2015-10-09|       8.4|English/Ukranian/...|680947|2023-02-01|         High|          1.52|  Medium Runtime|
# |A Very Murray Chr...|    Comedy / Musical| 2015-12-04|       5.5|             English|117590|2023-01-15|         High|          0.93|   Short Runtime|
# |    The Ridiculous 6|             Western| 2015-12-11|       4.8|             English|987414|2023-01-13|          Low|          1.98|  Medium Runtime|
# |Pee-wee's Big Hol...|           Adventure| 2016-03-18|       6.1|             English|247926|2023-01-13|         High|          1.48|  Medium Runtime|
# |Special Correspon...|              Satire| 2016-04-29|       5.8|             English|117018|2023-01-14|         High|          1.67|  Medium Runtime|
# |         The Do-Over|       Action comedy| 2016-05-27|       5.7|             English| 97618|2023-01-14|         High|           1.8|  Medium Runtime|
# |       Brahman Naman|              Comedy| 2016-07-07|       5.6|             English| 69651|2023-01-28|         High|          1.58|  Medium Runtime|
# |             Rebirth|            Thriller| 2016-07-15|       5.0|             English|113322|2023-01-14|         High|          1.67|  Medium Runtime|
# |Tony Robbins: I A...|         Documentary| 2016-07-15|       6.7|             English|221117|2023-02-08|         High|          1.93|  Medium Runtime|
# |            Tallulah|        Comedy-drama| 2016-07-29|       6.7|             English|154647|2023-02-03|         High|          1.85|  Medium Runtime|
# |I'll Sleep When I...|         Documentary| 2016-08-19|       6.6|             English| 97679|2023-02-06|         High|          1.32|  Medium Runtime|
# +--------------------+--------------------+-----------+----------+--------------------+------+----------+-------------+--------------+----------------+
# only showing top 20 rows

# %%
# %%pyspark
# df.select([count(when(col(c).isNull(),c)).alias(c) for c in df.columns]).show()
# Out:
# +-----+-----+-----------+----------+--------+-----+---------+-------------+--------------+----------------+
# |Title|Genre|ReleaseDate|IMDB Score|Language|Views|AddedDate|IMDB Category|RuntimeinHours|Runtime_Category|
# +-----+-----+-----------+----------+--------+-----+---------+-------------+--------------+----------------+
# |    0|    0|          7|         0|       0|    0|        0|            0|             0|               0|
# +-----+-----+-----------+----------+--------+-----+---------+-------------+--------------+----------------+

# %% [markdown]
# #### Renombrar las columnas de "IMDB Score" y "IMDB Category"

# %%
# %%pyspark
# df = df.withColumnRenamed("IMDB Score","IMDB_Score")

# %%
# %%pyspark
# df = df.withColumnRenamed("IMDB Category","IMDB_Category")

# %%
# %%pyspark
# df.show()
# Out:
# +--------------------+--------------------+-----------+----------+--------+-------+----------+-------------+--------------+----------------+
# |               Title|               Genre|ReleaseDate|IMDB_Score|Language|  Views| AddedDate|IMDB_Category|RuntimeinHours|Runtime_Category|
# +--------------------+--------------------+-----------+----------+--------+-------+----------+-------------+--------------+----------------+
# |               Barry|              Biopic| 2016-12-16|       5.8| English| 156567|2023-01-15|         High|          1.73|  Medium Runtime|
# |        Holiday Rush|         Family film| 2019-11-28|       4.9| English|  20221|2023-01-21|          Low|          1.57|  Medium Runtime|
# |Michael Bolton's ...|        Variety Show| 2017-02-07|       6.7| English|  84016|2023-02-03|         High|           0.9|   Short Runtime|
# |        Road to Roma|           Making-of| 2020-02-11|       7.7| Spanish|  90372|2023-02-03|         High|           1.2|   Short Runtime|
# |    The Midnight Sky|     Science fiction| 2020-12-23|       5.6| English| 660286|2023-01-15|         High|          1.97|  Medium Runtime|
# |Eurovision Song C...|      Musical comedy| 2020-06-26|       6.5| English|  34248|2023-01-21|         High|          2.05|  Medium Runtime|
# |         Stuck Apart|               Drama| 2021-01-08|       6.1| Turkish| 377336|2023-01-21|         High|           1.6|  Medium Runtime|
# |                  IO|Science fiction/D...| 2019-01-18|       4.7| English| 122853|2023-01-21|          Low|          1.58|  Medium Runtime|
# |    Caught by a Wave| Romantic teen drama| 2021-03-25|       5.7| Italian| 246360|2023-01-21|         High|          1.65|  Medium Runtime|
# |        Giving Voice|         Documentary| 2020-12-11|       6.7| English| 312495|2023-01-21|         High|           1.5|  Medium Runtime|
# |     Imperial Dreams|               Drama| 2017-02-03|       6.7| English| 135706|2023-02-03|         High|          1.45|  Medium Runtime|
# |   Happy Anniversary|     Romantic comedy| 2018-03-30|       5.8| English|  72778|2023-01-21|         High|           1.3|   Short Runtime|
# |ReMastered: The M...|         Documentary| 2019-03-22|       7.0| English| 453179|2023-01-15|         High|          1.17|   Short Runtime|
# |Blackpink: Light ...|         Documentary| 2020-10-14|       7.5|  Korean| 352698|2023-01-15|         High|          1.32|  Medium Runtime|
# |              Oxygen|Science fiction t...| 2021-05-12|       6.5|  French| 217464|2023-02-03|         High|          1.68|  Medium Runtime|
# |        Shimmer Lake|      Crime thriller| 2017-06-09|       6.3| English| 492324|2023-02-03|         High|          1.43|  Medium Runtime|
# |            Good Sam|               Drama| 2019-05-16|       5.7| English| 442082|2023-01-21|         High|          1.48|  Medium Runtime|
# |      A Whisker Away|       Anime/Fantasy| 2020-06-18|       6.7|Japanese|  89059|2023-01-21|         High|          1.73|  Medium Runtime|
# |          Coin Heist|               Heist| 2017-01-06|       4.8| English|2791414|2023-01-15|          Low|          1.62|  Medium Runtime|
# |          Isi & Ossi|     Romantic comedy| 2020-02-14|       6.4|  German| 249425|2023-02-03|         High|          1.88|  Medium Runtime|
# +--------------------+--------------------+-----------+----------+--------+-------+----------+-------------+--------------+----------------+
# only showing top 20 rows
