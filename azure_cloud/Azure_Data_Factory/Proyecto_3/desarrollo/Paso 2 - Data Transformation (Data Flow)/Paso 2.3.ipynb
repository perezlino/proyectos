# %% [markdown]
# #### Modificar los dataset **ds_ecdc_file_list**, **ds_raw_cases_and_deaths**, **ds_raw_hospital_admission**, **ds_country_lookup** y **ds_dim_date_lookup**
#
# Este dataset lo utilizamos en el **Paso 1.10**. En el archivo **ecdc_list_file.json** en **SinkFileName** agregamos un directorio, por lo cual, cada archivo se copiará en su propio directorio al re-ejecutar el pipeline **pl_ingest_ecdc_data**
#
# ```
# [
#     {
#         "sourceBaseURL":"https://github.com",
#         "sourceRelativeURL":"cloudboxacademy/covid19/raw/main/ecdc_data/cases_deaths.csv",
#         "sinkFileName":"cases_deaths/cases_deaths.csv"
#     },
#     {
#         "sourceBaseURL":"https://github.com",
#         "sourceRelativeURL":"cloudboxacademy/covid19/raw/main/ecdc_data/hospital_admissions.csv",
#         "sinkFileName":"hospital_admissions/hospital_admissions.csv"
#     },
#     {
#         "sourceBaseURL":"https://github.com",
#         "sourceRelativeURL":"cloudboxacademy/covid19/raw/main/ecdc_data/testing.csv",
#         "sinkFileName":"testing/testing.csv"
#     },
#     {
#         "sourceBaseURL":"https://github.com",
#         "sourceRelativeURL":"cloudboxacademy/covid19/raw/main/ecdc_data/country_response.csv",
#         "sinkFileName":"country_response/country_response.csv"
#     }
# ]
# ```
#
# <center><img src="https://i.postimg.cc/gk5HtXpd/adf939.png"></center>
#
# Se crearon los directorios y dentro de ellos cada archivo
#
# <center><img src="https://i.postimg.cc/9fPPfL7F/adf940.png"></center>
#
# Borramos los archivos anteriores
#
# <center><img src="https://i.postimg.cc/Hky4qYWM/adf941.png"></center>
#
# Editamos la ruta del dataset **ds_raw_cases_and_deaths** --> **raw/ecdc/cases_deaths/cases_deaths.csv**
#
# <center><img src="https://i.postimg.cc/d33G4vSL/adf942.png"></center>
#
# Editamos la ruta del dataset **ds_raw_hospital_admission** --> **raw/ecdc/hospital_admissions/hospital_admissions.csv**
#
# <center><img src="https://i.postimg.cc/KzJnP4f6/adf943.png"></center>
#
# Creamos manualmente dos directorios dentro del contenedor **lookup** donde almacenaremos cada archivo
#
# <center><img src="https://i.postimg.cc/KzZP3tP7/adf944.png"></center>
# <center><img src="https://i.postimg.cc/SKb7qBjv/adf945.png"></center>
#
# Editamos la ruta para los datasets **ds_country_lookup** y **ds_dim_date_lookup**
#
# <center><img src="https://i.postimg.cc/yxGcG5wn/adf946.png"></center>
# <center><img src="https://i.postimg.cc/dQN2DkLd/adf947.png"></center>
