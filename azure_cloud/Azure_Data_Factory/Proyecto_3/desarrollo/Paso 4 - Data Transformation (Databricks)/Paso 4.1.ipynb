# %% [markdown]
# ## Mount the following data lake storage gen2 containers
# 1. raw
# 2. processed
# 3. lookup

# %% [markdown]
# ### Set-up the configs
# #### Please update the following
# - application-id : b972d151-0d43-492d-8483-3a67d2bcd852
# - directory-id (tenant-id) : 65947afd-b0be-440f-b3d5-2ca66af0ef41
# - service-credential (secret) : _YRYijA.rF62jz9Z7_BNHMk.Uv.zbww.xG

# %%
configs = {"fs.azure.account.auth.type": "OAuth",
           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
           "fs.azure.account.oauth2.client.id": "<application-id>",
           "fs.azure.account.oauth2.client.secret": "<service-credential>",
           "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/<directory-id>/oauth2/token"}

# %%
configs = {"fs.azure.account.auth.type": "OAuth",
           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
           "fs.azure.account.oauth2.client.id": "b972d151-0d43-492d-8483-3a67d2bcd852",
           "fs.azure.account.oauth2.client.secret": "_YRYijA.rF62jz9Z7_BNHMk.Uv.zbww.xG",
           "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/65947afd-b0be-440f-b3d5-2ca66af0ef41/oauth2/token"}

# %% [markdown]
# ### Mount the raw container
# #### Update the storage account name before executing
#
# Azure Data Lake Storage: **covidreportingdl**

# %%
dbutils.fs.mount(
  source = "abfss://raw@<storage account name>.dfs.core.windows.net/",
  mount_point = "/mnt/<storage account name>/raw",
  extra_configs = configs)

# %%
dbutils.fs.mount(
  source = "abfss://raw@covidreportingdl.dfs.core.windows.net/",
  mount_point = "/mnt/covidreportingdl/raw",
  extra_configs = configs)

# %% [markdown]
# ### Mount the processed container
# #### Update the storage account name before executing

# %%
dbutils.fs.mount(
  source = "abfss://processed@<storage account name>.dfs.core.windows.net/",
  mount_point = "/mnt/<storage account name>/processed",
  extra_configs = configs)

# %%
dbutils.fs.mount(
  source = "abfss://processed@covidreportingdl.dfs.core.windows.net/",
  mount_point = "/mnt/covidreportingdl/processed",
  extra_configs = configs)

# %% [markdown]
# ### Mount the lookup container
# #### Update the storage account name before executing

# %%
dbutils.fs.mount(
  source = "abfss://lookup@<storage account name>.dfs.core.windows.net/",
  mount_point = "/mnt/<storage account name>/lookup",
  extra_configs = configs)

# %%
dbutils.fs.mount(
  source = "abfss://lookup@covidreportingdl.dfs.core.windows.net/",
  mount_point = "/mnt/covidreportingdl/lookup",
  extra_configs = configs)
