# %% [markdown]
# ### **Paso 2.4 - Ingesta del archivo "drivers.json"**

# %%
# %run "../includes/configuration"

# %%
# %run "../includes/common_functions"

# %% [markdown]
# #### Paso 1 - Leer el archivo JSON

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType

# %%
name_schema = StructType(fields=[StructField("forename", StringType(), True),
                                 StructField("surname", StringType(), True)
  
])

# %%
drivers_schema = StructType(fields=[StructField("driverId", IntegerType(), False),
                                    StructField("driverRef", StringType(), True),
                                    StructField("number", IntegerType(), True),
                                    StructField("code", StringType(), True),
                                    StructField("name", name_schema),
                                    StructField("dob", DateType(), True),
                                    StructField("nationality", StringType(), True),
                                    StructField("url", StringType(), True)  
])

# %%
# El parámetro "raw_folder_path" se encuentra en el notebook "configuration"
drivers_df = spark.read \
.schema(drivers_schema) \
.json(f"{raw_folder_path}/drivers.json")

# %%
drivers_df.show(truncate=False)
# Out:
# +--------+----------+------+----+---------------------+----------+-----------+-----------------------------------------------------+
# |driverId|driverRef |number|code|name                 |dob       |nationality|url                                                  |
# +--------+----------+------+----+---------------------+----------+-----------+-----------------------------------------------------+
# |1       |hamilton  |44    |HAM |{Lewis, Hamilton}    |1985-01-07|British    |http://en.wikipedia.org/wiki/Lewis_Hamilton          |
# |2       |heidfeld  |null  |HEI |{Nick, Heidfeld}     |1977-05-10|German     |http://en.wikipedia.org/wiki/Nick_Heidfeld           |
# |3       |rosberg   |6     |ROS |{Nico, Rosberg}      |1985-06-27|German     |http://en.wikipedia.org/wiki/Nico_Rosberg            |
# |4       |alonso    |14    |ALO |{Fernando, Alonso}   |1981-07-29|Spanish    |http://en.wikipedia.org/wiki/Fernando_Alonso         |
# |5       |kovalainen|null  |KOV |{Heikki, Kovalainen} |1981-10-19|Finnish    |http://en.wikipedia.org/wiki/Heikki_Kovalainen       |
# |6       |nakajima  |null  |NAK |{Kazuki, Nakajima}   |1985-01-11|Japanese   |http://en.wikipedia.org/wiki/Kazuki_Nakajima         |
# |7       |bourdais  |null  |BOU |{Sébastien, Bourdais}|1979-02-28|French     |http://en.wikipedia.org/wiki/S%C3%A9bastien_Bourdais |
# |8       |raikkonen |7     |RAI |{Kimi, Räikkönen}    |1979-10-17|Finnish    |http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen|
# |9       |kubica    |88    |KUB |{Robert, Kubica}     |1984-12-07|Polish     |http://en.wikipedia.org/wiki/Robert_Kubica           |
# |10      |glock     |null  |GLO |{Timo, Glock}        |1982-03-18|German     |http://en.wikipedia.org/wiki/Timo_Glock              |
# |11      |sato      |null  |SAT |{Takuma, Sato}       |1977-01-28|Japanese   |http://en.wikipedia.org/wiki/Takuma_Sato             |
# |12      |piquet_jr |null  |PIQ |{Nelson, Piquet Jr.} |1985-07-25|Brazilian  |http://en.wikipedia.org/wiki/Nelson_Piquet,_Jr.      |
# |13      |massa     |19    |MAS |{Felipe, Massa}      |1981-04-25|Brazilian  |http://en.wikipedia.org/wiki/Felipe_Massa            |
# |14      |coulthard |null  |COU |{David, Coulthard}   |1971-03-27|British    |http://en.wikipedia.org/wiki/David_Coulthard         |
# |15      |trulli    |null  |TRU |{Jarno, Trulli}      |1974-07-13|Italian    |http://en.wikipedia.org/wiki/Jarno_Trulli            |
# |16      |sutil     |99    |SUT |{Adrian, Sutil}      |1983-01-11|German     |http://en.wikipedia.org/wiki/Adrian_Sutil            |
# |17      |webber    |null  |WEB |{Mark, Webber}       |1976-08-27|Australian |http://en.wikipedia.org/wiki/Mark_Webber             |
# |18      |button    |22    |BUT |{Jenson, Button}     |1980-01-19|British    |http://en.wikipedia.org/wiki/Jenson_Button           |
# |19      |davidson  |null  |DAV |{Anthony, Davidson}  |1979-04-18|British    |http://en.wikipedia.org/wiki/Anthony_Davidson        |
# |20      |vettel    |5     |VET |{Sebastian, Vettel}  |1987-07-03|German     |http://en.wikipedia.org/wiki/Sebastian_Vettel        |
# +--------+----------+------+----+---------------------+----------+-----------+-----------------------------------------------------+
# only showing top 20 rows

# %%
drivers_df.printSchema()
# Out:
# root
#  |-- driverId: integer (nullable = true)
#  |-- driverRef: string (nullable = true)
#  |-- number: integer (nullable = true)
#  |-- code: string (nullable = true)
#  |-- name: struct (nullable = true)
#  |    |-- forename: string (nullable = true)
#  |    |-- surname: string (nullable = true)
#  |-- dob: date (nullable = true)
#  |-- nationality: string (nullable = true)
#  |-- url: string (nullable = true)

# %% [markdown]
# #### Paso 2 - Renombrar columnas y añadir nuevas columnas
# 1. **driverId** renombrado a **driver_id**
# 2. **driverRef** renombrado a **driver_ref**
# 3. Se añade la columna **ingestion_date**
# 4. Se añade la columna **name** con la concatenación de **forename** y **surname**.

# %%
from pyspark.sql.functions import col, concat, lit

# %%
drivers_with_columns_df = drivers_df.withColumnRenamed("driverId", "driver_id") \
                                    .withColumnRenamed("driverRef", "driver_ref") \
                                    .withColumn("name", concat(col("name.forename"), lit(" "), col("name.surname")))

# %%
drivers_with_columns_df.show(truncate=False)
# Out:
# +---------+----------+------+----+------------------+----------+-----------+-----------------------------------------------------+
# |driver_id|driver_ref|number|code|name              |dob       |nationality|url                                                  |
# +---------+----------+------+----+------------------+----------+-----------+-----------------------------------------------------+
# |1        |hamilton  |44    |HAM |Lewis Hamilton    |1985-01-07|British    |http://en.wikipedia.org/wiki/Lewis_Hamilton          |
# |2        |heidfeld  |null  |HEI |Nick Heidfeld     |1977-05-10|German     |http://en.wikipedia.org/wiki/Nick_Heidfeld           |
# |3        |rosberg   |6     |ROS |Nico Rosberg      |1985-06-27|German     |http://en.wikipedia.org/wiki/Nico_Rosberg            |
# |4        |alonso    |14    |ALO |Fernando Alonso   |1981-07-29|Spanish    |http://en.wikipedia.org/wiki/Fernando_Alonso         |
# |5        |kovalainen|null  |KOV |Heikki Kovalainen |1981-10-19|Finnish    |http://en.wikipedia.org/wiki/Heikki_Kovalainen       |
# |6        |nakajima  |null  |NAK |Kazuki Nakajima   |1985-01-11|Japanese   |http://en.wikipedia.org/wiki/Kazuki_Nakajima         |
# |7        |bourdais  |null  |BOU |Sébastien Bourdais|1979-02-28|French     |http://en.wikipedia.org/wiki/S%C3%A9bastien_Bourdais |
# |8        |raikkonen |7     |RAI |Kimi Räikkönen    |1979-10-17|Finnish    |http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen|
# |9        |kubica    |88    |KUB |Robert Kubica     |1984-12-07|Polish     |http://en.wikipedia.org/wiki/Robert_Kubica           |
# |10       |glock     |null  |GLO |Timo Glock        |1982-03-18|German     |http://en.wikipedia.org/wiki/Timo_Glock              |
# |11       |sato      |null  |SAT |Takuma Sato       |1977-01-28|Japanese   |http://en.wikipedia.org/wiki/Takuma_Sato             |
# |12       |piquet_jr |null  |PIQ |Nelson Piquet Jr. |1985-07-25|Brazilian  |http://en.wikipedia.org/wiki/Nelson_Piquet,_Jr.      |
# |13       |massa     |19    |MAS |Felipe Massa      |1981-04-25|Brazilian  |http://en.wikipedia.org/wiki/Felipe_Massa            |
# |14       |coulthard |null  |COU |David Coulthard   |1971-03-27|British    |http://en.wikipedia.org/wiki/David_Coulthard         |
# |15       |trulli    |null  |TRU |Jarno Trulli      |1974-07-13|Italian    |http://en.wikipedia.org/wiki/Jarno_Trulli            |
# |16       |sutil     |99    |SUT |Adrian Sutil      |1983-01-11|German     |http://en.wikipedia.org/wiki/Adrian_Sutil            |
# |17       |webber    |null  |WEB |Mark Webber       |1976-08-27|Australian |http://en.wikipedia.org/wiki/Mark_Webber             |
# |18       |button    |22    |BUT |Jenson Button     |1980-01-19|British    |http://en.wikipedia.org/wiki/Jenson_Button           |
# |19       |davidson  |null  |DAV |Anthony Davidson  |1979-04-18|British    |http://en.wikipedia.org/wiki/Anthony_Davidson        |
# |20       |vettel    |5     |VET |Sebastian Vettel  |1987-07-03|German     |http://en.wikipedia.org/wiki/Sebastian_Vettel        |
# +---------+----------+------+----+------------------+----------+-----------+-----------------------------------------------------+
# only showing top 20 rows

# %%
# La función "add_ingestion_date()" se encuentra en el notebook "common_functions"
drivers_with_ingestion_date_df = add_ingestion_date(drivers_df)

# %%
drivers_with_ingestion_date_df.show(truncate=False)
# Out:
# +--------+----------+------+----+---------------------+----------+-----------+-----------------------------------------------------+-----------------------+
# |driverId|driverRef |number|code|name                 |dob       |nationality|url                                                  |ingestion_date         |
# +--------+----------+------+----+---------------------+----------+-----------+-----------------------------------------------------+-----------------------+
# |1       |hamilton  |44    |HAM |{Lewis, Hamilton}    |1985-01-07|British    |http://en.wikipedia.org/wiki/Lewis_Hamilton          |2023-06-11 01:38:44.634|
# |2       |heidfeld  |null  |HEI |{Nick, Heidfeld}     |1977-05-10|German     |http://en.wikipedia.org/wiki/Nick_Heidfeld           |2023-06-11 01:38:44.634|
# |3       |rosberg   |6     |ROS |{Nico, Rosberg}      |1985-06-27|German     |http://en.wikipedia.org/wiki/Nico_Rosberg            |2023-06-11 01:38:44.634|
# |4       |alonso    |14    |ALO |{Fernando, Alonso}   |1981-07-29|Spanish    |http://en.wikipedia.org/wiki/Fernando_Alonso         |2023-06-11 01:38:44.634|
# |5       |kovalainen|null  |KOV |{Heikki, Kovalainen} |1981-10-19|Finnish    |http://en.wikipedia.org/wiki/Heikki_Kovalainen       |2023-06-11 01:38:44.634|
# |6       |nakajima  |null  |NAK |{Kazuki, Nakajima}   |1985-01-11|Japanese   |http://en.wikipedia.org/wiki/Kazuki_Nakajima         |2023-06-11 01:38:44.634|
# |7       |bourdais  |null  |BOU |{Sébastien, Bourdais}|1979-02-28|French     |http://en.wikipedia.org/wiki/S%C3%A9bastien_Bourdais |2023-06-11 01:38:44.634|
# |8       |raikkonen |7     |RAI |{Kimi, Räikkönen}    |1979-10-17|Finnish    |http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen|2023-06-11 01:38:44.634|
# |9       |kubica    |88    |KUB |{Robert, Kubica}     |1984-12-07|Polish     |http://en.wikipedia.org/wiki/Robert_Kubica           |2023-06-11 01:38:44.634|
# |10      |glock     |null  |GLO |{Timo, Glock}        |1982-03-18|German     |http://en.wikipedia.org/wiki/Timo_Glock              |2023-06-11 01:38:44.634|
# |11      |sato      |null  |SAT |{Takuma, Sato}       |1977-01-28|Japanese   |http://en.wikipedia.org/wiki/Takuma_Sato             |2023-06-11 01:38:44.634|
# |12      |piquet_jr |null  |PIQ |{Nelson, Piquet Jr.} |1985-07-25|Brazilian  |http://en.wikipedia.org/wiki/Nelson_Piquet,_Jr.      |2023-06-11 01:38:44.634|
# |13      |massa     |19    |MAS |{Felipe, Massa}      |1981-04-25|Brazilian  |http://en.wikipedia.org/wiki/Felipe_Massa            |2023-06-11 01:38:44.634|
# |14      |coulthard |null  |COU |{David, Coulthard}   |1971-03-27|British    |http://en.wikipedia.org/wiki/David_Coulthard         |2023-06-11 01:38:44.634|
# |15      |trulli    |null  |TRU |{Jarno, Trulli}      |1974-07-13|Italian    |http://en.wikipedia.org/wiki/Jarno_Trulli            |2023-06-11 01:38:44.634|
# |16      |sutil     |99    |SUT |{Adrian, Sutil}      |1983-01-11|German     |http://en.wikipedia.org/wiki/Adrian_Sutil            |2023-06-11 01:38:44.634|
# |17      |webber    |null  |WEB |{Mark, Webber}       |1976-08-27|Australian |http://en.wikipedia.org/wiki/Mark_Webber             |2023-06-11 01:38:44.634|
# |18      |button    |22    |BUT |{Jenson, Button}     |1980-01-19|British    |http://en.wikipedia.org/wiki/Jenson_Button           |2023-06-11 01:38:44.634|
# |19      |davidson  |null  |DAV |{Anthony, Davidson}  |1979-04-18|British    |http://en.wikipedia.org/wiki/Anthony_Davidson        |2023-06-11 01:38:44.634|
# |20      |vettel    |5     |VET |{Sebastian, Vettel}  |1987-07-03|German     |http://en.wikipedia.org/wiki/Sebastian_Vettel        |2023-06-11 01:38:44.634|
# +--------+----------+------+----+---------------------+----------+-----------+-----------------------------------------------------+-----------------------+
# only showing top 20 rows

# %% [markdown]
# #### Paso 3 - Eliminar las columnas no deseadas

# %%
drivers_final_df = drivers_with_ingestion_date_df.drop(col("url"))

# %%
drivers_final_df.show(truncate=False)
# Out:
# +--------+----------+------+----+---------------------+----------+-----------+-----------------------+
# |driverId|driverRef |number|code|name                 |dob       |nationality|ingestion_date         |
# +--------+----------+------+----+---------------------+----------+-----------+-----------------------+
# |1       |hamilton  |44    |HAM |{Lewis, Hamilton}    |1985-01-07|British    |2023-06-11 01:39:03.514|
# |2       |heidfeld  |null  |HEI |{Nick, Heidfeld}     |1977-05-10|German     |2023-06-11 01:39:03.514|
# |3       |rosberg   |6     |ROS |{Nico, Rosberg}      |1985-06-27|German     |2023-06-11 01:39:03.514|
# |4       |alonso    |14    |ALO |{Fernando, Alonso}   |1981-07-29|Spanish    |2023-06-11 01:39:03.514|
# |5       |kovalainen|null  |KOV |{Heikki, Kovalainen} |1981-10-19|Finnish    |2023-06-11 01:39:03.514|
# |6       |nakajima  |null  |NAK |{Kazuki, Nakajima}   |1985-01-11|Japanese   |2023-06-11 01:39:03.514|
# |7       |bourdais  |null  |BOU |{Sébastien, Bourdais}|1979-02-28|French     |2023-06-11 01:39:03.514|
# |8       |raikkonen |7     |RAI |{Kimi, Räikkönen}    |1979-10-17|Finnish    |2023-06-11 01:39:03.514|
# |9       |kubica    |88    |KUB |{Robert, Kubica}     |1984-12-07|Polish     |2023-06-11 01:39:03.514|
# |10      |glock     |null  |GLO |{Timo, Glock}        |1982-03-18|German     |2023-06-11 01:39:03.514|
# |11      |sato      |null  |SAT |{Takuma, Sato}       |1977-01-28|Japanese   |2023-06-11 01:39:03.514|
# |12      |piquet_jr |null  |PIQ |{Nelson, Piquet Jr.} |1985-07-25|Brazilian  |2023-06-11 01:39:03.514|
# |13      |massa     |19    |MAS |{Felipe, Massa}      |1981-04-25|Brazilian  |2023-06-11 01:39:03.514|
# |14      |coulthard |null  |COU |{David, Coulthard}   |1971-03-27|British    |2023-06-11 01:39:03.514|
# |15      |trulli    |null  |TRU |{Jarno, Trulli}      |1974-07-13|Italian    |2023-06-11 01:39:03.514|
# |16      |sutil     |99    |SUT |{Adrian, Sutil}      |1983-01-11|German     |2023-06-11 01:39:03.514|
# |17      |webber    |null  |WEB |{Mark, Webber}       |1976-08-27|Australian |2023-06-11 01:39:03.514|
# |18      |button    |22    |BUT |{Jenson, Button}     |1980-01-19|British    |2023-06-11 01:39:03.514|
# |19      |davidson  |null  |DAV |{Anthony, Davidson}  |1979-04-18|British    |2023-06-11 01:39:03.514|
# |20      |vettel    |5     |VET |{Sebastian, Vettel}  |1987-07-03|German     |2023-06-11 01:39:03.514|
# +--------+----------+------+----+---------------------+----------+-----------+-----------------------+
# only showing top 20 rows

# %%
drivers_final_df.printSchema()
# Out:
# root
#  |-- driverId: integer (nullable = true)
#  |-- driverRef: string (nullable = true)
#  |-- number: integer (nullable = true)
#  |-- code: string (nullable = true)
#  |-- name: struct (nullable = true)
#  |    |-- forename: string (nullable = true)
#  |    |-- surname: string (nullable = true)
#  |-- dob: date (nullable = true)
#  |-- nationality: string (nullable = true)
#  |-- ingestion_date: timestamp (nullable = false)

# %% [markdown]
# #### Paso 4 - Escribir datos en el contenedor **processed** del ADLS como **parquet**

# %%
# Escribimos el archivo con formato PARQUET en el contenedor "processed" y directorio "drivers"
drivers_final_df.write.mode('overwrite').parquet(f"{processed_folder_path}/drivers")

# %%
# Visualizamos los objetos que se encuentran en el directorio "constructors"
# %fs
ls /mnt/formula1dl/processed/drivers
