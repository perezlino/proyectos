# %% [markdown]
# ### **Información proyecto - Carga de `Dataframe` a `Postgres`**

# %% [markdown]
# En este proyecto vamos a desarrollar movimiento de datos desde mi `Sistema local` a la base de datos `Postgres`. Más especificamente se realizaran los siguientes pasos:
#
# - Se cargara el dataframe de un archivo `CSV` en una tabla que crearemos en la base de datos `Postgres`
# - Luego en base a esa tabla se crearan 3 nuevos `dataframes`
# - Se crearan 3 nuevas tablas y se cargaran esos 3 `dataframes` en la base de datos `Postgres`

# %% [markdown]
# <center><img src="https://i.postimg.cc/MKTVzqDG/p47.png"></center> <Corresponde a la imagen p5>
